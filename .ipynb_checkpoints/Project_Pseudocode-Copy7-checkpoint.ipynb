# %%
import random
import pandas as pd
import copy
import matplotlib as plt

"Hello world"
# Out:
# 'Hello world'

# %% [markdown]
# # Data Models

# %%
# =======================  INSERT STUDENTS INTO DATAFRAME
student_file = pd.read_csv('studentNames.csv', header=None)
print(student_file)

# =======================  INSERT COURSES INTO DATAFRAME
course_file = pd.read_csv('courses.csv', header=None)
print(course_file)


# =======================  INSERT STUDENT COURSES INTO DATAFRAME
student_course_file = pd.read_csv('studentCourse.csv')
print(student_course_file)


# =======================  INSERT TEACHERS INTO DATAFRAME
teacher_file = pd.read_csv('teachers.csv')
print(teacher_file)

# =======================  INSERT CLASSROOMS INTO DATAFRAME



# =======================  INSERT DAYS INTO DATAFRAME





## Construct a valid input here (according to what we need)

# Structure (Bottom-Up):
#        1. Gene : Contains 1 course, 1 instructor , and an array of Students, It's corresponding Day (mon, tue, wed ...) ,
#                  It's corresponding Time (9-12, 10-1 ...).
#        2. Chromosome: Contains a classroom , TimeTable for the classroom , fitness value of the generated Timetable
#        3. Member: Contains a list of chromosomes
#        4. Population:  Contains a list of members


# initialise population 

Classrooms_Array = ['c301','c302','c303','c304','c305','c306','c307','c308','c309','c310']
Courses_Array = ['CS217','CS218','CS219','CS220','CS221','CS222']
Instructors_Array = ['Ayesha Bano','Aqeel Shahzad','Usman Rashid','Maimoona Rassol','Muhammad bin Qasim','Sanaa Ilyas']
Students_Array = ['Bano','Aqeel Usman ','Shahzad Rashid','Maimoona Qasim','Muhammad bin Aqeel','Sanaa Rassol']
Days_Array = ['Sunday', 'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

class Course:
    def __init__ (self, id, name):
        self.id = id
        self.name = name

class Instructor:
    def __init__ (self, name):
        self.name = name
        
class Student:
    def __init__ (self, name):
        self.name = name

class Classroom:
    def __init__ (self, id, capacity):
        self.id = id
        self.capacity = capacity
        
class Student_Course:
    def __init__ (self, course, student):
        self.course = course
        self.student_id = student
# Out:
#                      0
# 0        Mohammed Azam
# 1    Mohamed F Bakaram
# 2      Manal Aldaihani
# 3        Ibrar Manawer
# 4         Adam Flowers
# ..                 ...
# 195     Naveed Hussain
# 196      Sarah L Clark
# 197       Maria Lytras
# 198        Bibi A Khan
# 199       Iram Matloob
#
# [200 rows x 1 columns]
#          0                                            1
# 0    CS217                  Object Oriented Programming
# 1    EE227                         Digital Logic Design
# 2    CS211                          Discrete Structures
# 3    SE110                Intro to Software Engineering
# 4    CS118                     Programming Fundamentals
# 5    CS219                             Database Systems
# 6    CS220                            Operating Systems
# 7    CS302              Design & Analysis of Algorithms
# 8   CY2012                            Digital Forensics
# 9    CS307                            Computer Networks
# 10   CS328                         Software Engineering
# 11   EE229  Computer Organization and Assembly Language
# 12  AI2011                           Programming for AI
# 13  DS3011                           Big Data Analytics
# 14   CS328                         Software Engineering
# 15   CS218                              Data Structures
# 16   EE229    Computer Organization & Assembly Language
# 17   CS211                          Discrete Structures
# 18   MT224                       Differential Equations
# 19   SS113                             Pakistan Studies
# 20   MG220                         Marketing Management
# 21   MG223                   Fundamentals of Management
# 22   SS111                Islamic and Religious Studies
# 23   SS152          Communication & Presentation Skills
# 24   SS118                                   Psychology
# 25   MT205                   Probability and Statistics
#      Unnamed: 0                 Student Name Course Code
# 0             0                Sam D Edwards      AI2011
# 1             1               Sheila Hughton      DS3011
# 2             2                 Yasmin Ahmed       SE110
# 3             3  Sarah N Md Sallehuddin Khan       EE229
# 4             4                Sarah Nolasco      AI2011
# ..          ...                          ...         ...
# 815         815                    Adam Kirk      DS3011
# 816         816                Tara Glickman       SS111
# 817         817                Nina N Wronka       CS218
# 818         818                 Sonia V Diaz       MG220
# 819         819                 Sarah Wilson       MT224
#
# [820 rows x 3 columns]
#           Ayesha Bano
# 0       Aqeel Shahzad
# 1           Farah Naz
# 2          Hamda Khan
# 3        Usman Rashid
# 4   Farah Jabeen Awan
# ..                ...
# 57       Kashif Munir
# 58      Hammad Majeed
# 59       Noreen Jamil
# 60     Hassan Mustafa
# 61       Farwa Batool
#
# [62 rows x 1 columns]

# %% [markdown]
# # Population Model

# %%
class Gene:
    def __init__(
            self,
            course=None,
            instructor=None,
            students=None,
            day=None,
            start_time=None,
            end_time=None,
            classroom_name=None,
    ):

        if course is None:
            course = Courses_Array[random.randint(0, len(Courses_Array) - 1)]

        if instructor is None:
            instructor = Instructors_Array[random.randint(0, len(Instructors_Array) - 1)]

        if students is None:
            L = random.randint(1, len(Students_Array))
            students = random.sample(Students_Array, L)

        if day is None:
            day = Days_Array[random.randint(0, len(Days_Array) - 1)]

        if start_time is None:
            start_time = random.randint(9.0, 17.0)
        
        if end_time is None:
            ## Logical way is to start this range from start_time
            end_time = random.randint(start_time, 17.0)

        if classroom_name is None:
            classroom_name = Classrooms_Array[random.randint(0, len(Classrooms_Array) - 1)]
        
        self.course = course
        self.instructor = instructor
        self.students = students
        self.day = day
        self.start_time = start_time
        self.end_time = end_time
        self.classroom_name = classroom_name

    def __str__(self):
        return (
                self.classroom_name  + "\t" +
                self.day             + "\t" +
                str(self.start_time) + "\t" +
                str(self.end_time)   + "\t" +
                self.course          + "\t" +
                self.instructor      + "\t" +
                str(self.students)   + "\t" +
                "."
               )

class Chromosome:

    def __init__(self,
                 genes=None,
                 fitness_value=None,
                 ):


        if genes is None:
            genes = []
            for i in range(0, random.randint(30, 50)):
                genes.append(Gene())

        
        if fitness_value is None:
            fitness_value=0
        
        
        self.genes = genes
       
        self.fitness_value = fitness_value
        
    def __getitem__(self, index):
        return self.genes[index]

class Population:

    def __init__(self,
                 chromosomes=None
                 ):

        if chromosomes is None:
            chromosomes = []
            for i in range(1, 20):
                chromosomes.append(Chromosome())

        self.chromosomes = chromosomes                
                
    def __getitem__(self, index):
        return self.chromosomes[index]

# %% [markdown]
# # Initialization

# %%
def initialize_population():
    
    new_population = Population()

    
#     ----------------------------------------------- Debugging
#     for member in new_population.members:
#         for chromosome in member.chromosomes:
#             for gene in chromosome.genes:
#                 print (gene.course,gene.instructor,gene.students,gene.day,gene.start_time,gene.end_time)
#     ----------------------------------------------- Debugging


    return new_population

# %%
new_pop = initialize_population()

for chromosome in new_pop:
#         print("\n\nCLASSROOM:", chromosome.classroom_name)
    sort_by_day = sorted(chromosome, key=lambda gene: (gene.day, gene.start_time) )
    for gene in sort_by_day:
        print(gene)
# Out:
# c307	Friday	10	13	CS222	Aqeel Shahzad	['Aqeel Usman ', 'Maimoona Qasim']	.
# c305	Friday	11	13	CS219	Sanaa Ilyas	['Maimoona Qasim', 'Aqeel Usman ']	.
# c305	Friday	16	17	CS218	Sanaa Ilyas	['Sanaa Rassol', 'Aqeel Usman ', 'Muhammad bin Aqeel', 'Shahzad Rashid', 'Bano']	.
# c310	Friday	17	17	CS220	Sanaa Ilyas	['Sanaa Rassol', 'Bano', 'Aqeel Usman ', 'Shahzad Rashid', 'Maimoona Qasim', 'Muhammad bin Aqeel']	.
# c309	Monday	10	15	CS220	Sanaa Ilyas	['Shahzad Rashid', 'Muhammad bin Aqeel', 'Aqeel Usman ', 'Sanaa Rassol', 'Maimoona Qasim', 'Bano']	.
# c310	Monday	14	17	CS218	Ayesha Bano	['Maimoona Qasim', 'Bano', 'Aqeel Usman ', 'Shahzad Rashid', 'Sanaa Rassol']	.
# c307	Monday	16	17	CS219	Maimoona Rassol	['Aqeel Usman ']	.
# c302	Monday	17	17	CS220	Ayesha Bano	['Bano', 'Aqeel Usman ', 'Maimoona Qasim', 'Shahzad Rashid', 'Muhammad bin Aqeel', 'Sanaa Rassol']	.
# c307	Saturday	11	17	CS222	Usman Rashid	['Aqeel Usman ', 'Bano', 'Maimoona Qasim', 'Shahzad Rashid', 'Muhammad bin Aqeel']	.
# c305	Saturday	12	16	CS222	Aqeel Shahzad	['Bano', 'Aqeel Usman ', 'Maimoona Qasim']	.
# c302	Saturday	14	16	CS219	Usman Rashid	['Sanaa Rassol', 'Muhammad bin Aqeel']	.
# c304	Sunday	9	11	CS220	Sanaa Ilyas	['Sanaa Rassol', 'Shahzad Rashid', 'Bano', 'Maimoona Qasim', 'Aqeel Usman ']	.
# c308	Sunday	12	13	CS221	Sanaa Ilyas	['Muhammad bin Aqeel', 'Maimoona Qasim', 'Sanaa Rassol', 'Bano']	.
# c303	Sunday	13	13	CS217	Sanaa Ilyas	['Bano', 'Muhammad bin Aqeel', 'Maimoona Qasim', 'Shahzad Rashid', 'Aqeel Usman ']	.
# c303	Sunday	16	17	CS220	Ayesha Bano	['Muhammad bin Aqeel', 'Maimoona Qasim', 'Aqeel Usman ', 'Bano', 'Shahzad Rashid']	.
# c305	Thursday	9	12	CS218	Aqeel Shahzad	['Aqeel Usman ', 'Bano', 'Muhammad bin Aqeel']	.
# c303	Thursday	12	13	CS218	Aqeel Shahzad	['Aqeel Usman ', 'Shahzad Rashid', 'Bano', 'Maimoona Qasim', 'Muhammad bin Aqeel', 'Sanaa Rassol']	.
# c303	Thursday	15	16	CS221	Muhammad bin Qasim	['Aqeel Usman ', 'Bano']	.
# c301	Thursday	15	15	CS222	Aqeel Shahzad	['Aqeel Usman ', 'Muhammad bin Aqeel']	.
# c308	Thursday	16	16	CS222	Usman Rashid	['Muhammad bin Aqeel', 'Sanaa Rassol', 'Aqeel Usman ', 'Maimoona Qasim']	.
# c309	Thursday	16	17	CS218	Ayesha Bano	['Aqeel Usman ']	.
# c305	Thursday	17	17	CS219	Sanaa Ilyas	['Muhammad bin Aqeel']	.
# c305	Thursday	17	17	CS220	Muhammad bin Qasim	['Shahzad Rashid', 'Maimoona Qasim']	.
# c310	Thursday	17	17	CS221	Muhammad bin Qasim	['Maimoona Qasim']	.
# c301	Tuesday	12	13	CS217	Maimoona Rassol	['Sanaa Rassol', 'Aqeel Usman ']	.
# c305	Wednesday	10	17	CS222	Muhammad bin Qasim	['Maimoona Qasim', 'Shahzad Rashid', 'Aqeel Usman ', 'Muhammad bin Aqeel', 'Sanaa Rassol', '
        current += chromosome.fitness_value
        if current > pick:
            mom = chromosome
            break

    pick = random.uniform(0, maximum_val)
    current = 0
    for chromosome in population:
        current += chromosome.fitness_value
        if current > pick:
            dad = chromosome
            break

    if mom is None:
        mom = population[random.randint(0,len(population.chromosomes)-1)]

    if dad is None:
        dad = population[random.randint(0, len(population.chromosomes) - 1)]

    return mom, dad


def elitism(population):
    max_index_1 = 0
    max_index_2 = 0
    max_fitness1 = 0
    max_fitness2 = 0

    for idx, individual in enumerate(population.chromosomes):
        if individual.fitness_value > max_fitness2:
            if individual.fitness_value > max_fitness1:
                max_fitness2 = max_fitness1
                max_index_2 = max_index_1
                max_fitness1 = individual.fitness_value
                max_index_1 = idx
            elif individual.fitness_value > max_fitness2:
                max_fitness2 = individual.fitness_value
                max_index_2 = idx

    return population[max_index_1], population[max_index_2]


def select_best_mom_and_dad(population):
    ## Since we're instructed to do Roulette_wheel_selection...
#     return roulette_wheel_selection(population)

    ## i g n o r e d
    return elitism(population)

# %%
new_pop = initialize_population()

for member in new_pop:
    member.fitness_value = random.randint(0,20)

mom,dad = select_best_mom_and_dad(new_pop)

print(" M O M ")

for gene in mom:
    print(gene)
        
print()
print(" D A D ") 

for gene in dad:
    print(gene)
# Out:
#  M O M
# c306	Friday	9	11	CS221	Ayesha Bano	['Maimoona Qasim']	.
# c305	Thursday	17	17	CS222	Ayesha Bano	['Bano']	.
# c304	Sunday	15	15	CS219	Aqeel Shahzad	['Aqeel Usman ', 'Maimoona Qasim', 'Bano', 'Shahzad Rashid', 'Muhammad bin Aqeel', 'Sanaa Rassol']	.
# c310	Wednesday	13	15	CS217	Usman Rashid	['Muhammad bin Aqeel', 'Shahzad Rashid']	.
# c309	Wednesday	17	17	CS217	Maimoona Rassol	['Shahzad Rashid']	.
# c307	Friday	17	17	CS217	Usman Rashid	['Shahzad Rashid', 'Sanaa Rassol', 'Aqeel Usman ', 'Bano']	.
# c302	Saturday	13	17	CS222	Aqeel Shahzad	['Shahzad Rashid', 'Sanaa Rassol', 'Maimoona Qasim']	.
# c302	Saturday	9	10	CS221	Maimoona Rassol	['Muhammad bin Aqeel', 'Shahzad Rashid', 'Sanaa Rassol', 'Aqeel Usman ', 'Bano']	.
# c308	Saturday	10	11	CS220	Maimoona Rassol	['Bano', 'Maimoona Qasim', 'Sanaa Rassol']	.
# c308	Friday	10	13	CS218	Muhammad bin Qasim	['Muhammad bin Aqeel']	.
# c306	Sunday	13	15	CS221	Usman Rashid	['Aqeel Usman ', 'Shahzad Rashid', 'Maimoona Qasim']	.
# c304	Wednesday	13	14	CS222	Sanaa Ilyas	['Bano', 'Shahzad Rashid', 'Aqeel Usman ']	.
# c307	Sunday	12	14	CS222	Sanaa Ilyas	['Sanaa Rassol', 'Maimoona Qasim', 'Shahzad Rashid']	.
# c302	Friday	9	12	CS218	Maimoona Rassol	['Bano', 'Maimoona Qasim', 'Aqeel Usman ', 'Sanaa Rassol', 'Shahzad Rashid', 'Muhammad bin Aqeel']	.
# c305	Sunday	10	13	CS217	Aqeel Shahzad	['Muhammad bin Aqeel', 'Shahzad Rashid', 'Bano']	.
# c309	Friday	16	16	CS218	Ayesha Bano	['Bano']	.
# c307	Saturday	9	17	CS217	Maimoona Rassol	['Shahzad Rashid', 'Aqeel Usman ']	.
# c307	Wednesday	9	12	CS222	Sanaa Ilyas	['Bano', 'Aqeel Usman ', 'Maimoona Qasim', 'Sanaa Rassol', 'Shahzad Rashid', 'Muhammad bin Aqeel']	.
#
['Aqeel Usman ', 'Muhammad bin Aqeel', 'Bano', 'Shahzad Rashid', 'Maimoona Qasim']	.
# c301	Saturday	17	17	CS217	Usman Rashid	['Aqeel Usman ', 'Shahzad Rashid', 'Maimoona Qasim', 'Muhammad bin Aqeel', 'Bano']	.
# c308	Friday	9	11	CS220	Ayesha Bano	['Muhammad bin Aqeel', 'Aqeel Usman ', 'Sanaa Rassol', 'Maimoona Qasim', 'Bano']	.
# c306	Tuesday	9	12	CS217	Ayesha Bano	['Maimoona Qasim', 'Muhammad bin Aqeel', 'Shahzad Rashid', 'Bano']	.
# c304	Wednesday	13	16	CS218	Usman Rashid	['Sanaa Rassol', 'Aqeel Usman ', 'Bano', 'Muhammad bin Aqeel']	.
# c309	Tuesday	16	16	CS221	Sanaa Ilyas	['Shahzad Rashid']	.
# c310	Thursday	11	16	CS221	Muhammad bin Qasim	['Shahzad Rashid', 'Sanaa Rassol', 'Bano']	.
# c302	Sunday	9	17	CS218	Maimoona Rassol	['Aqeel Usman ', 'Bano', 'Sanaa Rassol', 'Muhammad bin Aqeel', 'Shahzad Rashid']	.
# c304	Thursday	11	15	CS222	Usman Rashid	['Muhammad bin Aqeel']	.
# c305	Friday	13	16	CS221	Ayesha Bano	['Aqeel Usman ', 'Maimoona Qasim', 'Shahzad Rashid', 'Sanaa Rassol', 'Bano', 'Muhammad bin Aqeel']	.
# c308	Saturday	10	11	CS222	Maimoona Rassol	['Maimoona Qasim', 'Sanaa Rassol', 'Aqeel Usman ']	.
# c301	Wednesday	11	17	CS222	Maimoona Rassol	['Shahzad Rashid', 'Muhammad bin Aqeel', 'Aqeel Usman ', 'Bano']	.
# c307	Sunday	14	16	CS222	Sanaa Ilyas	['Bano', 'Aqeel Usman ', 'Maimoona Qasim', 'Muhammad bin Aqeel', 'Shahzad Rashid']	.
# c301	Wednesday	13	14	CS220	Usman Rashid	['Sanaa Rassol', 'Bano', 'Maimoona Qasim']	.
# c301	Friday	16	16	CS219	Ayesha Bano	['Bano', 'Maimoona Qasim', 'Muhammad bin Aqeel', 'Sanaa Rassol']	.
# c310	Thursday	12	12	CS221	Muhammad bin Qasim	['Aqeel Usman ', 'Shahzad Rashid', 'Maimoona Qasim', 'Muhammad bin Aqeel', 'Bano']	.
# c310	Sunday	10	14	CS221	Sanaa Ilyas	['Bano', 'Muhammad bin Aqeel', 'Shahzad Rashid', 'Aqeel Usman ']	.
# c303	Thursday	14	17	CS221	Muhammad bin Qasim	['Bano', 'Sanaa Rassol', 'Aqeel Usman ', 'Muhammad bin Aqeel']	.
# c305	Friday	17	17	CS219	Maimoona Rassol	['Shahzad Rashid', 'Sanaa Rassol', 'Muhammad bin Aqeel', 'Aqeel Usman ', 'Maimoona Qasim']	.
# c309	Wednesday	10	17	CS219	Maimoona Rassol	['Sanaa Rassol', 'Aqeel Usman ', 'Bano', 'Maimoona Qasim']	.
# c307	Monday	14	14	CS222	Ayesha Bano	['Maimoona Qasim', 'Shahzad Rashid', 'Sanaa Rassol', 'Muhammad bin Aqeel']	.
# c307	Saturday	14	14	CS218	Usman Rashid	['Muhammad bin Aqeel']	.
# c301	Wednesday	15	16	CS217	Sanaa Ilyas	['Maimoona Qasim', 'Aqeel Usman ', 'Sanaa Rassol', 'Shahzad Rashid']	.
# c303	Thursday	15	17	CS217	Aqeel Shahzad	['Shahzad Rashid', 'Maimoona Qasim', 'Aqeel Usman ', 'Muhammad bin Aqeel', 'Sanaa Rassol']	.

# %% [markdown]
# # Crossover

# %%
def binary_crossover(husband, wife):
    length = len(husband.genes) // 2
    children = []
    son = husband.genes[:length] + wife.genes[length:]
    daughter = wife.genes[:length] + husband.genes[length:]

    children.append(son)
    children.append(daughter)

    return children


def randomized_fixed_point_crossover(mom, dad):
    # Random point must be between the length of the best member
#     print("Length of member 1 are:", len(chromosome_1.genes))
    pass_loop = True

    new_pop = []

    while pass_loop:
        try:
            random_fixed_point = random.randint(1, len(mom.genes) - 1)
            son = mom.genes[:random_fixed_point] + dad.genes[random_fixed_point:]
            daughter = dad.genes[:random_fixed_point] + mom.genes[random_fixed_point:]

            new_pop.append(son)
            new_pop.append(daughter)

#             for gene_a, gene_b in zip(chromosome_a, chromosome_b):
#                 if (gene_a == gene_b):
#                     print ("Gene is same!")
            
#             if chromosome_a == chromosome_b:
#                 print ("Chromosome is same!")
            
            pass_loop = False
        except:
            pass_loop = True

    return new_pop


def crossover(mom, dad, population):
    #     return binary_crossover(mom, dad)
    new_chromosomes = []
    for i in range(0, random.randint(2, 30)):
        children = randomized_fixed_point_crossover(mom, dad)
        for child in children:
#             if (child not in new_chromosomes):
            new_chromosomes.append(Chromosome(genes=child))

    return Population(chromosomes=new_chromosomes)

# %% [markdown]
# # Constraints

# %%
def hard_test_invigilator(chromosome):
    wrong_value = 0
    wrong_genes = []

    # for gene1 in chromosome.genes:
    #     for gene2 in chromosome.genes:
    #         if gene1.day == gene2.day:
    #             if gene1.start_time == gene2.start_time:
    #                 wrong_genes.append(gene1)
    #                 wrong_genes.append(gene2)
    #                 wrong_value += 1

    i = 0
    while i < len(chromosome.genes) - 1:
        j = i
        while j < len(chromosome.genes) - 1:
            j += 1
            if chromosome[i].day == chromosome[j].day:
                if chromosome[i].instructor == chromosome[j].instructor:
                    if abs(chromosome[i].start_time - chromosome[j].start_time) < 3:
                        if (chromosome[i], chromosome[j]) not in wrong_genes and (
                                chromosome[j], chromosome[i]) not in wrong_genes:
                            # wrong_genes.append((chromosome[i], chromosome[j]))
                            # wrong_value += 1
                            return False
        i += 1

    for genes in wrong_genes:
        print(genes[0])
        print(genes[1])

    # return wrong_value
    return True


def hard_test_valid_paper_duration(chromosome):
    #     for chromosome in chromosomes:
    points = 0
    for gene_p in chromosome:
        if (gene_p.end_time - gene_p.start_time) != 3:
            continue
        else:
            points += 10

    #     print("I am true at: ",gene_p.start_time,gene_p.end_time)
    return points


def hard_test_no_exam_on_weekends(chromosome):
    #     for chromosome in chromosomes:
    points = 0
    for gene_p in chromosome:
        if (gene_p.day in ["Saturday", "Sunday"]):
            continue
        else:
            points += 10
    return points




# def hard_test_one_invigilator_per_exam(chromosome):
#     """At a given time, one instructor can only invigilate one exam"""
#     pass



## Possible generic constraints
def hard_test_student_one_exam_at_a_time(chromosome):
    """At a given time, student can only give one exam"""
    # Note: Also test the current gene from which the student is selected, because the same student might be repeated in a single class
    points = 0
    i = j = 0

    while i < len(chromosome.genes):
        for student in chromosome.genes[i].students:
            for genes in chromosome:
                if genes == chromosome.genes[i]:
                    continue
                if genes.start_time == chromosome.genes[i].start_time and genes.day == chromosome.genes[i].day:
                    if student in genes.students:
                        # print('Student in multiple exam')
                        continue
                    else:
                        points += 10
        i += 1

    return points

def hard_test_one_exam_per_course(chromosome):
    """First hard constraint: Every course must have an exam"""
    pass

def hard_test_one_exam_per_classroom(chromosome):
    """At a given time, a classroom can only have one exam ongoing"""
    pass

def hard_test_classroom_capacity(chromosome):
    """Number of students in an exam must not exceed the classroom capacity"""
    pass

def hard_test_students_taking_correct_exam(chromosome):
    """Students must be taking the exam of the course they're registered for"""
    pass




def soft_test_consecutive_exams(data):
    print("Hello soft constraint test")
    return True


HARD_CONSTRAINTS = [
    {
        "name": "Paper must be of 3 hours",
        "func": hard_test_valid_paper_duration,
        "fields": [
            'start_time',
            'end_time',
        ]
    },
#     {
#             "name":"Instructor cannot invigilate two consecutive exams",
#             "func":hard_test_invigilator,
#             "fields":[
#                 'instructor',
#             ]
#     },
    {
        "name": "No exams on weekend",
        "func": hard_test_no_exam_on_weekends,
        "fields": [
            'day',
        ]
    },
    {
        "name": "One exam at a time",
        "func": hard_test_student_one_exam_at_a_time,
        "fields": [
            'students',
        ]
    },
]

soft_constraints = [
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },

]

# %% [markdown]
# # Fitness of chromosome

# %%
def set_fitness(chromosome_p):
    constraints_passed = 0
    fields_to_mutate = []

    # Right now, checking only hard constraints
    for constraint in HARD_CONSTRAINTS:
        constraints_passed += constraint["func"](chromosome_p)
        if constraints_passed < 1000:
            if constraint["fields"] not in fields_to_mutate: fields_to_mutate += constraint["fields"]

    # Set fitness value of individual chromosome
    chromosome_p.fitness_value = constraints_passed

    return constraints_passed, fields_to_mutate

# %%
new_pop = initialize_population()

for chromosome in new_pop:
    chromosome.fitness_value = random.randint(0,20)

mom, dad = select_best_mom_and_dad(new_pop)

fields_to_mutate = []


fitness_value, temp_fields = set_fitness(mom)
if temp_fields not in fields_to_mutate: fields_to_mutate.append(temp_fields)
else: fields_to_mutate.append([])
    
        
print(fields_to_mutate)
# Out:
# [['start_time', 'end_time', 'day', 'students']]

# %% [markdown]
# # Mutation

# %%
def choose_random_possibility_from_model(gene, fields):
    # Two different approaches:
    # 1. Only mutate those values which were found to violate the constraints e.g time was not right so mutate time only
    #    -> will require a list of all constraints not met by the chromosome
    # 2. Mutate the entire gene completely

    # For now, let's try a combination of both.
    # Our model is partially self-aware.
    # So what we can do is that flip a coin.
    # If heads, then return a completely new gene.
    # If tails, apply some self-awareness.

    coin = random.randint(0, 1)

    # First make a completely random new Gene
    new_gene = Gene()

    # If heads...
    if coin:
        return new_gene

    # Else if tails...

    # Modify the existing fields of the selected gene
    for field in fields:
        setattr(gene, field, getattr(new_gene, field))

    return gene


def mutate(chromosome, fields_to_mutate):
    random_index = random.randint(0, len(chromosome.genes) - 1)
    # print('current gene: ', chromosome.genes[random_index], '\n\n')
    chromosome.genes[random_index] = choose_random_possibility_from_model(chromosome.genes[random_index],
                                                                          fields_to_mutate)
    # print('after mutation gene: ', chromosome.genes[random_index], '\n\n')

    return chromosome.genes[random_index]

# %%
    new_pop = initialize_population()

    for chromosome in new_pop:
        chromosome.fitness_value = random.randint(0,20)
    
    mom, dad = select_best_mom_and_dad(new_pop)

    fields_to_mutate = []

    fitness_value, temp_fields = set_fitness(mom)
    if temp_fields not in fields_to_mutate:
        fields_to_mutate.append(temp_fields)
    else:
        fields_to_mutate.append([])

#     for gene in mom:
#         print(gene)
        
    print(fields_to_mutate)

    # print('Mom genes before mutation')
    # for chromosome in mom:
    #     for gene in chromosome:
    #         print(gene)
    random_index = random.randint(0, len(mom.genes) - 1)
    previous_constraint, fields_to_mutate = set_fitness(mom)
    print('Constraints met before mutation: ', previous_constraint)

    for i in range(0, 2000):
        mutate(mom, fields_to_mutate)

        new_constraint, fields_to_mutate = set_fitness(mom)

#     for gene in mom:
#         print(gene)
    print('Constraints met after mutation: ', new_constraint)
# Out:
# [['start_time', 'end_time', 'day', 'students']]
# Constraints met before mutation:  430
# Constraints met after mutation:  350

# %% [markdown]
# # Evaluation

# %%
min_soft_constraints = 3

def evaluate(candidate, tatti):
    
#     for constraint in hard_constraints:
#         if (constraint["func"](solution) == False):
#             return False

#     print (tatti)

    if tatti is None:
        tatti = copy.deepcopy(candidate)
    elif candidate.fitness_value > tatti.fitness_value:
        tatti = copy.deepcopy(candidate)
#     soft_constraint_pass_counter = 0
#     for constraint in soft_constraints:
#         if (constraint["func"](solution) == True):
#             soft_constraint_pass_counter += 1
#         if soft_constraint_pass_counter > min_soft_constraints:
#             return True
            
    
    return tatti

# %%
# evaluate(mom)

# %% [markdown]
# # Our Genetic Algorithm
#
# ## Basic
# Steps are:
# - ~Generate New Population~
# - ~Initial Selection of Parents~
# - ~Crossover~
# - ~Fitness~
# - ~Mutate~
# - ~Select best mom and dad~
# - ~Evaluate~
#
# ## Advanced
# - Use pandas, numpy
# - ~Set accurate constraints (we have issues in some constraints where we are only checking Intra-chromosome, whereas we should be checking  INTER-chromosome e.g. Teacher constraint, sometimes teacher might appear in different classrooms)~ (Fixed by putting classroom_name in Gene class)
# - Make all test cases
# - ~Completely clean out "Member" implementations~
# - ~Generate more children~
# - ~Roulette wheel selection~
# - Population regeneration if evaluation failure, if certain number of failures happen then stop
#     - If mom and dad better than last time, then continue. Maybe you'll find better
# - Days should have IDs, so that we can also go to the next week incase the current week is full
# - Generate a completely correct value
#
#
#
# ## Cherry-on-top
# - Use data from the CSVs

# %%
def print_mom_and_dad(mom, dad):
    print("Mom genes:")

    for gene in mom:
        print(gene)

    print("Mom Fitness Value: ", mom.fitness_value)
    print("\n")
    print("Dad genes:")
    
    for gene in dad:
        print(gene)
    
    print("Dad Fitness Value: ", dad.fitness_value)


def GeneticAlgorithm():
        #     min_benchmark = calculate_minimum_benchmark(domain)
    #     min_distance = random.randint(50, 100)
    #     fail_limit = random.randint(0,20)

    mutation_probability = random.randint(0, 50)

    new_generation = initialize_population()

    solution_counter = 0
    prev_best_solution = None
    best_solution = None
    
    ## Two options:
    ## Randomize initial mom and dad
    # mom, dad = new_generation[random.randint(0, len(new_generation.chromosomes) // 2)], new_generation[
    # random.randint(len(new_generation.chromosomes) // 2, len(new_generation.chromosomes) - 1)]

    ## Or select the best
    for chromosome in new_generation:
        set_fitness(chromosome)        
    mom, dad = select_best_mom_and_dad(new_generation)
    
    
    print("========================= Before:")
    print_mom_and_dad(mom, dad)

    
    print("\n\n")

    for i in range(0, 1000):

#         print("Mom is = ", mom)
#         print("Dad is = ", dad)
        children = crossover(mom, dad, new_generation)
        new_chromosomes = []
        fields_to_mutate = []
        for idx, chromosome in enumerate(children):

            fitness_value, temp_fields = set_fitness(chromosome)
            fields_to_mutate.append(temp_fields)

#             if fitness_value == -1:
#                 continue

            if random.randint(0, 100) < mutation_probability:
#                 prev_fitness_value = copy.deepcopy(fitness_value)
#                 while fitness_value <= prev_fitness_value:
                mutate(chromosome, fields_to_mutate[idx])
                fitness_value_changed, fields_to_mutate[idx] = set_fitness(chromosome)
                fitness_value = fitness_value_changed

            new_chromosomes.append(chromosome)



#         sorted_generation = sorted(new_generation, key=lambda chromosome: chromosome.fitness_value )

#         new_generation.chromosomes = sorted_generation[len(sorted_generation)//2:]
               
#         for chromosome in new_chromosomes:
#             new_generation.chromosomes.append(chromosome)

            
        next_gen = Population(chromosomes=new_chromosomes)

#         for chromosome in next_gen:
#             print("Fitness value", chromosome.fitness_value)

        mom, dad = select_best_mom_and_dad(next_gen)
        
        best_solution = evaluate(mom, best_solution)
        
        ### print Every 100th generation results
        if i % 50 == 0:
            
            
            print ('\nCurrent generation..: {}'.format(i))
            print ('Current Mom fitness value:', mom.fitness_value)
            print ('Current Dad fitness value:', dad.fitness_value)
            print ('Best solution so far: {}'.format(best_solution.fitness_value))
            if prev_best_solution is None:
                prev_best_solution = best_solution
            if best_solution.fitness_value > prev_best_solution.fitness_value:
                solution_counter = 0
            elif best_solution.fitness_value == prev_best_solution.fitness_value:
                solution_counter += 1
            
            print (solution_counter)
            
            if solution_counter > 5:
                # Too much stagnation
                print("Stagnation occured. DESTROY POPULATION.")
                new_generation = initialize_population()
                new_generation.chromosomes.append(mom)
                new_generation.chromosomes.append(prev_best_solution)
        
                solution_counter = 0

            elif solution_counter > 1:
                # Reintroduce  D A D into chromosome pool
                print("Sending heavenly assistance.")
                dad = best_solution
                
            else:
                prev_best_solution = best_solution
        
        

    print("\n\n")
    
    print("========================= After 1000 iterations:")
    print_mom_and_dad(mom, dad)

    print ("\n\n=================================------------======================================")

    print ("Our best solution is:")
    for gene in best_solution:
        print (gene)
        
    print ("\nFitness value is: ", best_solution.fitness_value)

# %%
GeneticAlgorithm()
# Out:
# ========================= Before:
# Mom genes:
# c307	Wednesday	17	17	CS222	Maimoona Rassol	['Sanaa Rassol', 'Bano', 'Muhammad bin Aqeel', 'Aqeel Usman ']	.
# c310	Wednesday	14	14	CS220	Usman Rashid	['Sanaa Rassol', 'Bano', 'Shahzad Rashid', 'Muhammad bin Aqeel', 'Maimoona Qasim', 'Aqeel Usman ']	.
# c301	Wednesday	14	16	CS221	Muhammad bin Qasim	['Bano', 'Sanaa Rassol', 'Shahzad Rashid']	.
# c305	Monday	10	10	CS218	Sanaa Ilyas	['Aqeel Usman ', 'Bano', 'Sanaa Rassol', 'Maimoona Qasim', 'Muhammad bin Aqeel', 'Shahzad Rashid']	.
# c306	Thursday	14	15	CS219	Aqeel Shahzad	['Sanaa Rassol', 'Aqeel Usman ', 'Muhammad bin Aqeel', '
# Current Mom fitness value: 1220
# Current Dad fitness value: 1220
# Best solution so far: 1480
# 0
#
# Current generation..: 100
# Current Mom fitness value: 1160
# Current Dad fitness value: 1110
# Best solution so far: 1480
# 1
#
# Current generation..: 150
# Current Mom fitness value: 1320
# Current Dad fitness value: 1320
# Best solution so far: 1480
# 2
# Sending heavenly assistance.
#
# Current generation..: 200
# Current Mom fitness value: 1260
# Current Dad fitness value: 1260
# Best solution so far: 1630
# 0
#
# Current generation..: 250
# Current Mom fitness value: 1300
# Current Dad fitness value: 1300
# Best solution so far: 1630
# 1
#
# Current generation..: 300
# Current Mom fitness value: 1510
# Current Dad fitness value: 1510
# Best solution so far: 1630
# 2
# Sending heavenly assistance.
#
# Current generation..: 350
# Current Mom fitness value: 1560
# Current Dad fitness value: 1520
# Best solution so far: 1630
# 3
# Sending heavenly assistance.
#
# Current generation..: 400
# Current Mom fitness value: 1320
# Current Dad fitness value: 1320
# Best solution so far: 1790
# 0
#
# Current generation..: 450
# Current Mom fitness value: 1100
# Current Dad fitness value: 1100
# Best solution so far: 1790
# 1
#
# Current generation..: 500
# Current Mom fitness value: 990
# Current Dad fitness value: 990
# Best solution so far: 1790
# 2
# Sending heavenly assistance.
#
# Current generation..: 550
# Current Mom fitness value: 1130
# Current Dad fitness value: 1130
# Best solution so far: 1910
# 0
#
# Current generation..: 600
# Current Mom fitness value: 1090
# Current Dad fitness value: 1090
# Best solution so far: 1910
# 1
#
# Current generation..: 650
# Current Mom fitness value: 1300
# Current Dad fitness value: 1300
# Best solution so far: 1910
# 2
# Sending heavenly assistance.
#
# Current generation..: 700
# Current Mom fitness value: 1940
# Current Dad fitness value: 1940
# Best solution so far: 2080
# 0
#
# Current generation..: 750
# Current Mom fitness value: 1610
# Current Dad fitness value: 1610
# Best solution so far: 2100
# 0
#
# Current generation..: 800
# Current Mom fitness value: 1170
# Current Dad fitness value: 1170
# Best solution so far: 2100
# 1
#
# Current generation..: 850
# Current Mom fitness value: 1210
# Current Dad fitness value: 1200
# Best solution so far: 2100
# 2
# Sending heavenly assistance.
#
# Current generation..: 900
# Current Mom fitness value: 1350
# Current Dad fitness value: 1270
# Best solution so far: 2100
# 3
# Sending heavenly assistance.
#
# Current generation..: 950
# Current Mom fitness value: 1300
# Current Dad fitness value: 1300
# Best solution so far: 2100
# 4
# Sending heavenly assistance.
#
#
#
# ========================= After 1000 iterations:
# Mom genes:
# c303	Wednesday	15	17	CS222	Muhammad bin Qasim	['Shahzad Rashid', 'Aqeel Usman ', 'Muhammad bin Aqeel', 'Sanaa Rassol']	.
# c306	Wednesday	15	15	CS221	Sanaa Ilyas	['Sanaa Rassol', 'Maimoona Qasim']	.
# c307	Saturday	16	16	CS221	Muhammad bin Qasim	['Muhammad bin Aqeel', 'Aqeel Usman ']	.
# c309	Saturday	9	12	CS220	Maimoona Rassol	['Bano', 'Aqeel Usman ', 'Shahzad Rashid', 'Sanaa Rassol', 'Maimoona Qasim', 'Muhammad bin Aqeel']	.
# c303	Wednesday	11	14	CS222	Muhammad bin Qasim	['Aqeel Usman ', 'Bano', 'Shahzad Rashid', 'Muhammad bin Aqeel']	.
#
 'Sanaa Rassol', 'Muhammad bin Aqeel']	.
# c303	Saturday	10	15	CS222	Usman Rashid	['Bano', 'Aqeel Usman ', 'Shahzad Rashid', 'Sanaa Rassol']	.
# c305	Friday	13	13	CS218	Usman Rashid	['Muhammad bin Aqeel', 'Shahzad Rashid', 'Bano', 'Sanaa Rassol', 'Maimoona Qasim']	.
# c306	Monday	16	16	CS218	Usman Rashid	['Muhammad bin Aqeel', 'Sanaa Rassol', 'Bano', 'Aqeel Usman ']	.
# Dad Fitness Value:  1380
#
#
# =================================------------======================================
# Our best solution is:
# c303	Wednesday	15	17	CS222	Muhammad bin Qasim	['Shahzad Rashid', 'Aqeel Usman ', 'Muhammad bin Aqeel', 'Sanaa Rassol']	.
# c301	Wednesday	10	11	CS220	Maimoona Rassol	['Maimoona Qasim', 'Shahzad Rashid', 'Bano']	.
# c307	Saturday	16	16	CS221	Muhammad bin Qasim	['Muhammad bin Aqeel', 'Aqeel Usman ']	.
# c309	Saturday	9	12	CS220	Maimoona Rassol	['Bano', 'Aqeel Usman ', 'Shahzad Rashid', 'Sanaa Rassol', 'Maimoona Qasim', 'Muhammad bin Aqeel']	.
# c306	Sunday	10	13	CS219	Aqeel Shahzad	['Sanaa Rassol', 'Aqeel Usman ', 'Muhammad bin Aqeel', 'Bano', 'Maimoona Qasim', 'Shahzad Rashid']	.
# c308	Thursday	13	14	CS218	Sanaa Ilyas	['Muhammad bin Aqeel', 'Bano']	.
# c310	Tuesday	16	17	CS219	Sanaa Ilyas	['Maimoona Qasim', 'Sanaa Rassol', 'Shahzad Rashid', 'Aqeel Usman ', 'Bano', 'Muhammad bin Aqeel']	.
# c304	Thursday	12	15	CS218	Sanaa Ilyas	['Muhammad bin Aqeel', 'Shahzad Rashid']	.
# c309	Sunday	11	14	CS219	Usman Rashid	['Sanaa Rassol', 'Muhammad bin Aqeel', 'Shahzad Rashid', 'Aqeel Usman ', 'Bano']	.
# c302	Tuesday	10	16	CS218	Aqeel Shahzad	['Aqeel Usman ', 'Shahzad Rashid', 'Muhammad bin Aqeel']	.
# c309	Wednesday	14	16	CS219	Muhammad bin Qasim	['Muhammad bin Aqeel', 'Maimoona Qasim']	.
# c301	Tuesday	9	13	CS222	Muhammad bin Qasim	['Sanaa Rassol']	.
# c308	Tuesday	17	17	CS220	Ayesha Bano	['Sanaa Rassol', 'Shahzad Rashid', 'Bano', 'Muhammad bin Aqeel', 'Maimoona Qasim', 'Aqeel Usman ']	.
# c310	Tuesday	16	16	CS219	Usman Rashid	['Bano', 'Sanaa Rassol', 'Maimoona Qasim']	.
# c301	Tuesday	16	16	CS217	Sanaa Ilyas	['Sanaa Rassol', 'Muhammad bin Aqeel', 'Shahzad Rashid', 'Aqeel Usman ', 'Maimoona Qasim', 'Bano']	.
# c309	Friday	11	14	CS221	Aqeel Shahzad	['Maimoona Qasim', 'Aqeel Usman ', 'Sanaa Rassol', 'Bano', 'Muhammad bin Aqeel']	.
# c309	Wednesday	11	13	CS220	Muhammad bin Qasim	['Maimoona Qasim', 'Muhammad bin Aqeel', 'Shahzad Rashid', 'Bano']	.
# c304	Thursday	12	12	CS222	Aqeel Shahzad	['Sanaa Rassol', 'Aqeel Usman ', 'Bano']	.
# c307	Monday	9	14	CS222	Sanaa Ilyas	['Bano', 'Sanaa Rassol', 'Muhammad bin Aqeel', 'Aqeel Usman ', 'Maimoona Qasim']	.
# c302	Monday	10	16	CS222	Muhammad bin Qasim	['Muhammad bin Aqeel', 'Sanaa Rassol', 'Bano']	.
# c305	Friday	9	12	CS218	Muhammad bin Qasim	['Aqeel Usman ', 'Muhammad bin Aqeel', 'Bano', 'Maimoona Qasim']	.
# c307	Monday	16	16	CS218	Sanaa Ilyas	['Muhammad bin Aqeel', 'Bano']	.
# c308	Tuesday	11	11	CS222	Aqeel Shahzad	['Maimoona Qasim', 'Shahzad Rashid', 'Aqeel Usman ', 'Sanaa Rassol', 'Muhammad bin Aqeel', '