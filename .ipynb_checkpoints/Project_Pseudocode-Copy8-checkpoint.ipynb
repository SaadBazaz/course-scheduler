# %%
import random
import pandas as pd
import numpy as np
import copy
import matplotlib as plt

"Hello world"
# Out:
# 'Hello world'

# %% [markdown]
# # Data Models

# %%
# =======================  INSERT STUDENTS INTO DATAFRAME
student_file = pd.read_csv('studentNames.csv', header=None)
student_file.reset_index(drop=True, inplace=True)
print(student_file)

print("THIS IS ONE STUDENT:", student_file[0][1])

# =======================  INSERT COURSES INTO DATAFRAME
course_file = pd.read_csv('courses.csv', header=None)
print(course_file)

# =======================  INSERT STUDENT COURSES INTO DATAFRAME
student_course_file = pd.read_csv('studentCourse.csv')
print(student_course_file)

# =======================  INSERT TEACHERS INTO DATAFRAME
teacher_file = pd.read_csv('teachers.csv', header=None)
print(teacher_file)

## Construct a valid input here (according to what we need)

# Structure (Bottom-Up):
#        1. Gene : Contains 1 course, 1 instructor , and an array of Students, It's corresponding Day (mon, tue, wed ...) ,
#                  It's corresponding Time (9-12, 10-1 ...).
#        2. Chromosome: Contains a classroom , TimeTable for the classroom , fitness value of the generated Timetable
#        3. Member: Contains a list of chromosomes
#        4. Population:  Contains a list of members


# initialise population

Classrooms_Array = ['c301', 'c302', 'c303', 'c304', 'c305', 'c306', 'c307', 'c308', 'c309', 'c310']

Courses_Array = list(course_file[0])

print ("Reached here")

Instructors_Array = list(teacher_file[0])

# Students_Array = ['Bano','Aqeel Usman ','Shahzad Rashid','Maimoona Qasim','Muhammad bin Aqeel','Sanaa Rassol']

Students_Array = list(student_file[0])
student_courses = []


print(student_courses)
print('Printing students array')
print(Students_Array)

Days_Array = [
    #               'Sunday',
    'Monday',
    'Tuesday',
    'Wednesday',
    'Thursday',
    'Friday',
    #               'Saturday',
]

num_of_days_in_week = len(Days_Array)

Days_ID_Array = [
    #     0,
    0,
    1,
    2,
    3,
    4,
    #     6
]



def change_fundamentals():
    """'And (remember) as your Lord said to the Angels, "Surely I am making in the earth a successor." They said, "Will You make therein one who will corrupt in it and shed blood (Literally: bloods) while we (are the ones who) extol (with) Your praise and call You Holy? Literally: hallow for you)" He said, "Surely I know whatever you do not know."'"""
    
    next_day = Days_Array[(Days_ID_Array[-1] + 1)%num_of_days_in_week]
    
    # Increase days
    Days_ID_Array.append(Days_ID_Array[-1] + 1)
    Days_Array.append(next_day)  


class Course:
    def __init__(self, id, name):
        self.id = id
        self.name = name


class Instructor:
    def __init__(self, name):
        self.name = name


class Student:
    def __init__(self, name):
        self.name = name


class Classroom:
    def __init__(self, id, capacity):
        self.id = id
        self.capacity = capacity


class Student_Course:
    def __init__(self, course, student):
        self.course = course
        self.student_id = student
# Out:
#                      0
# 0        Mohammed Azam
# 1    Mohamed F Bakaram
# 2      Manal Aldaihani
# 3        Ibrar Manawer
# 4         Adam Flowers
# ..                 ...
# 195     Naveed Hussain
# 196      Sarah L Clark
# 197       Maria Lytras
# 198        Bibi A Khan
# 199       Iram Matloob
#
# [200 rows x 1 columns]
# THIS IS ONE STUDENT: Mohamed F Bakaram
#          0                                            1
# 0    CS217                  Object Oriented Programming
# 1    EE227                         Digital Logic Design
# 2    CS211                          Discrete Structures
# 3    SE110                Intro to Software Engineering
# 4    CS118                     Programming Fundamentals
# 5    CS219                             Database Systems
# 6    CS220                            Operating Systems
# 7    CS302              Design & Analysis of Algorithms
# 8   CY2012                            Digital Forensics
# 9    CS307                            Computer Networks
# 10   CS328                         Software Engineering
# 11   EE229  Computer Organization and Assembly Language
# 12  AI2011                           Programming for AI
# 13  DS3011                           Big Data Analytics
# 14   CS328                         Software Engineering
# 15   CS218                              Data Structures
# 16   EE229    Computer Organization & Assembly Language
# 17   CS211                          Discrete Structures
# 18   MT224                       Differential Equations
# 19   SS113                             Pakistan Studies
# 20   MG220                         Marketing Management
# 21   MG223                   Fundamentals of Management
# 22   SS111                Islamic and Religious Studies
# 23   SS152          Communication & Presentation Skills
# 24   SS118                                   Psychology
# 25   MT205                   Probability and Statistics
#      Unnamed: 0                  StudentName CourseCode
# 0             0                Sam D Edwards     AI2011
# 1             1               Sheila Hughton     DS3011
# 2             2                 Yasmin Ahmed      SE110
# 3             3  Sarah N Md Sallehuddin Khan      EE229
# 4             4                Sarah Nolasco     AI2011
# ..          ...                          ...        ...
# 815         815                    Adam Kirk     DS3011
# 816         816                Tara Glickman      SS111
# 817         817                Nina N Wronka      CS218
# 818         818                 Sonia V Diaz      MG220
# 819         819                 Sarah Wilson      MT224
#
# [820 rows x 3 columns]
#                  0
# 0      Ayesha Bano
# 1    Aqeel Shahzad
# 2        Farah Naz
# 3       Hamda Khan
# 4     Usman Rashid
# ..             ...
# 58    Kashif Munir
# 59   Hammad Majeed
# 60    Noreen Jamil
# 61  Hassan Mustafa
# 62    Farwa Batool
#
# [63 rows x 1 columns]
# Reached here
# []
# Printing students array
# ['Mohammed Azam', 'Mohamed F Bakaram', 'Manal Aldaihani', 'Ibrar Manawer', 'Adam Flowers', 'Lilia Kyuchukova', 'Sarina Patel', 'Aleena Unadkat', 'Ibrahim Adegboye', 'Salma Khanam', 'Kiran K Chahal', 'Omar F Khan', 'Seema Mandalia', 'Asim Ali', 'Yasmin Ahmed', 'Sheila Hughton', 'Sarah Taylor', 'Anja Sarlah', 'Syed M Abbas', 'Hanna I Siahaan', 'Sarah Austin', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Halima Sayed', 'Sarah L Barber-Jones', 'Meryem Mehmetbasoglu', 'Adam L Finch', 'Sarah Hanley', 'Sarah Fogg', 'Tara Glickman', 'Reem N Hassan', 'Amir Ahmed', 'Sarah French', 'Sarah J Roberts', 'Sam D Edwards', 'Sam Duncanson', 'Amber Summerfield', 'Mika Tatsumoto', 'Maria Antonia Morua Leyva', 'Ann D Brix', 'Jina Zhao', 'Zahir Hussain', 'Syed M Ghufran', 'Adam C Ryan', 'Adam Sanders', 'Mohamed A Baalousha', 'Naseem Akram', 'Ann Tai', 'Ann White', 'Sarah Wilson', 'Judi Glen', 'Ayan Lowe', 'Sarah Montgomery', 'Meltem Naylor', 'Damian A Cummings', 'Maria A Grenfell', 'Nabila Altaf', 'Sarah Nolasco', 'Mohammed A Suleman', 'Hazimah H Hj Hamzah', 'Farzana Yamin', 'Sonia V Diaz', 'Huda O Ali', 'Parastoo Jamshidi', 'Arsheen Rajpar', 'Nausheen Saleem', 'Ana Vukojevic', 'Sajida Ayub', 'Sam Dalgleish', 'Shahzada S Niwaz', 'Sam J Pottier', 'Sarah Armstrong', 'Sarah J Bradford', 'Natasha J Seaward', 'Leila C Payne', 'Shari K Rasmussen', 'Kabir A Khan', 'Nadia Parveen', 'Leanne M Taylor-Smith', 'Jasmine Winyard', 'Mohammed Zafran', 'Natasha Leeson', 'Natasha Lelijveld', 'Sarah E Kirkham-Slack', 'Sarah N Md Sallehuddin Khan', 'Adam Green', 'Siraj Shariff', 'Saleem Abubacker', 'Tina Nasersharif', 'Soha Siahpoosh Kolyaei', 'Ali M Sadeghioon', 'Zahra Faraji Rad', 'Ayda Niazi', 'Shadan Mirarmandehi', 'Behzad Babakhani', 'Sadra Keyhani', 'Maryam Askari Louyeh', 'Usman Rafiq', 'Aidan P Murphy', 'Sagar R Jilka', 'Babak Cheraghchi Bashi Astaneh', 'Hamza Bin Muhammad', 'Arman N Bahadori', 'Sonia Zain', 'Yasir M Salih', 'Yaser A Aljammaz', 'Salwa S Alobaid', 'Samar E Nassar', 'Shahid Khan', 'Shahina Parveen', 'Nina N Wronka', 'Mohammad Abir', 'Zeenat K Guness-Goolbar', 'Faheema Korumtollee', 'Shireen Dowlut-Beebeejaun', 'Ameerah Kasenally-Boodoo', 'Maysa Saeidi', 'Maria M Ponce Carpio', 'Adam Kirk', 'Mohammed Sukkari', 'Adam Selby', 'Natasha Tait', 'Jenna Riley', 'Adam N Starling', 'Dean Brodesky', 'Sara Zamberlan', 'Mohammed I Al Arfaj', 'Selina V Penarski', 'Sarah H Przybylak', 'Sadia Rehman', 'Sarah R Young', 'Sarah S Shahid', 'Arooba Zahoor', 'Irfan Yousaf', 'Omar Chaudhrey', 'Anita Hodler', 'Marwa Elcheikh', 'Shadan Alam', 'Yas Khaled', 'Kamila Houdkova', 'Zainab Khattak', 'Ana B Javier Cuetos', 'Nadine Meyer', 'Eileen Harris', 'Jan Fiala', 'Sarah Hewitt', 'Sarah Clements', 'Samina Akbar', 'Zaki Choudhury', 'Sam Isherwood', 'Anja Brezovnik', 'Natasha Edwards', 'Adam Mickiewicz', 'Nosheen Maqbool', 'Dalia Remeikyte', 'Rida Shaikh', 'Rafal Szczypinski', 'Kamal Anwar', 'Hassana Begum', 'Sarah Dobson', 'Ann Wilson', 'Bushra Duri', 'Sarah Hinett', 'Eileen Haycox', 'Bahjat Al-Ani', 'Ramesh R Singh', 'Sarah J Hammon', 'Kamila Keshubay', 'Mohammed Z Albahar', 'Salman Hassan Zadeh', 'Razan Z Haji Zulkifli', 'Aras Panahian Jand', 'Leyla Doroudi', 'Sara De La Serna', 'Negar Saleh', 'Nima Dirie', 'Ana Sbert Ortin', 'Omar S Aslam', 'Imtiaz Kermali', 'Safiya Issa', 'Faris Quaid', 'Muna Osman', 'Farzad Farahmand', 'Iram Meharban', 'Sarah Hadley', 'Ahmad F Yang Abd Talib', 'Sarwar Hussain', 'Mona Vadher', 'Ayse Hatunoglu', 'Faraj B Shaban', 'Ayman Jaheen', 'Abdul Gafur', 'Ahmed Ahmed', 'Aida Hoxha', 'Muhammad Ijaz-Ul-Haq', 'Ahmed Abbas Ahmed', 'Naveed Hussain', 'Sarah L Clark', 'Maria Lytras', 'Bibi A Khan', 'Iram Matloob']

# %% [markdown]
# # Population Model

# %%
class Gene:
    def __init__(
            self,
            course=None,
            instructor=None,
            students=None,
            day=None,
            start_time=None,
            end_time=None,
            classroom_name=None,
    ):

        if course is None:
            course = Courses_Array[random.randint(0, len(Courses_Array) - 1)]

        if instructor is None:
            instructor = random.randint(0, len(Instructors_Array) - 1)

        if students is None:
            std_list = []
            for i in range(1, 30):
                L = random.randint(1, len(Students_Array) - 1)
                std_list.append(L)
            students = np.array(std_list)
        #             print ("STUDENTS ARE", students)
        #
        if day is None:
            day = Days_ID_Array[random.randint(0, len(Days_ID_Array) - 1)]

        if start_time is None:
            start_time = random.randint(9.0, 17.0 - 3)

        if end_time is None:
            ## Logical way is to start this range from start_time
            end_time = start_time + 3

        if classroom_name is None:
            classroom_name = Classrooms_Array[random.randint(0, len(Classrooms_Array) - 1)]

        self.course = course
        self.instructor = instructor
        self.students = students
        self.day = day
        self.start_time = start_time
        self.end_time = end_time
        self.classroom_name = classroom_name

    def __str__(self):

        student_names = []
        for student in self.students:
            student_names.append(Students_Array[int(student)])

#         print('Day in number is: ', self.day)
        temp_day_name = Days_Array[self.day]
    
    
        instructor_name = Instructors_Array[self.instructor]

        return (
                self.classroom_name + "\t" +
                temp_day_name + "\t" +
                str(self.start_time) + "\t" +
                str(self.end_time) + "\t" +
                self.course + "\t" +
                instructor_name + "\t\n" +
                str(student_names) + "\t" +
                "."
        )


class Chromosome:

    def __init__(self,
                 genes=None,
                 fitness_value=None,
                 ):

        if genes is None:
            genes = []
            for i in range(0, random.randint(30, 50)):
                genes.append(Gene())

        if fitness_value is None:
            fitness_value = 0

        self.genes = np.array(genes)

        self.fitness_value = fitness_value

    def __getitem__(self, index):
        return self.genes[index]


class Population:

    def __init__(self,
                 chromosomes=None
                 ):

        if chromosomes is None:
            chromosomes = []
            for i in range(1, 20):
                chromosomes.append(Chromosome())

        self.chromosomes = np.array(chromosomes)

    def __getitem__(self, index):
        return self.chromosomes[index]

# %% [markdown]
# # Initialization

# %%
def initialize_population():
    new_population = Population()

    #     ----------------------------------------------- Debugging
    #     for member in new_population.members:
    #         for chromosome in member.chromosomes:
    #             for gene in chromosome.genes:
    #                 print (gene.course,gene.instructor,gene.students,gene.day,gene.start_time,gene.end_time)
    #     ----------------------------------------------- Debugging

    return new_population

# %%
new_pop = initialize_population()

for chromosome in new_pop:
#         print("\n\nCLASSROOM:", chromosome.classroom_name)
    sort_by_day = sorted(chromosome, key=lambda gene: (gene.day, gene.start_time) )
    for gene in sort_by_day:
        print(gene)
# Out:
# c302	Monday	9	12	CS219	Adnan Tariq
# ['Sarah Wilson', 'Salwa S Alobaid', 'Sarah L Clark', 'Mohamed F Bakaram', 'Jasmine Winyard', 'Leanne M Taylor-Smith', 'Adam Mickiewicz', 'Naseem Akram', 'Sadia Rehman', 'Manal Aldaihani', 'Kamila Keshubay', 'Mohammed Z Albahar', 'Farzad Farahmand', 'Farzana Yamin', 'Maysa Saeidi', 'Ana Sbert Ortin', 'Damian A Cummings', 'Yas Khaled', 'Sarwar Hussain', 'Anja Brezovnik', 'Mona Vadher', 'Eileen Harris', 'Sarah Austin', 'Parastoo Jamshidi', 'Siraj Shariff', 'Naseem Akram', 'Arman N Bahadori', 'Reem N Hassan', 'Zahra Faraji Rad']	.
# c310	Monday	11	14	CS118	Shehreyar Rashid
# ['Adam Kirk', 'Samar E Nassar', 'Mohammed A Suleman', 'Mona Vadher', 'Sarah Hinett', 'Zainab Khattak', 'Shahzada S Niwaz', 'Sarina Patel', 'Bibi A Khan', 'Natasha J Seaward', 'Faris Quaid', 'Syed M Ghufran', 'Sarah Hadley', 'Bibi A Khan', 'Adam L Finch', 'Ana B Javier Cuetos', 'Lilia Kyuchukova', 'Aida Hoxha', 'Sam Duncanson', 'Nosheen Maqbool', 'Reem N Hassan', 'Sarah L Barber-Jones', 'Safiya Issa', 'Dalia Remeikyte', 'Farzad Farahmand', 'Mohammed Zafran', 'Sarah J Bradford', 'Usman Rafiq', 'Shari K Rasmussen']	.
# c305	Monday	12	15	EE227	Mehwish Hassan
# ['Salma Khanam', 'Sarah Montgomery', 'Bushra Duri', 'Maria A Grenfell', 'Hanna I Siahaan', 'Dean Brodesky', 'Ahmed Abbas Ahmed', 'Soha Siahpoosh Kolyaei', 'Mohammed A Suleman', 'Nabila Altaf', 'Huda O Ali', 'Amber Summerfield', 'Ann White', 'Mohammed Z Albahar', 'Iram Matloob', 'Shahzada S Niwaz', 'Sarah Montgomery', 'Jina Zhao', 'Nausheen Saleem', 'Asim Ali', 'Asim Ali', 'Sarah Nolasco', 'Hassana Begum', 'Shahid Khan', 'Sarah Hinett', 'Halima Sayed', 'Ramesh R Singh', 'Jenna Riley', 'Dean Brodesky']	.
# c305	Monday	13	16	EE229	Faisal Cheema
# ['Kamal Anwar', 'Sam J Pottier', 'Mohammed A Suleman', 'Zeenat K Guness-Goolbar', 'Shadan Mirarmandehi', 'Ayda Niazi', 'Zahir Hussain', 'Ana Sbert Ortin', 'Jina Zhao', 'Arooba Zahoor', 'Reem N Hassan', 'Dalia Remeikyte', 'Jan Fiala', 'Ayda Niazi', 'Maria M Ponce Carpio', 'Negar Saleh', 'Kamila Keshubay', 'Abdul Gafur', 'Faraj B Shaban', 'Aidan P Murphy', 'Zahra Faraji Rad', 'Mohammad Abir', 'Ibrahim Adegboye', 'Faraj B Shaban', 'Hazimah H Hj Hamzah', 'Ann Wilson', 'Eileen Haycox', 'Naveed Hussain', 'Natasha Edwards']	.
# c301	Monday	14	17	MG220	Noreen Jamil
# ['Sarah Taylor', 'Usman Rafiq', 'Sarah J Bradford', 'Sonia Zain', 'Selina V Penarski', 'Sarah L Clark', 'Ahmed Abbas Ahmed', 'Mohammed Z Albahar', 'Salman Hassan Zadeh', 'Jina Zhao', 'Mohammed A Suleman', 'Jenna Riley', 'Nabila Altaf', 'Abdul Gafur', 'Sarah Taylor', 'Ahmed Abbas Ahmed', 'Adam Green', 'Sonia V Diaz', 'Salwa S Alobaid', 'Omar Chaudhrey', 'Mohamed F Bakaram', 'Hazimah H Hj Hamzah', 'Siraj Shariff', 'Maria Antonia Morua Leyva', 'Shireen Dowlut-Beebeejaun', 'Omar Chaudhrey', 'Eileen Harris', 'Nosheen Maqbool', 'Shadan Mirarmandehi']	.
# c310	Monday	14	17	CS302	Adnan Tariq
# ['Jasmine Winyard', 'Mona Vadher', 'Yasir M Salih', 'Sagar R Jilka', 'Zainab Khattak', 'Muna Osman', 'Samina Akbar', 'Anja Brezovnik', 'Sam J Pottier', 'Sarah N Md Sallehuddin Khan', 'Jina Zhao', 'Muhammad Ijaz-Ul-Haq', 'Samar E Nassar', 'Samar E Nassar', 'Meltem Naylor', 'Samar E Nassar', 'Iram Matloob', 'Adam C Ryan', 'Ann Tai', 'Sarah J Roberts', 'Ayan Lowe', 'Manal Aldaihani', 'Ana Vukojevic', 'Imtiaz Kermali', 'Nadine Meyer', 'Kiran K Chahal', 'Behzad Babakhani', 'Maryam Askari Louyeh', 'Eileen Haycox']	.
# c301	Tuesday	9	12	MT205	Shehreyar Rashid
# ['Maria A Grenfell', 'Sarah Hanley', 'Dalia Remeikyte', 'Sarah Dobson', 'Amber Summerfield', 'Dalia Remeikyte', 'Aidan P Murphy', 'Babak Cheraghchi Bashi Astaneh', 'Sarah Montgomery', 'Meryem Mehmetbasoglu', 'Sarina Patel', 'Hazimah H Hj Hamzah', 'Sadia Rehman', 'Mohammed Zafran', 'Aida Hoxha', 'Manal Aldaihani', 'Natasha Leeson', 'Anja Sarlah', 'Samina Akbar', 'Yaser A Aljammaz', 'Sonia V Diaz', 'Faris Quaid', 'Jan Fiala', 'Sonia Zain', 'Yaser A Aljammaz', 'Sarah Hanley', 'Maria A Grenfell', 'Sarah Montgomery', 'Halima Sayed']	.
# c309	Tuesday	11	14	SS118	Adnan Tariq
# ['Sadia Rehman', 'Amir Ahmed', 'Ayan Lowe', 'Tara Glickman', 'Amber Summerfield', 'Rida Shaikh', 'Iram Matloob', 'Syed M Ghufran', 'Mohammed A Suleman', 'Sam D Edwards', 'Sarina Patel', 'Sarina Patel', 'Mohammed Z Albahar', 'Sarah Taylor', 'Maria A Grenfell', 'Anja Brezovnik', 'Parastoo Jamshidi', 'Sajida Ayub', 'Abdul Gafur', 'Nabila Altaf', 'Yaser A Aljammaz', 'Sarah E Kirkham-Slack', 'Asim Ali', 'Maria M Ponce Carpio', 'Sarah French', 'Sarah Hinett', 'Farzana Yamin', 'Sarah Hinett', 'Adam Mickiewicz']	.
# c304	Tuesday	14	17	EE229	Hassan Mustafa
# ['Nabila Altaf', 'Adam L Finch', 'Bushra Duri', 'Syed M Abbas', 'Nima Dirie', 'Iram Matloob', 'Amir Ahmed', 'Ana Vukojevic', 'Razan Z Haji Zulkifli', 'Dalia Remeikyte', 'Leyla Doroudi', 'Nabila Altaf', 'Bushra Duri', 'Usman Rafiq', 'Sarah L Barber-Jones', 'Sarah Hanley', 'Natasha Edwards', 'Natasha J Seaward', 'Adam Flowers', 'Selina V Penarski', 'Omar S Aslam', 'Yasir M Salih', 'Reem N Hassan', 'Rafal Szczypinski', 'Sarah R Young', 'Zaki Choudhury', 'Safiya Issa', 'Mohammed Z Albahar', 'Anita Hodler']	.
# c304	Wednesday	9	12	CS307	Hassan Mustafa
# ['Ibrahim Adegboye', 'Marwa Elcheikh', 'Natasha Tait', 'Sarah N Md Sallehuddin Khan', 'Ali M Sadeghioon', 'Zahra Faraji Rad', 'Arman N Bahadori', 'Shahid Khan', 'Kamila Keshubay', 'Adam Selby', 'Parastoo Jamshidi', 'Soha Siahpoosh Kolyaei', 'Sarah Wilson', 'Aida Hoxha', 'Sarah Hewitt', 'Ahmed Abbas Ahmed', 'Sarah E Kirkham-Slack', 'Meryem Mehmetbasoglu', 'Natasha Edwards', 'Sonia V Diaz', 'Siraj Shariff', 'Behzad Babakhani', 'Adam Mickiewicz', 'Omar S Aslam', 'Maria M Ponce Carpio', 'Omar Chaudhrey', 'Adam N Starling', 'Naveed Hussain', 'Salwa S Alobaid']	.
# c310	Wednesday	10	13	CS220	Sara Aziz
# ['Shadan Alam', 'Halima Sayed', 'Dean Brodesky', 'Ayan Lowe', 'Aleena Unadkat', 'Natasha Edwards', 'Mona Vadher', 'Mohammed A Suleman', 'Arman N Bahadori', 'Zahra Faraji Rad', 'Sarah Dobson', 'Ahmad F Yang Abd Talib', 'Sarah L Barber-Jones', 'Adam Selby', 'Dean Brodesky', 'Hazimah H Hj Hamzah', 'Farzad Farahmand', 'Sarah R Young', 'Shadan Mirarmandehi', 'Anja Brezovnik', 'Jina Zhao', 'Selina V Penarski', 'Hassana Begum', 'Sarah Montgomery', 'Jan Fiala', 'Meltem Naylor', 'Sagar R Jilka', 'Sarah Hadley', 'Ana Vukojevic']	.
# c303	Wednesday	10	13	MT224	Mehboobullah
# ['Rida Shaikh', 'Bushra Duri', 'Ann D Brix', 'Natasha J Seaward', 'Maria A Grenfell', 'Sarah H Przybylak', 'Siraj Shariff', 'Iram Meharban', 'Saleem Abubacker', 'Rafal Szczypinski', 'Reem N Hassan', 'Zahir Hussain', 'Ann D Brix', 'Arooba Zahoor', 'Leyla Doroudi', 'Natasha Tait', 'Rida Shaikh', 'Ahmad F Yang Abd Talib', 'Arman N Bahadori', 'Sarah J Bradford', 'Farzad Farahmand', 'Bahjat Al-Ani', 'Iram Matloob', 'Farzad Farahmand', 'Anita Hodler', 'Mika Tatsumoto', 'Yasir M Salih', 'Sarah Austin', 'Maria M Ponce Carpio']	.
# c309	Wednesday	10	13	AI2011	Shehreyar Rashid
# ['Sarah Hanley', 'Sara De La Serna', 'Reem N Hassan', 'Razan Z Haji Zulkifli', 'Natasha Lelijveld', 'Natasha Tait', 'Parastoo Jamshidi', 'Leanne M Taylor-Smith', 'Nadia Parveen', 'Tara Glickman', 'Shireen Dowlut-Beebeejaun', 'Sarah J Roberts', 'Kamal Anwar', 'Natasha Tait', 'Mohammad Abir', 'Asim Ali', 'Sadia Rehman', 'Ahmed Abbas Ahmed', 'Nausheen Saleem', 'Yasmin Ahmed', 'Anita Hodler', 'Kabir A Khan', 'Salman Hassan Zadeh', 'Sarah J Hammon', 'Ayse Hatunoglu', 'Manal Aldaihani', 'Maysa Saeidi', 'Mohammed A Suleman', 'Farzad Farahmand']	.
# c309	Wednesday	12	15	MT205	Kifayat Ullah
# ['Kabir A Khan', 'Zeenat K Guness-Goolbar', 'Seema Mandalia', 'Sagar R Jilka', 'Faheema Korumtollee', 'Zainab Khattak', 'Hazimah H Hj Hamzah', 'Sadra Keyhani', 'Ana Vukojevic', 'Ibrar Manawer', 'Sam Dalgleish', 'Sarah J Roberts', 'Adam N Starling', 'Farzana Yamin', 'Hazimah H Hj Hamzah', 'Sonia V Diaz', 'Babak Cheraghchi Bashi Astaneh', 'Iram Meharban', 'Shahid Khan', 'Zeenat K Guness-Goolbar', 'Naveed Hussain', 'Abdul Gafur', 'Natasha Leeson', 'Natasha J Seaward', 'Zahra Faraji Rad', 'Samar E Nassar', 'Sagar R Jilka', 'Maysa Saeidi', 'Rida Shaikh']	.
# c305	Wednesday	13	16	EE227	Hassan Raza
# ['Hassana Begum', 'Leyla Doroudi', 'Razan Z Haji Zulkifli', 'Marwa Elcheikh', 'Ayman Jaheen', 'Yasmin Ahmed', 'Zeenat K Guness-Goolbar', 'Maysa Saeidi', 'Shadan Mirarmandehi', 'Iram Matloob', 'Aidan P Murphy', 'Yas Khaled', 'Kamila Keshubay', 'Salma Khanam', 'Adam Sanders', 'Eileen Harris', 'Huda O Ali', 'Omar Chaudhrey', 'Sara De La Serna', 'Omar S Aslam', 'Kabir A Khan', 'Sarah Nolasco', 'Muna Osman', 'Asim Ali', 'Sam Dalgleish', 'Aleena Unadkat', 'Adam L Finch', 'Amber Summerfield', 'Seema Mandalia']	.
# c305	Wednesday	14	17	CY2012	Khadija Farooq
# ['Adam Mickiewicz', 'Jina Zhao', 'Nina N Wronka', 'Manal Aldaihani', 'Mohammed Z Albahar', 'Rida Shaikh', 'Mohamed F Bakaram', 'Ayan Lowe', 'Hazimah H Hj Hamzah', 'Huda O Ali', 'Leila C Payne', 'Abdul Gafur', 'Faris Quaid', 'Aidan P Murphy', 'Ana Sbert Ortin', 'Sarah S Shahid', 'Arman N Bahadori', 'Hanna I Siahaan', 'Yas Khaled', 'Salman Hassan Zadeh', 'Sajida Ayub', 'Syed M Abbas', 'Marwa Elcheikh', 'Shahid Khan', 'Zahir Hussain', 'Sarah J Hammon', 'Kamal Anwar', 'Mohammad Abir', 'Kiran K Chahal']	.
# c310	Wednesday	14	17	CS219	Ayesha Bano
# ['Jasmine Winyard', 'Shadan Alam', 'Faris Quaid', 'Soha Siahpoosh Kolyaei', 'Manal Aldaihani', 'Ibrar Manawer', 'Sarah E Kirkham-Slack', 'Aida Hoxha', 'Sarah R Young', 'Adam L Finch', 'Jina Zhao', 'Huda O Ali', 'Sarah Clements', 'Sarah Austin', 'Yasmin Ahmed', 'Leanne M Taylor-Smith', 'Zeenat K Guness-Goolbar', 'Natasha Tait', 'Sarah Hewitt', 'Reem N Hassan', 'Nadine Meyer', 'Aras Panahian Jand', 'Marwa Elcheikh', 'Sarah E Kirkham-Slack', 'Anja Brezovnik', 'Bahjat Al-Ani', 'Mohamed A Baalousha', 'Faheema Korumtollee', 'Maria Antonia Morua Leyva']	.
# c307	Thursday	9	12	EE227	Zeeshan Qaiser
# ['Kiran K Chahal', 'Rida Shaikh', 'Asim Ali', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sarah J Roberts', 'Mohamed A Baalousha', 'Anja Sarlah', 'Rida Shaikh', 'Mona Vadher', 'Ibrahim Adegboye', 'Muna Osman', 'Iram Meharban', 'Sonia Zain', 'Jasmine Winyard', 'Damian A Cummings', 'Zeenat K Guness-Goolbar', 'Sarah Hinett', 'Imtiaz Kermali', 'Selina V Penarski', 'Iram Meharban', 'Ramesh R Singh', 'Syed M Ghufran', 'Jasmine Winyard', 'Jenna Riley', 'Jasmine Winyard', 'Sonia V Diaz', 'Sarah Hanley', 'Arman N Bahadori', 'Ibrahim Adegboye']	.
# c307	Thursday	9	12	SS111	Farah Jabeen Awan
# ['Bushra Duri', 'Adam Green', 'Salwa S Alobaid', 'Mika Tatsumoto', 'Mohammed Z Albahar', 'Leyla Doroudi', 'Yas Khaled', 'Hanna I Siahaan', 'Yasir M Salih', 'Ayda Niazi', 'Sam Isherwood', 'Sam D Edwards', 'Judi Glen', 'Adam Sanders', 'Adam C Ryan', 'Irfan Yousaf', 'Sam Isherwood', 'Sam Dalgleish', 'Adam C Ryan', 'Eileen Haycox', 'Sarah Dobson', 'Salwa S Alobaid', 'Kabir A Khan', 'Mohammed Zafran', 'Maryam Askari Louyeh', 'Sajida Ayub', 'Natasha Leeson', 'Faheema Korumtollee', 'Mohammed I Al Arfaj']	.
# c307	Thursday	10	13	MT224	Zohaib Iqbal
# ['Sam Duncanson', 'Sara De La Serna', 'Ramesh R Singh', 'Sarah J Roberts', 'Parastoo Jamshidi', 'Ramesh R Singh', 'Sarah J Bradford', 'Nina N Wronka', 'Mohamed A Baalousha', 'Negar Saleh', 'Natasha Edwards', 'Shireen Dowlut-Beebeejaun', 'Mohammed Sukkari', 'Eileen Harris', 'Ann Wilson', 'Maria Antonia Morua Leyva', 'Ibrar Manawer', 'Ayan Lowe', 'Seema Mandalia', 'Safiya Issa', 'Kabir A Khan', 'Sarah Nolasco', 'Huda O Ali', 'Muhammad Ijaz-Ul-Haq', 'Nima Dirie', 'Ayda Niazi', 'Adam L Finch', 'Shari K Rasmussen', 'Sarah Nolasco']	.
# c307	Thursday	10	13	CS218	Shahzad Mehmood
# ['Iram Matloob', 'Irfan Yousaf', 'Sam J Pottier', 'Anja Sarlah', 'Syed M Abbas', 'Sarah Hinett', 'Asim Ali', 'Jina Zhao', 'Lilia Kyuchukova', 'Anja Brezovnik', 'Bushra Duri', 'Kamila Houdkova', 'Jina Zhao', 'Aleena Unadkat', 'Faris Quaid', 'Manal Aldaihani', 'Sarah Fogg', 'Sarah J Bradford', 'Sheila Hughton', 'Shahid Khan', 'Maria Antonia Morua Leyva', 'Jenna Riley', 'Anja Sarlah', 'Aras Panahian Jand', 'Zahir Hussain', 'Rida Shaikh', 'Shari K Rasmussen', 'Aleena Unadkat', 'Hazimah H Hj Hamzah']	.
# c307	Thursday	13	16	CS211	Nagina Safdar
# ['Irfan Yousaf', 'Syed M Abbas', 'Aidan P Murphy', 'Iram Matloob', 'Maryam Askari Louyeh', 'Ibrahim Adegboye', 'Anita Hodler', 'Negar Saleh', 'Parastoo Jamshidi', 'Naveed Hussain', 'Damian A Cummings', 'Jina Zhao', 'Ibrahim Adegboye', 'Adam N Starling', 'Nausheen Saleem', 'Maryam Askari Louyeh', 'Marwa Elcheikh', 'Maria Antonia Morua Leyva', 'Ibrar Manawer', 'Mohammed A Suleman', 'Adam C Ryan', 'Imtiaz Kermali', 'Adam Kirk', 'Hamza Bin Muhammad', 'Yasmin Ahmed', 'Sagar R Jilka', 'Natasha Edwards', 'Damian A Cummings', 'Samina Akbar']	.
# c301	Thursday	13	16	CS307	Shoaib Mehboob
# ['Manal Aldaihani', 'Safiya Issa', 'Ann Tai', 'Hanna I Siahaan', 'Shadan Alam', 'Maria A Grenfell', 'Ann Tai', 'Zeenat K Guness-Goolbar', 'Maria Antonia Morua Leyva', 'Dalia Remeikyte', 'Adam Flowers', 'Leila C Payne', 'Sarah L Clark', 'Abdul Gafur', 'Manal Aldaihani', 'Sarah J Bradford', 'Sarah Austin', 'Tara Glickman', 'Adam C Ryan', 'Shadan Alam', 'Bahjat Al-Ani', 'Kiran K Chahal', 'Shahina Parveen', 'Seema Mandalia', 'Sarah Armstrong', 'Safiya Issa', 'Amir Ahmed', 'Hamza Bin Muhammad', 'Mohammed Z Albahar']	.
# c304	Thursday	13	16	CS118	Naveed Ahmad
# ['Adam Flowers', 'Ann Wilson', 'Muna Osman', 'Faraj B Shaban', 'Arsheen Rajpar', 'Sarah Wilson', 'Kabir A Khan', 'Syed M Ghufran', 'Sarah Austin', 'Mohamed A Baalousha', 'Mohammed I Al Arfaj', 'Safiya Issa', 'Bushra Duri', 'Ana B Javier Cuetos', 'Adam Kirk', 'Mohammed A Suleman', 'Muhammad Ijaz-Ul-Haq', 'Marwa Elcheikh', 'Hazimah H Hj Hamzah', 'Iram Matloob', 'Dalia Remeikyte', 'Usman Rafiq', 'Adam C Ryan', 'Iram Matloob', 'Jan Fiala', 'Soha Siahpoosh Kolyaei', 'Hassana Begum', 'Nadia Parveen', 'Salman Hassan Zadeh']	.
# c309	Thursday	14	17	CS218	Hammad Majeed
# ['Salman Hassan Zadeh', 'Meltem Naylor', 'Parastoo Jamshidi', 'Dalia Remeikyte', 'Sarah S Shahid', 'Sarah Hinett', 'Amir Ahmed', 'Seema Mandalia', 'Shahid Khan', 'Hamza Bin Muhammad', 'Maria A Grenfell', 'Ann White', 'Faraj B Shaban', 'Dalia Remeikyte', 'Ann Tai', 'Natasha Lelijveld', 'Arooba Zahoor', 'Jenna Riley', 'Yaser A Aljammaz', 'Ahmad F Yang Abd Talib', 'Zaki Choudhury', 'Sarah Wilson', 'Sarah E Kirkham-Slack', 'Saleem Abubacker', 'Adam Kirk', 'Leila C Payne', 'Sarah J Roberts', 'Arsheen Rajpar', 'Arsheen Rajpar']	.
# c304	Friday	9	12	SS111	Sehrish Hassan
# ['Sam D Edwards', 'Arsheen Rajpar', 'Halima Sayed', 'Tara Glickman', 'Aleena Unadkat', 'Adam Selby', 'Yaser A Aljammaz', 'Bahjat Al-Ani', 'Damian A Cummings', 'Adam Mickiewicz', 'Mohammed A Suleman', 'Safiya Issa', 'Shireen Dowlut-Beebeejaun', 'Zahir Hussain', 'Leyla Doroudi', 'Ana Vukojevic', 'Nima Dirie', 'Dean Brodesky', 'Adam Kirk', 'Sarah Austin', 'Ann Tai', 'Sonia V Diaz', 'Maryam Askari Louyeh', 'Ibrahim Adegboye', 'Farzana Yamin', 'Bahjat Al-Ani', 'Aidan P Murphy', 'Sarah Hewitt', 'Leila C Payne']	.
# c308	Friday	9	12	EE227	Hammad Majeed
# ['Judi Glen', 'Natasha Edwards', 'Ayan Lowe', 'Sarah Clements', 'Zeenat K Guness-Goolbar', 'Maria A Grenfell', 'Naseem Akram', 'Shari K Rasmussen', 'Ana Vukojevic', 'Ann Tai', 'Anja Sarlah', 'Jenna Riley', 'Zahra Faraji Rad', 'Nima Dirie', 'Imtiaz Kermali', 'Ayse Hatunoglu', 'Jan Fiala', 'Asim Ali', 'Adam C Ryan', 'Sarah Fogg', 'Salma Khanam', 'Aida Hoxha', 'Adam Mickiewicz', 'Jina Zhao', 'Sonia V Diaz', 'Samina Akbar', 'Meryem Mehmetbasoglu', 'Maria A Grenfell', 'Mika Tatsumoto']	.
# c310	Friday	9	12	MT205	Behjat Zuhaira
# ['Faris Quaid', 'Dalia Remeikyte', 'Sonia V Diaz', 'Usman Rafiq', 'Shireen Dowlut-Beebeejaun', 'Seema Mandalia', 'Leyla Doroudi', 'Imtiaz Kermali', 'Ahmed Ahmed', 'Ameerah Kasenally-Boodoo', 'Hamza Bin Muhammad', 'Salma Khanam', 'Leyla Doroudi', 'Mohamed A Baalousha', 'Kamila Keshubay', 'Sajida Ayub', 'Sarwar Hussain', 'Asim Ali', 'Ayman Jaheen', 'Natasha Leeson', 'Ann Tai', 'Shadan Alam', 'Natasha Lelijveld', 'Yas Khaled', 'Mohamed F Bakaram', 'Mohammad Abir', 'Maria M Ponce Carpio', 'Natasha Leeson', 'Sarah Dobson']	.
# c307	Friday	9	12	AI2011	Noreen Jamil
# ['Aras Panahian Jand', 'Salman Hassan Zadeh', 'Natasha Edwards', 'Sonia V Diaz', 'Iram Meharban', 'Salma Khanam', 'Arsheen Rajpar', 'Sarah Fogg', 'Amir Ahmed', 'Zaki Choudhury', 'Kiran K Chahal', 'Ann Tai', 'Syed M Abbas', 'Sam Isherwood', 'Hassana Begum', 'Kamal Anwar', 'Adam Kirk', 'Adam Sanders', 'Sarah Hinett', 'Rida Shaikh', 'Arsheen Rajpar', 'Kabir A Khan', 'Anja Brezovnik', 'Yasmin Ahmed', 'Sagar R Jilka', 'Anita Hodler', 'Maria M Ponce Carpio', 'Ramesh R Singh', 'Maria Lytras']	.
# c303	Friday	10	13	SS118	Usman Rashid
# ['Sam Duncanson', 'Mohamed F Bakaram', 'Irfan Yousaf', 'Leanne M Taylor-Smith', 'Zaki Choudhury', 'Maria Antonia Morua Leyva', 'Mohamed F Bakaram', 'Sarah Montgomery', 'Mohammed Z Albahar', 'Arman N Bahadori', 'Maryam Askari Louyeh', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Seema Mandalia', 'Ibrar Manawer', 'Kamila Keshubay', 'Sara De La Serna', 'Irfan Yousaf', 'Sarina Patel', 'Selina V Penarski', 'Adam N Starling', 'Jasmine Winyard', 'Sheila Hughton', 'Mohamed A Baalousha', 'Hazimah H Hj Hamzah', 'Tina Nasersharif', 'Selina V Penarski', 'Mohammed Z Albahar', 'Ahmad F Yang Abd Talib', 'Leyla Doroudi']	.
# c302	Friday	10	13	SS111	Muhammad Usman
# ['Mona Vadher', 'Sara De La Serna', 'Shahid Khan', 'Dalia Remeikyte', 'Judi Glen', 'Ana Vukojevic', 'Maria Antonia Morua Leyva', 'Sarah N Md Sallehuddin Khan', 'Mona Vadher', 'Ibrar Manawer', 'Ann White', 'Mohammed Z Albahar', 'Usman Rafiq', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Faris Quaid', 'Eileen Haycox', 'Sarah Hinett', 'Sarah Hanley', 'Ann White', 'Mohammad Abir', 'Sarah E Kirkham-Slack', 'Syed M Ghufran', 'Sarah Clements', 'Faris Quaid', 'Arsheen Rajpar', 'Sarah Hanley', 'Maria Lytras', 'Ayman Jaheen', 'Sadia Rehman']	.
# c306	Friday	10	13	MT224	Farah Jabeen Awan
# ['Ahmed Ahmed', 'Sarah L Clark', 'Natasha Tait', 'Tara Glickman', 'Meryem Mehmetbasoglu', 'Dean Brodesky', 'Safiya Issa', 'Ayse Hatunoglu', 'Sarwar Hussain', 'Naveed Hussain', 'Shireen Dowlut-Beebeejaun', 'Faris Quaid', 'Muna Osman', 'Sadia Rehman', 'Saleem Abubacker', 'Sonia Zain', 'Maria Antonia Morua Leyva', 'Natasha Tait', 'Samina Akbar', 'Natasha Tait', 'Sarah Hewitt', 'Kamila Houdkova', 'Sarah S Shahid', 'Sadra Keyhani', 'Meryem Mehmetbasoglu', 'Natasha Edwards', 'Eileen Haycox', 'Naseem Akram', 'Sam Duncanson']	.
# c303	Friday	11	14	SS113	Nagina Safdar
# ['Jenna Riley', 'Samina Akbar', 'Zainab Khattak', 'Mohammed Z Albahar', 'Sarah Austin', 'Anja Brezovnik', 'Sarwar Hussain', 'Adam Selby', 'Ayan Lowe', 'Mohammed Sukkari', 'Ahmed Ahmed', 'Ahmed Abbas Ahmed', 'Muhammad Ijaz-Ul-Haq', 'Imtiaz Kermali', 'Sarah Nolasco', 'Rafal Szczypinski', 'Mohammad Abir', 'Iram Matloob', 'Anita Hodler', 'Adam C Ryan', 'Yas Khaled', 'Ann D Brix', 'Yasir M Salih', 'Kabir A Khan', 'Sarah Fogg', 'Iram Matloob', 'Leyla Doroudi', 'Sheila Hughton', 'Nadia Parveen']	.
# c307	Friday	11	14	SS118	Subhan Ullah
# ['Nosheen Maqbool', 'Maryam Askari Louyeh', 'Leila C Payne', 'Bushra Duri', 'Shahzada S Niwaz', 'Adam Mickiewicz', 'Mohamed A Baalousha', 'Rida Shaikh', 'Arsheen Rajpar', 'Iram Meharban', 'Arooba Zahoor', 'Tina Nasersharif', 'Mohammed Sukkari', 'Sarah Hinett', 'Maria M Ponce Carpio', 'Zahra Faraji Rad', 'Faraj B Shaban', 'Sarah N Md Sallehuddin Khan', 'Judi Glen', 'Maria M Ponce Carpio', 'Usman Rafiq', 'Sarah L Barber-Jones', 'Natasha Edwards', 'Sarah Armstrong', 'Sarah J Roberts', 'Asim Ali', 'Mohammed I Al Arfaj', 'Tina Nasersharif', 'Mohammed I Al Arfaj']	.
# c304	Friday	11	14	CS307	Farah Naz
# ['Yaser A Aljammaz', 'Shahid Khan', 'Jenna Riley', 'Sarah Montgomery', 'Meltem Naylor', 'Adam Flowers', 'Negar Saleh', 'Nima Dirie', 'Sajida Ayub', 'Shadan Alam', 'Sarah N Md Sallehuddin Khan', 'Aras Panahian Jand', 'Natasha Edwards', 'Maria A Grenfell', 'Arooba Zahoor', 'Nadine Meyer', 'Sadia Rehman', 'Maysa Saeidi', 'Arman N Bahadori', 'Salwa S Alobaid', 'Samina Akbar', 'Ana B Javier Cuetos', 'Maria M Ponce Carpio', 'Sarah Clements', 'Soha Siahpoosh Kolyaei', 'Soha Siahpoosh Kolyaei', 'Ana B Javier Cuetos', 'Asim Ali', 'Ana Vukojevic']	.
# c308	Friday	12	15	CS118	Ameen Chilwan
# ['Judi Glen', 'Bibi A Khan', 'Sagar R Jilka', 'Halima Sayed', 'Eileen Harris', 'Babak Cheraghchi Bashi Astaneh', 'Sam J Pottier', 'Nabila Altaf', 'Mohammed Z Albahar', 'Sonia V Diaz', 'Ann Tai', 'Ana B Javier Cuetos', 'Sarah Armstrong', 'Naseem Akram', 'Arooba Zahoor', 'Adam Kirk', 'Muna Osman', 'Maria A Grenfell', 'Maysa Saeidi', 'Sarah Wilson', 'Samina Akbar', 'Adam Mickiewicz', 'Aleena Unadkat', 'Ahmed Abbas Ahmed', 'Arooba Zahoor', 'Salwa S Alobaid', 'Meryem Mehmetbasoglu', 'Damian A Cummings', 'Yas Khaled']	.
# c306	Friday	13	16	CS219	Rohail Gulbaz
# ['Amber Summerfield', 'Mona Vadher', 'Zeenat K Guness-Goolbar', 'Irfan Yousaf', 'Sarah L Clark', 'Iram Meharban', 'Kamila Houdkova', 'Sonia Zain', 'Kamila Houdkova', 'Ameerah Kasenally-Boodoo', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Salman Hassan Zadeh', 'Hazimah H Hj Hamzah', 'Mohamed A Baalousha', 'Razan Z Haji Zulkifli', 'Bushra Duri', 'Syed M Ghufran', 'Seema Mandalia', 'Zahra Faraji Rad', 'Soha Siahpoosh Kolyaei', 'Arooba Zahoor', 'Nima Dirie', 'Lilia Kyuchukova', 'Ibrar Manawer', 'Sarah L Clark', 'Sarah J Roberts', 'Salma Khanam', 'Nadine Meyer', 'Sarah N Md Sallehuddin Khan']	.
# c301	Friday	13	16	SS111	Ameen Chilwan
# ['Abdul Gafur', 'Yasmin Ahmed', 'Natasha Tait', 'Nadine Meyer', 'Iram Matloob', 'Sam J Pottier', 'Iram Meharban', 'Kabir A Khan', 'Natasha J Seaward', 'Shahzada S Niwaz', 'Natasha Tait', 'Adam Green', 'Adam N Starling', 'Anita Hodler', 'Arsheen Rajpar', 'Nadine Meyer', 'Maryam Askari Louyeh', 'Natasha Lelijveld', 'Farzad Farahmand', 'Zainab Khattak', 'Natasha Edwards', 'Damian A Cummings', 'Sarah Nolasco', 'Sagar R Jilka', 'Ana Sbert Ortin', 'Eileen Harris', 'Bahjat Al-Ani', 'Faris Quaid', 'Siraj Shariff']	.
# c302	Monday	9	12	EE229	Javaria Imtiaz
# ['Hamza Bin Muhammad', 'Amir Ahmed', 'Maria Antonia Morua Leyva', 'Maria M Ponce Carpio', 'Sarina Patel', 'Hanna I Siahaan', 'Sarah Hinett', 'Sarah Hadley', 'Bahjat Al-Ani', 'Sarah Austin', 'Faris Quaid', 'Adam Green', 'Yas Khaled', 'Adam L Finch', 'Ahmed Ahmed', 'Farzad Farahmand', 'Sarah Hadley', 'Sadra Keyhani', 'Muna Osman', 'Sam Duncanson', 'Natasha Leeson', 'Zainab Khattak', 'Sarah Clements', 'Arman N Bahadori', 'Natasha Leeson', 'Anja Sarlah', 'Adam Selby', 'Rafal Szczypinski', 'Sarah Wilson']	.
# c303	Monday	9	12	AI2011	Waqas Munir
# ['Usman Rafiq', 'Farzad Farahmand', 'Tina Nasersharif', 'Sara Zamberlan', 'Zeenat K Guness-Goolbar', 'Arsheen Rajpar', 'Nabila Altaf', 'Omar F Khan', 'Seema Mandalia', 'Sarah H Przybylak', 'Faris Quaid', 'Lilia Kyuchukova', 'Ibrahim Adegboye', 'Maria Antonia Morua Leyva', 'Shahzada S Niwaz', 'Kamal Anwar', 'Ahmed Abbas Ahmed', 'Adam L Finch', 'Natasha Lelijveld', 'Jasmine Winyard', 'Siraj Shariff', 'Halima Sayed', 'Jan Fiala', 'Adam Sanders', 'Sam Dalgleish', 'Ramesh R Singh', 'Yaser A Aljammaz', 'Damian A Cummings', 'Sam D Edwards']	.
# c308	Monday	10	13	SE110	Gul e Aisha
# ['Hazimah H Hj Hamzah', 'Sonia Zain', 'Adam Kirk', 'Sarwar Hussain', 'Reem N Hassan', 'Dalia Remeikyte', 'Ibrar Manawer', 'Sagar R Jilka', 'Natasha Lelijveld', 'Sarah Nolasco', 'Ibrar Manawer', 'Sarah Hewitt', 'Rida Shaikh', 'Farzad Farahmand', 'Mohammed I Al Arfaj', 'Nadine Meyer', 'Sarah L Clark', 'Salman Hassan Zadeh', 'Bahjat Al-Ani', 'Ann Wilson', 'Yas Khaled', 'Sara De La Serna', 'Usman Rafiq', 'Sam D Edwards', 'Ayda Niazi', 'Ann D Brix', 'Sam J Pottier', 'Sarah E Kirkham-Slack', 'Natasha Edwards']	.
# c304	Monday	10	13	MT224	Maimoona Rassol
# ['Salwa S Alobaid', 'Manal Aldaihani', 'Shadan Mirarmandehi', 'Syed M Ghufran', 'Mohammed Zafran', 'Tara Glickman', 'Ayan Lowe', 'Aras Panahian Jand', 'Zainab Khattak', 'Faraj B Shaban', 'Ann White', 'Adam Flowers', 'Omar S Aslam', 'Hanna I Siahaan', 'Ayman Jaheen', 'Ana Sbert Ortin', 'Nabila Altaf', 'Omar S Aslam', 'Shari K Rasmussen', 'Arsheen Rajpar', 'Sarah Clements', 'Irfan Yousaf', 'Jenna Riley', 'Hassana Begum', 'Sajida Ayub', 'Nina N Wronka', 'Sam J Pottier', 'Arsheen Rajpar', 'Bushra Duri']	.
# c309	Monday	11	14	EE229	Zohaib Iqbal
# ['Arsheen Rajpar', 'Ayda Niazi', 'Nima Dirie', 'Zaki Choudhury', 'Shahina Parveen', 'Mohammed Sukkari', 'Maria Lytras', 'Siraj Shariff', 'Rafal Szczypinski', 'Eileen Haycox', 'Samina Akbar', 'Adam Flowers', 'Sarah H Przybylak', 'Sadra Keyhani', 'Shahzada S Niwaz', 'Jina Zhao', 'Nima Dirie', 'Nadia Parveen', 'Naveed Hussain', 'Leyla Doroudi', 'Meltem Naylor', 'Manal Aldaihani', 'Maria M Ponce Carpio', 'Leanne M Taylor-Smith', 'Nadine Meyer', 'Dalia Remeikyte', 'Nima Dirie', 'Sarah Austin', 'Halima Sayed']	.
# c301	Monday	12	15	DS3011	Umair Arshad
# ['Manal Aldaihani', 'Sheila Hughton', 'Ana B Javier Cuetos', 'Adam C Ryan', 'Syed M Abbas', 'Sarah E Kirkham-Slack', 'Bibi A Khan', 'Hanna I Siahaan', 'Ann Tai', 'Sonia V Diaz', 'Adam L Finch', 'Eileen Haycox', 'Sara Zamberlan', 'Halima Sayed', 'Bahjat Al-Ani', 'Mohammed I Al Arfaj', 'Ayan Lowe', 'Sara Zamberlan', 'Jenna Riley', 'Shahina Parveen', 'Sarah Hewitt', 'Ahmed Abbas Ahmed', 'Hamza Bin Muhammad', 'Sarah L Clark', 'Tara Glickman', 'Natasha Edwards', 'Natasha Tait', 'Salma Khanam', 'Natasha Tait']	.
# c306	Tuesday	9	12	EE229	Noor ul Ain
# ['Sarah Hinett', 'Asim Ali', 'Jenna Riley', 'Ali M Sadeghioon', 'Jenna Riley', 'Saleem Abubacker', 'Adam Green', 'Leila C Payne', 'Mohammed Sukkari', 'Natasha J Seaward', 'Muhammad Ijaz-Ul-Haq', 'Hanna I Siahaan', 'Ana Sbert Ortin', 'Sheila Hughton', 'Sarah Hanley', 'Nadia Parveen', 'Sarah Hinett', 'Faheema Korumtollee', 'Usman Rafiq', 'Sarah Nolasco', 'Shahid Khan', 'Mika Tatsumoto', 'Muhammad Ijaz-Ul-Haq', 'Sarwar Hussain', 'Eileen Haycox', 'Shahzada S Niwaz', 'Shadan Mirarmandehi', 'Dalia Remeikyte', 'Tara Glickman']	.
# c304	Tuesday	12	15	CS219	Bilal Khalid
# ['Omar S Aslam', 'Shahina Parveen', 'Shahid Khan', 'Sam D Edwards', 'Ayda Niazi', 'Samina Akbar', 'Tina Nasersharif', 'Ahmed Ahmed', 'Maria A Grenfell', 'Dean Brodesky', 'Ann Wilson', 'Sarah R Young', 'Kiran K Chahal', 'Jina Zhao', 'Kiran K Chahal', 'Naseem Akram', 'Shahid Khan', 'Naveed Hussain', 'Ahmed Abbas Ahmed', 'Mona Vadher', 'Safiya Issa', 'Ahmad F Yang Abd Talib', 'Behzad Babakhani', 'Muna Osman', 'Ramesh R Singh', 'Ann D Brix', 'Selina V Penarski', 'Nina N Wronka', 'Hamza Bin Muhammad']	.
# c307	Tuesday	13	16	CS307	Shafaq Riaz
# ['Sheila Hughton', 'Mohammed Zafran', 'Hamza Bin Muhammad', 'Aida Hoxha', 'Zahra Faraji Rad', 'Naseem Akram', 'Huda O Ali', 'Faris Quaid', 'Syed M Abbas', 'Ayman Jaheen', 'Ann D Brix', 'Shadan Alam', 'Aida Hoxha', 'Syed M Abbas', 'Amber Summerfield', 'Mohamed A Baalousha', 'Sarah Hinett', 'Bibi A Khan', 'Naveed Hussain', 'Mohamed A Baalousha', 'Mika Tatsumoto', 'Ann Tai', 'Anja Brezovnik', 'Sadra Keyhani', 'Sam D Edwards', 'Selina V Penarski', 'Asim Ali', 'Sarah French', 'Anja Sarlah']	.
# c305	Tuesday	13	16	CS211	Hassan Raza
# ['Amber Summerfield', 'Manal Aldaihani', 'Irfan Yousaf', 'Omar Chaudhrey', 'Usman Rafiq', 'Naveed Hussain', 'Shari K Rasmussen', 'Sajida Ayub', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sara De La Serna', 'Farzana Yamin', 'Leyla Doroudi', 'Sarah Hanley', 'Ahmed Abbas Ahmed', 'Abdul Gafur', 'Shahzada S Niwaz', 'Adam Kirk', 'Aleena Unadkat', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Meryem Mehmetbasoglu', 'Natasha Edwards', 'Mohamed F Bakaram', 'Yaser A Aljammaz', 'Sarah L Clark', 'Samar E Nassar', 'Usman Rafiq', 'Meryem Mehmetbasoglu', 'Irfan Yousaf', 'Aleena Unadkat']	.
# c308	Tuesday	13	16	CS118	Rohail Gulbaz
# ['Razan Z Haji Zulkifli', 'Sam Duncanson', 'Faris Quaid', 'Sarah Nolasco', 'Sonia Zain', 'Jan Fiala', 'Shadan Mirarmandehi', 'Ayman Jaheen', 'Aleena Unadkat', 'Salma Khanam', 'Anja Brezovnik', 'Ahmad F Yang Abd Talib', 'Farzad Farahmand', 'Razan Z Haji Zulkifli', 'Sarah Austin', 'Natasha Lelijveld', 'Lilia Kyuchukova', 'Sajida Ayub', 'Adam Selby', 'Naseem Akram', 'Adam Kirk', 'Ibrar Manawer', 'Sarah Wilson', 'Adam Mickiewicz', 'Ann Wilson', 'Ahmad F Yang Abd Talib', 'Selina V Penarski', 'Sarah Clements', 'Natasha Edwards']	.
# c302	Tuesday	14	17	SS118	Sajid Khan
# ['Kamila Houdkova', 'Jenna Riley', 'Sara Zamberlan', 'Sarah Hadley', 'Ibrar Manawer', 'Nadia Parveen', 'Seema Mandalia', 'Sam D Edwards', 'Irfan Yousaf', 'Kiran K Chahal', 'Nina N Wronka', 'Adam L Finch', 'Parastoo Jamshidi', 'Rafal Szczypinski', 'Eileen Haycox', 'Omar Chaudhrey', 'Sarah Nolasco', 'Dean Brodesky', 'Leanne M Taylor-Smith', 'Sarah N Md Sallehuddin Khan', 'Sajida Ayub', 'Tara Glickman', 'Zahir Hussain', 'Muna Osman', 'Syed M Ghufran', 'Sarah J Bradford', 'Ann D Brix', 'Faris Quaid', 'Ali M Sadeghioon']	.
# c304	Wednesday	10	13	SS152	Kifayat Ullah
# ['Ann White', 'Arsheen Rajpar', 'Nabila Altaf', 'Sam Dalgleish', 'Arooba Zahoor', 'Adam N Starling', 'Sarah J Roberts', 'Ann D Brix', 'Sarah S Shahid', 'Nosheen Maqbool', 'Ahmed Abbas Ahmed', 'Ann D Brix', 'Eileen Harris', 'Tina Nasersharif', 'Sam Isherwood', 'Ayda Niazi', 'Maysa Saeidi', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sadia Rehman', 'Meltem Naylor', 'Sarah Fogg', 'Sarah Hanley', 'Imtiaz Kermali', 'Salma Khanam', 'Razan Z Haji Zulkifli', 'Syed M Abbas', 'Natasha Tait', 'Samar E Nassar', 'Mohamed A Baalousha']	.
# c301	Wednesday	11	14	CS211	Noreen Jamil
# ['Sarah L Barber-Jones', 'Selina V Penarski', 'Ahmed Ahmed', 'Faraj B Shaban', 'Ayse Hatunoglu', 'Shahzada S Niwaz', 'Adam Kirk', 'Mohammed A Suleman', 'Naseem Akram', 'Meltem Naylor', 'Sara Zamberlan', 'Dean Brodesky', 'Iram Matloob', 'Anita Hodler', 'Leyla Doroudi', 'Sarah Taylor', 'Nadia Parveen', 'Sarah L Barber-Jones', 'Ana B Javier Cuetos', 'Ahmed Abbas Ahmed', 'Sarah Hewitt', 'Yaser A Aljammaz', 'Sarah J Bradford', 'Rafal Szczypinski', 'Iram Matloob', 'Nabila Altaf', 'Lilia Kyuchukova', 'Ramesh R Singh', 'Damian A Cummings']	.
# c302	Wednesday	11	14	DS3011	Zainab Abaid
# ['Leyla Doroudi', 'Adam Sanders', 'Ali M Sadeghioon', 'Huda O Ali', 'Jina Zhao', 'Ibrahim Adegboye', 'Mohammed A Suleman', 'Adam Kirk', 'Sarah Armstrong', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Zeenat K Guness-Goolbar', 'Aidan P Murphy', 'Shireen Dowlut-Beebeejaun', 'Ramesh R Singh', 'Nadine Meyer', 'Ali M Sadeghioon', 'Zaki Choudhury', 'Judi Glen', 'Sonia Zain', 'Mohammed A Suleman', 'Farzad Farahmand', 'Sarah R Young', 'Sarah E Kirkham-Slack', 'Zaki Choudhury', 'Soha Siahpoosh Kolyaei', 'Nadine Meyer', 'Sarah Nolasco', 'Yasmin Ahmed', 'Kamila Houdkova']	.
# c304	Wednesday	12	15	AI2011	Sanaa Ilyas
# ['Manal Aldaihani', 'Maria Antonia Morua Leyva', 'Mohammed A Suleman', 'Ana Sbert Ortin', 'Sagar R Jilka', 'Behzad Babakhani', 'Bahjat Al-Ani', 'Sarah Dobson', 'Kamila Keshubay', 'Adam L Finch', 'Muna Osman', 'Kamal Anwar', 'Ibrahim Adegboye', 'Omar Chaudhrey', 'Seema Mandalia', 'Sarah Hanley', 'Judi Glen', 'Bushra Duri', 'Sara Zamberlan', 'Ayda Niazi', 'Hamza Bin Muhammad', 'Sadia Rehman', 'Omar Chaudhrey', 'Shireen Dowlut-Beebeejaun', 'Jenna Riley', 'Amber Summerfield', 'Reem N Hassan', 'Dalia Remeikyte', 'Hamza Bin Muhammad']	.
# c305	Thursday	9	12	CS118	Hassan Raza
# ['Ayda Niazi', 'Imtiaz Kermali', 'Sarah S Shahid', 'Natasha Leeson', 'Nadine Meyer', 'Sarah H Przybylak', 'Sarah Nolasco', 'Mohamed F Bakaram', 'Natasha Tait', 'Amber Summerfield', 'Shahid Khan', 'Rida Shaikh', 'Adam Selby', 'Shadan Mirarmandehi', 'Razan Z Haji Zulkifli', 'Nina N Wronka', 'Huda O Ali', 'Mohamed A Baalousha', 'Sarah S Shahid', 'Salman Hassan Zadeh', 'Salwa S Alobaid', 'Mohammed I Al Arfaj', 'Sarah E Kirkham-Slack', 'Samar E Nassar', 'Iram Meharban', 'Shireen Dowlut-Beebeejaun', 'Leyla Doroudi', 'Negar Saleh', 'Kamila Houdkova']	.
# c306	Thursday	9	12	CS218	Farah Jabeen Awan
# ['Ayda Niazi', 'Adam C Ryan', 'Mohammed Sukkari', 'Jan Fiala', 'Sarah Hanley', 'Nima Dirie', 'Sarah Hanley', 'Adam C Ryan', 'Abdul Gafur', 'Kamal Anwar', 'Behzad Babakhani', 'Irfan Yousaf', 'Aras Panahian Jand', 'Sarah Wilson', 'Jasmine Winyard', 'Leila C Payne', 'Sarah Clements', 'Kabir A Khan', 'Sarah Fogg', 'Sarah Hewitt', 'Bushra Duri', 'Omar S Aslam', 'Zahir Hussain', 'Sarah H Przybylak', 'Sarah Hadley', 'Shahina Parveen', 'Bahjat Al-Ani', 'Sarah N Md Sallehuddin Khan', 'Tina Nasersharif']	.
# c301	Thursday	9	12	MG220	Umair Arshad
# ['Mohammed Sukkari', 'Bahjat Al-Ani', 'Siraj Shariff', 'Mohamed A Baalousha', 'Natasha Edwards', 'Ibrahim Adegboye', 'Salma Khanam', 'Natasha J Seaward', 'Omar F Khan', 'Sonia Zain', 'Kabir A Khan', 'Nadine Meyer', 'Sarah J Bradford', 'Sarah Austin', 'Sam J Pottier', 'Ibrar Manawer', 'Seema Mandalia', 'Shadan Mirarmandehi', 'Ahmad F Yang Abd Talib', 'Kabir A Khan', 'Maria A Grenfell', 'Farzad Farahmand', 'Omar Chaudhrey', 'Sonia V Diaz', 'Seema Mandalia', 'Nabila Altaf', 'Eileen Harris', 'Sarah Hinett', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub']	.
# c306	Thursday	9	12	MG223	Hammad Majeed
# ['Leanne M Taylor-Smith', 'Adam Kirk', 'Faris Quaid', 'Sarah French', 'Seema Mandalia', 'Maria M Ponce Carpio', 'Omar F Khan', 'Shadan Mirarmandehi', 'Zeenat K Guness-Goolbar', 'Ana B Javier Cuetos', 'Samina Akbar', 'Arman N Bahadori', 'Adam L Finch', 'Zainab Khattak', 'Sam Duncanson', 'Sarah L Barber-Jones', 'Anja Sarlah', 'Kiran K Chahal', 'Tina Nasersharif', 'Eileen Harris', 'Shadan Mirarmandehi', 'Omar Chaudhrey', 'Sarah Montgomery', 'Irfan Yousaf', 'Sarina Patel', 'Jenna Riley', 'Mohamed F Bakaram', 'Mohammed I Al Arfaj', 'Farzana Yamin']	.
# c307	Thursday	11	14	CY2012	Muhammad Usman
# ['Hanna I Siahaan', 'Ana Vukojevic', 'Saleem Abubacker', 'Ameerah Kasenally-Boodoo', 'Judi Glen', 'Farzana Yamin', 'Samina Akbar', 'Mohammed A Suleman', 'Yaser A Aljammaz', 'Sajida Ayub', 'Abdul Gafur', 'Saleem Abubacker', 'Aras Panahian Jand', 'Adam N Starling', 'Arsheen Rajpar', 'Leanne M Taylor-Smith', 'Muna Osman', 'Natasha Edwards', 'Adam Sanders', 'Natasha Edwards', 'Lilia Kyuchukova', 'Eileen Haycox', 'Sam Dalgleish', 'Yasir M Salih', 'Muhammad Ijaz-Ul-Haq', 'Saleem Abubacker', 'Sarah S Shahid', 'Shireen Dowlut-Beebeejaun', 'Adam Kirk']	.
# c306	Thursday	12	15	SS152	Noreen Jamil
# ['Leyla Doroudi', 'Natasha Edwards', 'Zahir Hussain', 'Sarah L Barber-Jones', 'Amber Summerfield', 'Syed M Abbas', 'Kamila Houdkova', 'Natasha J Seaward', 'Soha Siahpoosh Kolyaei', 'Sheila Hughton', 'Sarwar Hussain', 'Rida Shaikh', 'Razan Z Haji Zulkifli', 'Shahina Parveen', 'Sarah Clements', 'Kamila Keshubay', 'Nadine Meyer', 'Eileen Haycox', 'Salwa S Alobaid', 'Yasmin Ahmed', 'Zeenat K Guness-Goolbar', 'Sadia Rehman', 'Negar Saleh', 'Saleem Abubacker', 'Irfan Yousaf', 'Kamila Houdkova', 'Ameerah Kasenally-Boodoo', 'Adam L Finch', 'Sarah Nolasco']	.
# c307	Thursday	12	15	MT205	Hassan Raza
# ['Maria A Grenfell', 'Naveed Hussain', 'Yaser A Aljammaz', 'Farzad Farahmand', 'Faheema Korumtollee', 'Mohammed A Suleman', 'Sadra Keyhani', 'Ayan Lowe', 'Maryam Askari Louyeh', 'Ibrar Manawer', 'Kamila Keshubay', 'Nima Dirie', 'Saleem Abubacker', 'Sarah R Young', 'Sonia Zain', 'Sarah R Young', 'Maria A Grenfell', 'Aidan P Murphy', 'Faris Quaid', 'Ayda Niazi', 'Parastoo Jamshidi', 'Mohammed Zafran', 'Selina V Penarski', 'Faris Quaid', 'Amber Summerfield', 'Hamza Bin Muhammad', 'Ameerah Kasenally-Boodoo', 'Jenna Riley', 'Syed M Ghufran']	.
# c310	Thursday	12	15	CS220	Sara Aziz
# ['Faraj B Shaban', 'Maria Lytras', 'Kamal Anwar', 'Mona Vadher', 'Manal Aldaihani', 'Irfan Yousaf', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Nina N Wronka', 'Sara Zamberlan', 'Natasha J Seaward', 'Sarah Hewitt', 'Maria M Ponce Carpio', 'Sarah J Roberts', 'Rida Shaikh', 'Maryam Askari Louyeh', 'Ayse Hatunoglu', 'Natasha Lelijveld', 'Nadia Parveen', 'Imtiaz Kermali', 'Ali M Sadeghioon', 'Leyla Doroudi', 'Samina Akbar', 'Reem N Hassan', 'Mohamed F Bakaram', 'Sarah Austin', 'Ahmad F Yang Abd Talib', 'Dean Brodesky', 'Ahmed Ahmed', 'Adam Flowers']	.
# c302	Friday	9	12	MT224	Zainab Moin
# ['Maria A Grenfell', 'Mohammed Z Albahar', 'Ann D Brix', 'Yasir M Salih', 'Sam Duncanson', 'Tina Nasersharif', 'Zainab Khattak', 'Mohammad Abir', 'Hanna I Siahaan', 'Maria Antonia Morua Leyva', 'Leyla Doroudi', 'Samina Akbar', 'Nadine Meyer', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Ahmed Ahmed', 'Yas Khaled', 'Sarina Patel', 'Yas Khaled', 'Sam J Pottier', 'Sarah Taylor', 'Adam Green', 'Sarina Patel', 'Zahir Hussain', 'Hassana Begum', 'Seema Mandalia', 'Eileen Haycox', 'Eileen Haycox', 'Leila C Payne']	.
# c305	Friday	9	12	CS328	Hassan Raza
# ['Aleena Unadkat', 'Shahina Parveen', 'Maria Antonia Morua Leyva', 'Judi Glen', 'Ana Sbert Ortin', 'Jina Zhao', 'Damian A Cummings', 'Shahid Khan', 'Salman Hassan Zadeh', 'Faheema Korumtollee', 'Sarah J Roberts', 'Eileen Harris', 'Jasmine Winyard', 'Anja Brezovnik', 'Ahmed Abbas Ahmed', 'Babak Cheraghchi Bashi Astaneh', 'Sheila Hughton', 'Sarah R Young', 'Sadra Keyhani', 'Samar E Nassar', 'Shadan Mirarmandehi', 'Leanne M Taylor-Smith', 'Jasmine Winyard', 'Leyla Doroudi', 'Jan Fiala', 'Samina Akbar', 'Aleena Unadkat', 'Samar E Nassar', 'Sam Dalgleish']	.
# c306	Friday	10	13	MG223	Muhammad Usman
# ['Sarah S Shahid', 'Sarah Montgomery', 'Leila C Payne', 'Nausheen Saleem', 'Sarah H Przybylak', 'Natasha Tait', 'Judi Glen', 'Salman Hassan Zadeh', 'Shahina Parveen', 'Kiran K Chahal', 'Ayan Lowe', 'Arman N Bahadori', 'Adam Sanders', 'Nosheen Maqbool', 'Ayse Hatunoglu', 'Hamza Bin Muhammad', 'Abdul Gafur', 'Rida Shaikh', 'Zahra Faraji Rad', 'Abdul Gafur', 'Leyla Doroudi', 'Kamila Keshubay', 'Saleem Abubacker', 'Naseem Akram', 'Sarah N Md Sallehuddin Khan', 'Seema Mandalia', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sarah L Barber-Jones', 'Ann D Brix']	.
# c304	Friday	10	13	MT205	Shoaib Mehboob
# ['Yas Khaled', 'Mona Vadher', 'Mohammed Sukkari', 'Naseem Akram', 'Leyla Doroudi', 'Ana B Javier Cuetos', 'Abdul Gafur', 'Hamza Bin Muhammad', 'Faris Quaid', 'Abdul Gafur', 'Iram Meharban', 'Zaki Choudhury', 'Aras Panahian Jand', 'Natasha Lelijveld', 'Sarah Fogg', 'Shahina Parveen', 'Manal Aldaihani', 'Shari K Rasmussen', 'Mohamed F Bakaram', 'Rafal Szczypinski', 'Yasir M Salih', 'Faraj B Shaban', 'Shadan Mirarmandehi', 'Shadan Mirarmandehi', 'Zahra Faraji Rad', 'Leanne M Taylor-Smith', 'Natasha Leeson', 'Bibi A Khan', 'Hanna I Siahaan']	.
# c308	Friday	10	13	SS111	Shehreyar Rashid
# ['Leanne M Taylor-Smith', 'Arooba Zahoor', 'Amir Ahmed', 'Samar E Nassar', 'Leanne M Taylor-Smith', 'Ayse Hatunoglu', 'Natasha Leeson', 'Ann White', 'Sam Isherwood', 'Sarah E Kirkham-Slack', 'Maysa Saeidi', 'Ali M Sadeghioon', 'Natasha Tait', 'Samina Akbar', 'Salman Hassan Zadeh', 'Sajida Ayub', 'Syed M Abbas', 'Ameerah Kasenally-Boodoo', 'Jasmine Winyard', 'Naseem Akram', 'Mona Vadher', 'Amber Summerfield', 'Tara Glickman', 'Sarah N Md Sallehuddin Khan', 'Adam Flowers', 'Nadia Parveen', 'Meltem Naylor', 'Sarina Patel', 'Jan Fiala']	.
# c309	Friday	11	14	CS328	Irum Inayat
# ['Faris Quaid', 'Jina Zhao', 'Sarah J Roberts', 'Halima Sayed', 'Sam Dalgleish', 'Ali M Sadeghioon', 'Faris Quaid', 'Jasmine Winyard', 'Ann Tai', 'Sarah Clements', 'Kabir A Khan', 'Natasha Tait', 'Razan Z Haji Zulkifli', 'Dean Brodesky', 'Sam Isherwood', 'Sarah Hewitt', 'Sara De La Serna', 'Nabila Altaf', 'Sadia Rehman', 'Sara De La Serna', 'Hanna I Siahaan', 'Hassana Begum', 'Shahina Parveen', 'Arsheen Rajpar', 'Sarah Nolasco', 'Aidan P Murphy', 'Shahid Khan', 'Mohammed Z Albahar', 'Naseem Akram']	.
# c305	Friday	12	15	DS3011	Ayesha Bano
# ['Sheila Hughton', 'Soha Siahpoosh Kolyaei', 'Tina Nasersharif', 'Sam Isherwood', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Seema Mandalia', 'Leyla Doroudi', 'Marwa Elcheikh', 'Ayda Niazi', 'Anja Sarlah', 'Naseem Akram', 'Syed M Abbas', 'Sarah Wilson', 'Usman Rafiq', 'Omar F Khan', 'Aida Hoxha', 'Zahir Hussain', 'Zainab Khattak', 'Dalia Remeikyte', 'Samar E Nassar', 'Amir Ahmed', 'Hassana Begum', 'Sarah R Young', 'Kamal Anwar', 'Siraj Shariff', 'Zahir Hussain', 'Zaki Choudhury', 'Jasmine Winyard', 'Mohammed I Al Arfaj']	.
# c310	Friday	12	15	MG223	Zainab Abaid
# ['Dalia Remeikyte', 'Mohammed Sukkari', 'Ahmad F Yang Abd Talib', 'Safiya Issa', 'Amber Summerfield', 'Hazimah H Hj Hamzah', 'Sarah R Young', 'Mika Tatsumoto', 'Faris Quaid', 'Ramesh R Singh', 'Sam Isherwood', 'Adam Green', 'Ayda Niazi', 'Ann Tai', 'Farzad Farahmand', 'Maryam Askari Louyeh', 'Faheema Korumtollee', 'Sarah N Md Sallehuddin Khan', 'Faris Quaid', 'Adam Green', 'Ibrahim Adegboye', 'Leanne M Taylor-Smith', 'Bahjat Al-Ani', 'Faris Quaid', 'Shahzada S Niwaz', 'Nosheen Maqbool', 'Bahjat Al-Ani', 'Sarah Wilson', 'Lilia Kyuchukova']	.
# c304	Friday	12	15	CS328	Usman Ashraf
# ['Maria Antonia Morua Leyva', 'Bibi A Khan', 'Hamza Bin Muhammad', 'Seema Mandalia', 'Bahjat Al-Ani', 'Ramesh R Singh', 'Parastoo Jamshidi', 'Nadine Meyer', 'Salwa S Alobaid', 'Natasha J Seaward', 'Abdul Gafur', 'Mohamed A Baalousha', 'Jan Fiala', 'Ayman Jaheen', 'Sara De La Serna', 'Judi Glen', 'Sam D Edwards', 'Leanne M Taylor-Smith', 'Imtiaz Kermali', 'Amber Summerfield', 'Sam J Pottier', 'Maria A Grenfell', 'Zeenat K Guness-Goolbar', 'Kiran K Chahal', 'Dean Brodesky', 'Jan Fiala', 'Zahra Faraji Rad', 'Sara Zamberlan', 'Ahmad F Yang Abd Talib']	.
# c310	Friday	13	16	CS218	Behjat Zuhaira
# ['Dalia Remeikyte', 'Jan Fiala', 'Sam Duncanson', 'Bushra Duri', 'Sarah H Przybylak', 'Sarah Wilson', 'Meryem Mehmetbasoglu', 'Samina Akbar', 'Mohammed A Suleman', 'Maria A Grenfell', 'Yasmin Ahmed', 'Sarah Clements', 'Ayda Niazi', 'Sam Isherwood', 'Ana Vukojevic', 'Syed M Ghufran', 'Muhammad Ijaz-Ul-Haq', 'Manal Aldaihani', 'Shadan Mirarmandehi', 'Ana Vukojevic', 'Shahzada S Niwaz', 'Ahmed Ahmed', 'Mika Tatsumoto', 'Jina Zhao', 'Sarah Nolasco', 'Ibrar Manawer', 'Nadine Meyer', 'Sarah Montgomery', 'Ayse Hatunoglu']	.
# c302	Friday	14	17	CS211	Javaria Imtiaz
# ['Shadan Alam', 'Sarah Hewitt', 'Shadan Mirarmandehi', 'Usman Rafiq', 'Ahmed Abbas Ahmed', 'Ameerah Kasenally-Boodoo', 'Sarah S Shahid', 'Sam D Edwards', 'Amber Summerfield', 'Kiran K Chahal', 'Shahina Parveen', 'Sam J Pottier', 'Sarah J Hammon', 'Sarah N Md Sallehuddin Khan', 'Aida Hoxha', 'Faris Quaid', 'Jasmine Winyard', 'Irfan Yousaf', 'Faris Quaid', 'Sarah Nolasco', 'Ramesh R Singh', 'Eileen Haycox', 'Adam Green', 'Zahir Hussain', 'Sarah J Hammon', 'Ameerah Kasenally-Boodoo', 'Syed M Ghufran', 'Behzad Babakhani', 'Arman N Bahadori']	.
# c304	Friday	14	17	SS111	Rohail Gulbaz
# ['Natasha J Seaward', 'Ayda Niazi', 'Sarah Wilson', 'Faraj B Shaban', 'Sarah Hanley', 'Sarah H Przybylak', 'Eileen Haycox', 'Anja Sarlah', 'Zahra Faraji Rad', 'Adam C Ryan', 'Faraj B Shaban', 'Manal Aldaihani', 'Dalia Remeikyte', 'Samina Akbar', 'Syed M Abbas', 'Maria Lytras', 'Sarah Hinett', 'Leila C Payne', 'Ramesh R Singh', 'Hamza Bin Muhammad', 'Mohamed F Bakaram', 'Maria Antonia Morua Leyva', 'Lilia Kyuchukova', 'Sarah L Clark', 'Aleena Unadkat', 'Babak Cheraghchi Bashi Astaneh', 'Anja Sarlah', 'Adam Kirk', 'Adam N Starling']	.
# c305	Monday	9	12	CS211	Waqas Munir
# ['Farzad Farahmand', 'Natasha Leeson', 'Jasmine Winyard', 'Jina Zhao', 'Farzana Yamin', 'Iram Matloob', 'Naveed Hussain', 'Ibrahim Adegboye', 'Seema Mandalia', 'Nosheen Maqbool', 'Sagar R Jilka', 'Salwa S Alobaid', 'Anja Sarlah', 'Behzad Babakhani', 'Samar E Nassar', 'Arman N Bahadori', 'Natasha Lelijveld', 'Hassana Begum', 'Maryam Askari Louyeh', 'Sam Dalgleish', 'Maryam Askari Louyeh', 'Ayda Niazi', 'Naseem Akram', 'Aida Hoxha', 'Ana B Javier Cuetos', 'Aleena Unadkat', 'Jina Zhao', 'Mohammed Sukkari', 'Samina Akbar']	.
# c308	Monday	10	13	SS111	Khadija Farooq
# ['Kabir A Khan', 'Mohammed A Suleman', 'Sarwar Hussain', 'Parastoo Jamshidi', 'Mika Tatsumoto', 'Farzana Yamin', 'Yasir M Salih', 'Sarah Dobson', 'Zahir Hussain', 'Sara De La Serna', 'Ahmed Abbas Ahmed', 'Huda O Ali', 'Zahra Faraji Rad', 'Sarah E Kirkham-Slack', 'Sarah R Young', 'Siraj Shariff', 'Usman Rafiq', 'Sarah N Md Sallehuddin Khan', 'Arman N Bahadori', 'Sarah N Md Sallehuddin Khan', 'Damian A Cummings', 'Ibrar Manawer', 'Sarah Austin', 'Manal Aldaihani', 'Sarah J Roberts', 'Arsheen Rajpar', 'Razan Z Haji Zulkifli', 'Rafal Szczypinski', 'Jan Fiala']	.
# c305	Monday	10	13	MT205	Maimoona Rassol
# ['Muhammad Ijaz-Ul-Haq', 'Behzad Babakhani', 'Arsheen Rajpar', 'Nadine Meyer', 'Reem N Hassan', 'Muhammad Ijaz-Ul-Haq', 'Sarah E Kirkham-Slack', 'Ann Wilson', 'Ali M Sadeghioon', 'Natasha Leeson', 'Ahmed Abbas Ahmed', 'Natasha J Seaward', 'Shadan Alam', 'Adam C Ryan', 'Yaser A Aljammaz', 'Sarah Hinett', 'Arman N Bahadori', 'Adam Sanders', 'Ali M Sadeghioon', 'Anita Hodler', 'Syed M Ghufran', 'Yas Khaled', 'Sarah Fogg', 'Sarah Hadley', 'Adam Sanders', 'Farzad Farahmand', 'Babak Cheraghchi Bashi Astaneh', 'Jan Fiala', 'Sam D Edwards']	.
# c303	Monday	12	15	MG223	Naveed Ahmad
# ['Arsheen Rajpar', 'Amber Summerfield', 'Ayman Jaheen', 'Iram Matloob', 'Nosheen Maqbool', 'Natasha Edwards', 'Sarah Nolasco', 'Sarah E Kirkham-Slack', 'Ameerah Kasenally-Boodoo', 'Shari K Rasmussen', 'Adam Sanders', 'Nima Dirie', 'Mona Vadher', 'Sarina Patel', 'Ibrar Manawer', 'Zahra Faraji Rad', 'Shadan Mirarmandehi', 'Amber Summerfield', 'Nadine Meyer', 'Sarah Austin', 'Mohamed F Bakaram', 'Sarah Clements', 'Mohammed I Al Arfaj', 'Ramesh R Singh', 'Zainab Khattak', 'Salwa S Alobaid', 'Sarah J Roberts', 'Yas Khaled', 'Muhammad Ijaz-Ul-Haq']	.
# c307	Monday	14	17	CS219	Maimoona Rassol
# ['Yasmin Ahmed', 'Sarah J Hammon', 'Adam C Ryan', 'Nadia Parveen', 'Kabir A Khan', 'Sheila Hughton', 'Adam C Ryan', 'Rafal Szczypinski', 'Sarah Austin', 'Sam Isherwood', 'Sarah Montgomery', 'Sarah J Roberts', 'Natasha Edwards', 'Selina V Penarski', 'Parastoo Jamshidi', 'Bibi A Khan', 'Ali M Sadeghioon', 'Sarah Hadley', 'Sarah Hinett', 'Kabir A Khan', 'Safiya Issa', 'Eileen Haycox', 'Jan Fiala', 'Nadia Parveen', 'Mona Vadher', 'Adam Kirk', 'Mohammed I Al Arfaj', 'Selina V Penarski', 'Eileen Harris']	.
# c307	Tuesday	9	12	CS217	Faisal Cheema
# ['Naveed Hussain', 'Syed M Ghufran', 'Sarah J Bradford', 'Sonia Zain', 'Sarah Dobson', 'Arsheen Rajpar', 'Rafal Szczypinski', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sarah J Roberts', 'Adam Kirk', 'Damian A Cummings', 'Sarah Nolasco', 'Sam D Edwards', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sarah E Kirkham-Slack', 'Mohamed F Bakaram', 'Omar S Aslam', 'Amir Ahmed', 'Mohammed A Suleman', 'Sam Dalgleish', 'Zahra Faraji Rad', 'Sam J Pottier', 'Naveed Hussain', 'Ayda Niazi', 'Sarah J Bradford', 'Nadia Parveen', 'Omar S Aslam', 'Sarah Armstrong', 'Zahir Hussain']	.
# c309	Tuesday	11	14	SS111	Behjat Zuhaira
# ['Amir Ahmed', 'Sarah R Young', 'Nabila Altaf', 'Salma Khanam', 'Shahzada S Niwaz', 'Mohammed A Suleman', 'Adam N Starling', 'Behzad Babakhani', 'Nadine Meyer', 'Anja Brezovnik', 'Salma Khanam', 'Nima Dirie', 'Shahzada S Niwaz', 'Salman Hassan Zadeh', 'Adam Selby', 'Nabila Altaf', 'Naseem Akram', 'Kamila Houdkova', 'Sarah Nolasco', 'Amber Summerfield', 'Aidan P Murphy', 'Farzana Yamin', 'Natasha Lelijveld', 'Babak Cheraghchi Bashi Astaneh', 'Behzad Babakhani', 'Rafal Szczypinski', 'Amir Ahmed', 'Sadra Keyhani', 'Amir Ahmed']	.
# c305	Tuesday	12	15	CS118	Mehwish Hassan
# ['Zainab Khattak', 'Jasmine Winyard', 'Safiya Issa', 'Zahra Faraji Rad', 'Mohamed A Baalousha', 'Shahina Parveen', 'Irfan Yousaf', 'Aras Panahian Jand', 'Jasmine Winyard', 'Babak Cheraghchi Bashi Astaneh', 'Shadan Mirarmandehi', 'Amber Summerfield', 'Sam Duncanson', 'Aidan P Murphy', 'Meltem Naylor', 'Bushra Duri', 'Zeenat K Guness-Goolbar', 'Faris Quaid', 'Salwa S Alobaid', 'Usman Rafiq', 'Sarah L Barber-Jones', 'Kamal Anwar', 'Tara Glickman', 'Sarah Hinett', 'Samar E Nassar', 'Faris Quaid', 'Ann Wilson', 'Yas Khaled', 'Ayan Lowe']	.
# c302	Tuesday	13	16	SS152	Sadia Nauman
# ['Adam N Starling', 'Sadra Keyhani', 'Sam J Pottier', 'Ann Tai', 'Mona Vadher', 'Sonia Zain', 'Yasir M Salih', 'Parastoo Jamshidi', 'Sarah Hinett', 'Yaser A Aljammaz', 'Jina Zhao', 'Ameerah Kasenally-Boodoo', 'Meryem Mehmetbasoglu', 'Kiran K Chahal', 'Adam C Ryan', 'Rafal Szczypinski', 'Sonia V Diaz', 'Sam D Edwards', 'Ibrahim Adegboye', 'Sarwar Hussain', 'Maria Lytras', 'Hassana Begum', 'Sarah Wilson', 'Iram Meharban', 'Maryam Askari Louyeh', 'Nausheen Saleem', 'Hassana Begum', 'Sam D Edwards', 'Zaki Choudhury']	.
# c307	Tuesday	14	17	MG223	Hassan Mustafa
# ...
# c303	Tuesday	10	13	DS3011	Sumera Abbas
# ['Sarah R Young', 'Ahmad F Yang Abd Talib', 'Sarah Fogg', 'Rafal Szczypinski', 'Sagar R Jilka', 'Sarah French', 'Sarah J Hammon', 'Mohamed A Baalousha', 'Negar Saleh', 'Sarina Patel', 'Maryam Askari Louyeh', 'Ahmed Ahmed', 'Ahmed Abbas Ahmed', 'Zaki Choudhury', 'Sarah Austin', 'Zaki Choudhury', 'Salman Hassan Zadeh', 'Asim Ali', 'Sarah Armstrong', 'Kabir A Khan', 'Ana B Javier Cuetos', 'Jina Zhao', 'Mohammad Abir', 'Bushra Duri', 'Mohammed A Suleman', 'Yasir M Salih', 'Meryem Mehmetbasoglu', 'Kabir A Khan', 'Kabir A Khan']	.
# c306	Tuesday	12	15	CS328	Khadija Farooq
# ['Hanna I Siahaan', 'Hazimah H Hj Hamzah', 'Sarah Nolasco', 'Natasha Leeson', 'Nina N Wronka', 'Sagar R Jilka', 'Aida Hoxha', 'Bahjat Al-Ani', 'Sarah Hadley', 'Sarah E Kirkham-Slack', 'Ana Vukojevic', 'Anja Brezovnik', 'Huda O Ali', 'Sarah Montgomery', 'Salwa S Alobaid', 'Naveed Hussain', 'Shahina Parveen', 'Zainab Khattak', 'Marwa Elcheikh', 'Aras Panahian Jand', 'Sarah Nolasco', 'Mohammed I Al Arfaj', 'Naseem Akram', 'Syed M Ghufran', 'Judi Glen', 'Mohammed Zafran', 'Behzad Babakhani', 'Mohammed Sukkari', 'Ameerah Kasenally-Boodoo']	.
# c307	Tuesday	12	15	SS152	Ejaz Ahmed
# ['Mohammed Sukkari', 'Aras Panahian Jand', 'Sarah Montgomery', 'Sadia Rehman', 'Mika Tatsumoto', 'Mohammed I Al Arfaj', 'Lilia Kyuchukova', 'Mika Tatsumoto', 'Zahra Faraji Rad', 'Sara Zamberlan', 'Ali M Sadeghioon', 'Sarah J Bradford', 'Usman Rafiq', 'Maria Antonia Morua Leyva', 'Adam Mickiewicz', 'Zainab Khattak', 'Yas Khaled', 'Hazimah H Hj Hamzah', 'Adam Flowers', 'Sarah Fogg', 'Natasha Leeson', 'Sarah J Bradford', 'Sam J Pottier', 'Natasha Tait', 'Sarah J Roberts', 'Zeenat K Guness-Goolbar', 'Zeenat K Guness-Goolbar', 'Meltem Naylor', 'Amber Summerfield']	.
# c301	Tuesday	14	17	EE229	Ayesha Bano
# ['Nausheen Saleem', 'Natasha J Seaward', 'Damian A Cummings', 'Leila C Payne', 'Sadia Rehman', 'Zainab Khattak', 'Zahra Faraji Rad', 'Adam Sanders', 'Mohammed Sukkari', 'Farzana Yamin', 'Ayan Lowe', 'Shahid Khan', 'Babak Cheraghchi Bashi Astaneh', 'Sarah J Roberts', 'Salwa S Alobaid', 'Meryem Mehmetbasoglu', 'Natasha J Seaward', 'Sonia V Diaz', 'Maysa Saeidi', 'Jenna Riley', 'Sam Dalgleish', 'Selina V Penarski', 'Shireen Dowlut-Beebeejaun', 'Behzad Babakhani', 'Damian A Cummings', 'Ayda Niazi', 'Ayan Lowe', 'Samina Akbar', 'Bushra Duri']	.
# c303	Tuesday	14	17	SS152	Shahzad Mehmood
# ['Tina Nasersharif', 'Sam J Pottier', 'Sara De La Serna', 'Adam N Starling', 'Anita Hodler', 'Ayda Niazi', 'Anja Brezovnik', 'Sarah J Bradford', 'Shari K Rasmussen', 'Faris Quaid', 'Zahra Faraji Rad', 'Adam Selby', 'Sam Isherwood', 'Maryam Askari Louyeh', 'Leila C Payne', 'Yasir M Salih', 'Seema Mandalia', 'Mohammed Z Albahar', 'Anita Hodler', 'Eileen Harris', 'Halima Sayed', 'Zahra Faraji Rad', 'Ann White', 'Parastoo Jamshidi', 'Muna Osman', 'Sarah Fogg', 'Iram Meharban', 'Sarah J Bradford', 'Salman Hassan Zadeh']	.
# c301	Wednesday	9	12	CS118	Waqas Munir
# ['Syed M Abbas', 'Sarah Austin', 'Selina V Penarski', 'Amir Ahmed', 'Naseem Akram', 'Bushra Duri', 'Sarah S Shahid', 'Ayda Niazi', 'Shadan Mirarmandehi', 'Amir Ahmed', 'Farzad Farahmand', 'Adam Flowers', 'Faheema Korumtollee', 'Anja Sarlah', 'Asim Ali', 'Selina V Penarski', 'Arooba Zahoor', 'Iram Matloob', 'Kamal Anwar', 'Siraj Shariff', 'Syed M Abbas', 'Ibrar Manawer', 'Hamza Bin Muhammad', 'Halima Sayed', 'Nina N Wronka', 'Sarah Fogg', 'Maria A Grenfell', 'Maria Lytras', 'Ibrahim Adegboye']	.
# c304	Wednesday	13	16	AI2011	Asif Naeem
# ['Kamila Keshubay', 'Mohamed F Bakaram', 'Tina Nasersharif', 'Mohammed A Suleman', 'Mohammed Sukkari', 'Selina V Penarski', 'Ibrahim Adegboye', 'Sarah H Przybylak', 'Soha Siahpoosh Kolyaei', 'Jenna Riley', 'Sam Duncanson', 'Mika Tatsumoto', 'Sajida Ayub', 'Behzad Babakhani', 'Zaki Choudhury', 'Naveed Hussain', 'Adam Green', 'Hazimah H Hj Hamzah', 'Kiran K Chahal', 'Farzad Farahmand', 'Ibrahim Adegboye', 'Aidan P Murphy', 'Mohammed Zafran', 'Syed M Abbas', 'Sarah N Md Sallehuddin Khan', 'Mohammed Sukkari', 'Ali M Sadeghioon', 'Sarah J Bradford', 'Omar Chaudhrey']	.
# c308	Thursday	9	12	CS219	Mehreen Alam
# ['Nausheen Saleem', 'Ayse Hatunoglu', 'Ana Sbert Ortin', 'Kabir A Khan', 'Mona Vadher', 'Dean Brodesky', 'Syed M Ghufran', 'Sonia Zain', 'Sarah Hanley', 'Mohammad Abir', 'Negar Saleh', 'Arman N Bahadori', 'Adam Mickiewicz', 'Ann Tai', 'Maria M Ponce Carpio', 'Leila C Payne', 'Halima Sayed', 'Maria Antonia Morua Leyva', 'Naseem Akram', 'Ann White', 'Maria Antonia Morua Leyva', 'Sarah Nolasco', 'Shahzada S Niwaz', 'Sarah Wilson', 'Farzana Yamin', 'Ana B Javier Cuetos', 'Sarah Montgomery', 'Sarah Hinett', 'Leanne M Taylor-Smith']	.
# c303	Thursday	9	12	CS118	Noreen Jamil
# ['Kamal Anwar', 'Ahmed Abbas Ahmed', 'Halima Sayed', 'Bahjat Al-Ani', 'Natasha Leeson', 'Adam C Ryan', 'Sarah Montgomery', 'Sarah Hanley', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Nausheen Saleem', 'Yaser A Aljammaz', 'Sarah H Przybylak', 'Aida Hoxha', 'Arman N Bahadori', 'Lilia Kyuchukova', 'Eileen Harris', 'Sam Duncanson', 'Sam Isherwood', 'Ramesh R Singh', 'Behzad Babakhani', 'Jina Zhao', 'Sarah J Bradford', 'Sarah H Przybylak', 'Maria Lytras', 'Saleem Abubacker', 'Sarah Wilson', 'Sarah Austin', 'Natasha Lelijveld', 'Zeenat K Guness-Goolbar']	.
# c303	Thursday	9	12	CS217	Irum Inayat
# ['Sarah Hanley', 'Arooba Zahoor', 'Parastoo Jamshidi', 'Natasha Edwards', 'Kiran K Chahal', 'Naseem Akram', 'Mohammad Abir', 'Zahir Hussain', 'Ann Tai', 'Damian A Cummings', 'Seema Mandalia', 'Sagar R Jilka', 'Shadan Mirarmandehi', 'Dalia Remeikyte', 'Mohammed Z Albahar', 'Adam Flowers', 'Sarah S Shahid', 'Sarah L Clark', 'Leanne M Taylor-Smith', 'Mohamed F Bakaram', 'Dean Brodesky', 'Zaki Choudhury', 'Shadan Mirarmandehi', 'Salma Khanam', 'Faris Quaid', 'Sam Dalgleish', 'Jina Zhao', 'Sarina Patel', 'Salwa S Alobaid']	.
# c310	Thursday	10	13	CS219	Adnan Tariq
# ['Bahjat Al-Ani', 'Nadia Parveen', 'Negar Saleh', 'Amir Ahmed', 'Asim Ali', 'Ahmed Abbas Ahmed', 'Ana B Javier Cuetos', 'Ahmad F Yang Abd Talib', 'Farzad Farahmand', 'Sam Dalgleish', 'Leila C Payne', 'Sam Isherwood', 'Ann White', 'Irfan Yousaf', 'Leyla Doroudi', 'Manal Aldaihani', 'Jan Fiala', 'Adam N Starling', 'Negar Saleh', 'Ann Wilson', 'Marwa Elcheikh', 'Tina Nasersharif', 'Shahina Parveen', 'Adam Green', 'Mohammed Z Albahar', 'Kamal Anwar', 'Mona Vadher', 'Ali M Sadeghioon', 'Natasha Tait']	.
# c310	Thursday	11	14	CY2012	Amna Irum
# ['Sarah French', 'Ana Vukojevic', 'Arman N Bahadori', 'Ali M Sadeghioon', 'Nima Dirie', 'Sarah J Roberts', 'Meltem Naylor', 'Bushra Duri', 'Maryam Askari Louyeh', 'Amber Summerfield', 'Kamila Keshubay', 'Dalia Remeikyte', 'Sarah Austin', 'Kamila Houdkova', 'Ana B Javier Cuetos', 'Shadan Alam', 'Maria Antonia Morua Leyva', 'Natasha Lelijveld', 'Sarah Armstrong', 'Sarah Nolasco', 'Sarina Patel', 'Sarah H Przybylak', 'Sarah Hewitt', 'Hazimah H Hj Hamzah', 'Abdul Gafur', 'Sarah Taylor', 'Ana Vukojevic', 'Mohammed Sukkari', 'Eileen Haycox']	.
# c310	Thursday	11	14	MG223	Shahzad Mehmood
# ['Zahra Faraji Rad', 'Farzad Farahmand', 'Nima Dirie', 'Mohammed Sukkari', 'Sarah J Roberts', 'Asim Ali', 'Faris Quaid', 'Nina N Wronka', 'Omar F Khan', 'Nausheen Saleem', 'Ayse Hatunoglu', 'Parastoo Jamshidi', 'Natasha Tait', 'Sarah E Kirkham-Slack', 'Omar F Khan', 'Adam Mickiewicz', 'Sarina Patel', 'Ali M Sadeghioon', 'Sarah J Bradford', 'Adam Green', 'Sarah J Roberts', 'Anja Sarlah', 'Samina Akbar', 'Samina Akbar', 'Zainab Khattak', 'Nabila Altaf', 'Natasha Tait', 'Sam Duncanson', 'Negar Saleh']	.
# c307	Thursday	11	14	CY2012	Farwa Batool
# ['Yasmin Ahmed', 'Bushra Duri', 'Omar S Aslam', 'Sarah J Hammon', 'Adam Green', 'Nabila Altaf', 'Bushra Duri', 'Bahjat Al-Ani', 'Sonia V Diaz', 'Sadia Rehman', 'Yas Khaled', 'Sarah Dobson', 'Imtiaz Kermali', 'Reem N Hassan', 'Sadia Rehman', 'Yasir M Salih', 'Maria Antonia Morua Leyva', 'Amber Summerfield', 'Reem N Hassan', 'Sarah J Bradford', 'Arooba Zahoor', 'Ana Sbert Ortin', 'Safiya Issa', 'Maria Lytras', 'Samar E Nassar', 'Anita Hodler', 'Mohammad Abir', 'Maria Antonia Morua Leyva', 'Yasmin Ahmed']	.
# c304	Thursday	11	14	SS111	Nagina Safdar
# ['Omar Chaudhrey', 'Meltem Naylor', 'Kamal Anwar', 'Leyla Doroudi', 'Meryem Mehmetbasoglu', 'Adam Flowers', 'Iram Meharban', 'Ann White', 'Aleena Unadkat', 'Rida Shaikh', 'Adam N Starling', 'Rafal Szczypinski', 'Aida Hoxha', 'Amber Summerfield', 'Adam L Finch', 'Aleena Unadkat', 'Adam Mickiewicz', 'Sarah S Shahid', 'Ayse Hatunoglu', 'Ibrar Manawer', 'Anja Brezovnik', 'Sarah Clements', 'Arsheen Rajpar', 'Salma Khanam', 'Mohammed I Al Arfaj', 'Sarah Montgomery', 'Jina Zhao', 'Adam Green', 'Omar S Aslam']	.
# c306	Thursday	11	14	CS211	Zohaib Iqbal
# ['Sarah Hadley', 'Natasha Edwards', 'Jina Zhao', 'Irfan Yousaf', 'Yaser A Aljammaz', 'Ayse Hatunoglu', 'Jasmine Winyard', 'Eileen Haycox', 'Mohamed F Bakaram', 'Sam J Pottier', 'Tina Nasersharif', 'Razan Z Haji Zulkifli', 'Damian A Cummings', 'Rida Shaikh', 'Ana Vukojevic', 'Hanna I Siahaan', 'Meryem Mehmetbasoglu', 'Shahina Parveen', 'Omar Chaudhrey', 'Shahzada S Niwaz', 'Jenna Riley', 'Yas Khaled', 'Siraj Shariff', 'Zahra Faraji Rad', 'Farzana Yamin', 'Zahir Hussain', 'Adam Sanders', 'Sarah Nolasco', 'Muna Osman']	.
# c309	Thursday	12	15	CS219	Rohail Gulbaz
# ['Bibi A Khan', 'Farzana Yamin', 'Salman Hassan Zadeh', 'Salwa S Alobaid', 'Hanna I Siahaan', 'Hanna I Siahaan', 'Saleem Abubacker', 'Sheila Hughton', 'Nabila Altaf', 'Jenna Riley', 'Sam D Edwards', 'Asim Ali', 'Kiran K Chahal', 'Dalia Remeikyte', 'Hassana Begum', 'Eileen Harris', 'Adam Flowers', 'Aidan P Murphy', 'Iram Meharban', 'Asim Ali', 'Ana Sbert Ortin', 'Maria M Ponce Carpio', 'Mohammed Zafran', 'Sam Isherwood', 'Arooba Zahoor', 'Ayse Hatunoglu', 'Anja Brezovnik', 'Sarah Wilson', 'Salma Khanam']	.
# c309	Thursday	13	16	CS219	Waqas Munir
# ['Marwa Elcheikh', 'Natasha Edwards', 'Yasmin Ahmed', 'Aleena Unadkat', 'Irfan Yousaf', 'Zahra Faraji Rad', 'Soha Siahpoosh Kolyaei', 'Sarah French', 'Behzad Babakhani', 'Sadia Rehman', 'Iram Matloob', 'Sarah Armstrong', 'Zainab Khattak', 'Shahid Khan', 'Tara Glickman', 'Sarah E Kirkham-Slack', 'Kamal Anwar', 'Ahmed Ahmed', 'Adam C Ryan', 'Huda O Ali', 'Zahra Faraji Rad', 'Anja Brezovnik', 'Iram Matloob', 'Sarah E Kirkham-Slack', 'Ayse Hatunoglu', 'Sagar R Jilka', 'Ayman Jaheen', 'Ahmed Abbas Ahmed', 'Rida Shaikh']	.
# c302	Thursday	13	16	CS211	Usman Ashraf
# ['Hassana Begum', 'Kamila Houdkova', 'Ayan Lowe', 'Usman Rafiq', 'Zainab Khattak', 'Hazimah H Hj Hamzah', 'Anja Sarlah', 'Sarina Patel', 'Syed M Ghufran', 'Shadan Mirarmandehi', 'Tara Glickman', 'Sarah E Kirkham-Slack', 'Natasha Lelijveld', 'Maria Lytras', 'Maysa Saeidi', 'Sarah Hewitt', 'Adam L Finch', 'Sam Duncanson', 'Muna Osman', 'Ana B Javier Cuetos', 'Sarah N Md Sallehuddin Khan', 'Arsheen Rajpar', 'Sara De La Serna', 'Parastoo Jamshidi', 'Lilia Kyuchukova', 'Ayda Niazi', 'Sadia Rehman', 'Sarah Armstrong', 'Ana Vukojevic']	.
# c308	Thursday	14	17	SS152	Zainab Abaid
# ['Babak Cheraghchi Bashi Astaneh', 'Samina Akbar', 'Ramesh R Singh', 'Nima Dirie', 'Sarah Hewitt', 'Mohamed F Bakaram', 'Nadia Parveen', 'Sagar R Jilka', 'Parastoo Jamshidi', 'Natasha Leeson', 'Zainab Khattak', 'Sarah J Hammon', 'Sarah Hinett', 'Faraj B Shaban', 'Aida Hoxha', 'Jina Zhao', 'Anja Sarlah', 'Mohammed Zafran', 'Nina N Wronka', 'Aida Hoxha', 'Zeenat K Guness-Goolbar', 'Sarah L Clark', 'Maria Lytras', 'Zahir Hussain', 'Ann Wilson', 'Adam N Starling', 'Sarah L Clark', 'Ana B Javier Cuetos', 'Kamila Houdkova']	.
# c301	Friday	11	14	DS3011	Tayyab Nadeem
# ['Salman Hassan Zadeh', 'Hazimah H Hj Hamzah', 'Ayan Lowe', 'Adam C Ryan', 'Sarah Hinett', 'Ann Wilson', 'Judi Glen', 'Eileen Haycox', 'Adam C Ryan', 'Nosheen Maqbool', 'Iram Matloob', 'Rida Shaikh', 'Nosheen Maqbool', 'Bahjat Al-Ani', 'Iram Meharban', 'Asim Ali', 'Salma Khanam', 'Muhammad Ijaz-Ul-Haq', 'Mohammed A Suleman', 'Nabila Altaf', 'Sarah Hanley', 'Natasha J Seaward', 'Sam J Pottier', 'Aras Panahian Jand', 'Lilia Kyuchukova', 'Sarah L Barber-Jones', 'Adam N Starling', 'Leanne M Taylor-Smith', 'Sadra Keyhani']	.
# c302	Friday	12	15	CS302	Hamda Khan
# ['Amir Ahmed', 'Lilia Kyuchukova', 'Sarah R Young', 'Dean Brodesky', 'Leyla Doroudi', 'Farzana Yamin', 'Omar F Khan', 'Muna Osman', 'Nadine Meyer', 'Sarah Hinett', 'Meryem Mehmetbasoglu', 'Mohamed A Baalousha', 'Shireen Dowlut-Beebeejaun', 'Maria Antonia Morua Leyva', 'Jina Zhao', 'Sarah Fogg', 'Zahra Faraji Rad', 'Selina V Penarski', 'Ann Wilson', 'Sarah J Roberts', 'Mohammed Sukkari', 'Shadan Alam', 'Adam N Starling', 'Sam D Edwards', 'Sonia Zain', 'Sarah French', 'Mohammed Zafran', 'Yas Khaled', 'Kamila Keshubay']	.
# c308	Friday	12	15	SS111	Hasan Mujtaba
# ['Sarah N Md Sallehuddin Khan', 'Farzad Farahmand', 'Sarah Dobson', 'Adam Selby', 'Adam Flowers', 'Negar Saleh', 'Bahjat Al-Ani', 'Aras Panahian Jand', 'Ana Vukojevic', 'Sarah Hewitt', 'Maria M Ponce Carpio', 'Faheema Korumtollee', 'Ayan Lowe', 'Irfan Yousaf', 'Nina N Wronka', 'Nabila Altaf', 'Anita Hodler', 'Nadia Parveen', 'Shireen Dowlut-Beebeejaun', 'Ayda Niazi', 'Asim Ali', 'Shahzada S Niwaz', 'Sarah L Clark', 'Muna Osman', 'Ana Vukojevic', 'Zeenat K Guness-Goolbar', 'Shahid Khan', 'Sarah J Bradford', 'Siraj Shariff']	.
# c302	Friday	13	16	SS113	Ayesha Bano
# ['Sarah S Shahid', 'Maria A Grenfell', 'Sarah J Roberts', 'Rida Shaikh', 'Bibi A Khan', 'Hassana Begum', 'Ahmed Ahmed', 'Soha Siahpoosh Kolyaei', 'Kamila Houdkova', 'Sarah Austin', 'Mohammed Sukkari', 'Sam Duncanson', 'Leyla Doroudi', 'Aida Hoxha', 'Dalia Remeikyte', 'Asim Ali', 'Meltem Naylor', 'Adam Kirk', 'Ana Sbert Ortin', 'Ann Wilson', 'Sarah Fogg', 'Natasha Lelijveld', 'Sarah Wilson', 'Ann White', 'Sam Duncanson', 'Hamza Bin Muhammad', 'Sarah S Shahid', 'Safiya Issa', 'Leyla Doroudi']	.
# c308	Friday	14	17	MT224	Tayyab Nadeem
# ['Mohammed A Suleman', 'Sarah S Shahid', 'Sarah J Bradford', 'Halima Sayed', 'Aras Panahian Jand', 'Razan Z Haji Zulkifli', 'Ahmad F Yang Abd Talib', 'Sarah Hewitt', 'Razan Z Haji Zulkifli', 'Ann D Brix', 'Leanne M Taylor-Smith', 'Mika Tatsumoto', 'Maysa Saeidi', 'Maria M Ponce Carpio', 'Damian A Cummings', 'Siraj Shariff', 'Ann White', 'Sarah J Bradford', 'Ayda Niazi', 'Anita Hodler', 'Sarah J Roberts', 'Sam Dalgleish', 'Seema Mandalia', 'Natasha Tait', 'Zahir Hussain', 'Mona Vadher', 'Adam Sanders', 'Sarah J Hammon', 'Jan Fiala']	.
# c305	Friday	14	17	CS220	Bilal Khalid
# ['Kamal Anwar', 'Mohammed A Suleman', 'Jasmine Winyard', 'Sonia Zain', 'Sarah H Przybylak', 'Nosheen Maqbool', 'Kabir A Khan', 'Razan Z Haji Zulkifli', 'Shahid Khan', 'Sadra Keyhani', 'Adam Flowers', 'Ayman Jaheen', 'Adam Selby', 'Natasha Edwards', 'Jan Fiala', 'Jina Zhao', 'Samar E Nassar', 'Adam L Finch', 'Yasir M Salih', 'Salwa S Alobaid', 'Adam L Finch', 'Omar Chaudhrey', 'Leyla Doroudi', 'Huda O Ali', 'Sarah Hanley', 'Jan Fiala', 'Marwa Elcheikh', 'Maysa Saeidi', 'Reem N Hassan']	.
# c306	Friday	14	17	SS111	Hammad Majeed
# ['Salwa S Alobaid', 'Irfan Yousaf', 'Sarah J Bradford', 'Dalia Remeikyte', 'Kamila Houdkova', 'Sajida Ayub', 'Sarwar Hussain', 'Jasmine Winyard', 'Leanne M Taylor-Smith', 'Selina V Penarski', 'Natasha Lelijveld', 'Natasha Edwards', 'Kiran K Chahal', 'Natasha J Seaward', 'Imtiaz Kermali', 'Kamal Anwar', 'Sam D Edwards', 'Ayse Hatunoglu', 'Mohamed F Bakaram', 'Anja Brezovnik', 'Natasha J Seaward', 'Razan Z Haji Zulkifli', 'Ann Tai', 'Usman Rafiq', 'Sarah E Kirkham-Slack', 'Mohamed A Baalousha', 'Sarah E Kirkham-Slack', 'Mohammed Sukkari', 'Sarah Austin']	.
# c309	Friday	14	17	CS328	Usman Rashid
# ['Halima Sayed', 'Manal Aldaihani', 'Zahra Faraji Rad', 'Seema Mandalia', 'Maysa Saeidi', 'Dalia Remeikyte', 'Damian A Cummings', 'Ann Tai', 'Arman N Bahadori', 'Ahmad F Yang Abd Talib', 'Sajida Ayub', 'Omar Chaudhrey', 'Ahmad F Yang Abd Talib', 'Damian A Cummings', 'Shahina Parveen', 'Zeenat K Guness-Goolbar', 'Jasmine Winyard', 'Dean Brodesky', 'Omar Chaudhrey', 'Ayman Jaheen', 'Shadan Alam', 'Sarah Nolasco', 'Faraj B Shaban', 'Syed M Abbas', 'Sadra Keyhani', 'Hassana Begum', 'Mohamed F Bakaram', 'Leila C Payne', 'Nabila Altaf']	.

# %% [markdown]
# # Selection

# %%
def roulette_wheel_selection(population):
    #     print ("I'm in roulette wheel!")

    maximum_val = sum(chromosome.fitness_value for chromosome in population)
    pick = random.uniform(0, maximum_val)
    current = 0

    mom, dad = None, None

    for chromosome in population:
        current += chromosome.fitness_value
        if current > pick:
            mom = chromosome
            break

    pick = random.uniform(0, maximum_val)
    current = 0
    for chromosome in population:
        current += chromosome.fitness_value
        if current > pick:
            dad = chromosome
            break

    if mom is None:
        mom = population[random.randint(0, len(population.chromosomes) - 1)]

    if dad is None:
        dad = population[random.randint(0, len(population.chromosomes) - 1)]

    return mom, dad


def elitism(population):
    max_index_1 = 0
    max_index_2 = 0
    max_fitness1 = 0
    max_fitness2 = 0

    for idx, individual in enumerate(population.chromosomes):
        if individual.fitness_value > max_fitness2:
            if individual.fitness_value > max_fitness1:
                max_fitness2 = max_fitness1
                max_index_2 = max_index_1
                max_fitness1 = individual.fitness_value
                max_index_1 = idx
            elif individual.fitness_value > max_fitness2:
                max_fitness2 = individual.fitness_value
                max_index_2 = idx

    return population[max_index_1], population[max_index_2]


def select_best_mom_and_dad(population):
    
    coin = random.randint(0, 1)

    if coin:
        ## Since we're instructed to do Roulette_wheel_selection...
        return roulette_wheel_selection(population)
    
    ## i g n o r e d
    return elitism(population)

# %%
new_pop = initialize_population()

for member in new_pop:
    member.fitness_value = random.randint(0,20)

mom,dad = select_best_mom_and_dad(new_pop)

print(" M O M ")

for gene in mom:
    print(gene)
        
print()
print(" D A D ") 

for gene in dad:
    print(gene)
# Out:
#  M O M
# c309	Monday	12	15	CS307	Hamda Khan
# ['Huda O Ali', 'Ahmed Ahmed', 'Salwa S Alobaid', 'Sara Zamberlan', 'Sam Isherwood', 'Arsheen Rajpar', 'Shahzada S Niwaz', 'Sagar R Jilka', 'Sarah Hewitt', 'Sarwar Hussain', 'Sarah Austin', 'Adam N Starling', 'Aidan P Murphy', 'Ann Wilson', 'Mohamed F Bakaram', 'Aras Panahian Jand', 'Ahmad F Yang Abd Talib', 'Aras Panahian Jand', 'Sarah Fogg', 'Amber Summerfield', 'Iram Meharban', 'Ann D Brix', 'Sagar R Jilka', 'Kamila Houdkova', 'Irfan Yousaf', 'Leyla Doroudi', 'Leila C Payne', 'Salma Khanam', 'Arman N Bahadori']	.
# c302	Thursday	11	14	MG220	Zohaib Iqbal
# ['Sarah J Hammon', 'Adam Selby', 'Kamal Anwar', 'Sarah E Kirkham-Slack', 'Omar S Aslam', 'Nabila Altaf', 'Faheema Korumtollee', 'Sam D Edwards', 'Natasha Tait', 'Syed M Abbas', 'Jina Zhao', 'Iram Meharban', 'Sarah J Bradford', 'Nadine Meyer', 'Dalia Remeikyte', 'Syed M Abbas', 'Mohammed A Suleman', 'Adam Selby', 'Iram Meharban', 'Sarah Nolasco', 'Meryem Mehmetbasoglu', 'Ali M Sadeghioon', 'Ramesh R Singh', 'Kiran K Chahal', 'Sarah Hadley', 'Arooba Zahoor', 'Anja Brezovnik', 'Sarah R Young', 'Adam N Starling']	.
# c307	Thursday	11	14	SS118	Noor ul Ain
# ['Tina Nasersharif', 'Ibrahim Adegboye', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sam J Pottier', 'Mohammed A Suleman', 'Irfan Yousaf', 'Farzad Farahmand', 'Sarah H Przybylak', 'Ann White', 'Tina Nasersharif', 'Ana Vukojevic', 'Sarah Hadley', 'Rafal Szczypinski', 'Hassana Begum', 'Mohammed A Suleman', 'Sarah R Young', 'Siraj Shariff', 'Halima Sayed', 'Ahmad F Yang Abd Talib', 'Arooba Zahoor', 'Nina N Wronka', 'Natasha Edwards', 'Adam Mickiewicz', 'Adam L Finch', 'Ahmed Ahmed', 'Jasmine Winyard', 'Natasha Tait', 'Shahzada S Niwaz', 'Sarah J Roberts']	.
# c310	Friday	9	12	SS111	Muhammad Asim
# ['Jasmine Winyard', 'Shahid Khan', 'Siraj Shariff', 'Ibrar Manawer', 'Sarah L Clark', 'Maysa Saeidi', 'Sarah Clements', 'Iram Meharban', 'Adam Selby', 'Abdul Gafur', 'Meryem Mehmetbasoglu', 'Samar E Nassar', 'Syed M Ghufran', 'Lilia Kyuchukova', 'Jenna Riley', 'Aleena Unadkat', 'Sarah Hanley', 'Maria Antonia Morua Leyva', 'Kamila Houdkova', 'Rida Shaikh', 'Anja Brezovnik', 'Sam Isherwood', 'Naveed Hussain', 'Sam Dalgleish', 'Sarah L Clark', 'Meryem Mehmetbasoglu', 'Hassana Begum', 'Marwa Elcheikh', 'Adam Flowers']	.
# c303	Wednesday	14	17	DS3011	Shafaq Riaz
# ['Mohammed Sukkari', 'Mohammed Zafran', 'Omar F Khan', 'Shahzada S Niwaz', 'Arman N Bahadori', 'Natasha J Seaward', 'Maria Lytras', 'Shadan Mirarmandehi', 'Selina V Penarski', 'Eileen Haycox', 'Faris Quaid', 'Natasha J Seaward', 'Hazimah H Hj Hamzah', 'Sarah Montgomery', 'Adam L Finch', 'Shadan Alam', 'Faheema Korumtollee', 'Ayse Hatunoglu', 'Sarah L Clark', 'Iram Meharban', 'Ibrahim Adegboye', 'Zaki Choudhury', 'Sarah Nolasco', 'Sarah J Roberts', 'Salma Khanam', 'Amber Summerfield', 'Natasha Edwards', 'Nadia Parveen', 'Mohammed Z Albahar']	.
# c308	Tuesday	9	12	MG220	Hammad Majeed
# ['Ann White', 'Sam Isherwood', 'Sarah Austin', 'Meltem Naylor', 'Zahir Hussain', 'Shahid Khan', 'Faris Quaid', 'Omar S Aslam', 'Sam Isherwood', 'Dalia Remeikyte', 'Maryam Askari Louyeh', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Aida Hoxha', 'Sarah Hewitt', 'Kamila Houdkova', 'Sarah Hewitt', 'Omar Chaudhrey', 'Dean Brodesky', 'Dean Brodesky', 'Sarah Austin', 'Jasmine Winyard', 'Syed M Ghufran', 'Kamal Anwar', 'Jenna Riley', 'Adam L Finch', 'Mohammed Sukkari', 'Nausheen Saleem', 'Salma Khanam', 'Usman Rafiq']	.
# c305	Wednesday	9	12	CS328	Amna Irum
# ['Zainab Khattak', 'Maria M Ponce Carpio', 'Maria Lytras', 'Yasir M Salih', 'Halima Sayed', 'Sarah Clements', 'Jan Fiala', 'Jina Zhao', 'Kamila Keshubay', 'Sonia Zain', 'Adam N Starling', 'Usman Rafiq', 'Sarah S Shahid', 'Farzad Farahmand', 'Marwa Elcheikh', 'Shahina Parveen', 'Meltem Naylor', 'Sarah Fogg', 'Sarah Montgomery', 'Sonia Zain', 'Mohammed Sukkari', 'Sajida Ayub', 'Razan Z Haji Zulkifli', 'Sadia Rehman', 'Mika Tatsumoto', 'Nadia Parveen', 'Zainab Khattak', 'Ayda Niazi', 'Ahmed Ahmed']	.
# c302	Tuesday	14	17	CS211	Bilal Khalid
# ['Farzana Yamin', 'Naveed Hussain', 'Nadine Meyer', 'Ahmad F Yang Abd Talib', 'Jina Zhao', 'Natasha J Seaward', 'Ana Sbert Ortin', 'Ana Sbert Ortin', 'Aras Panahian Jand', 'Ahmed Ahmed', 'Hazimah H Hj Hamzah', 'Jenna Riley', 'Eileen Harris', 'Yasmin Ahmed', 'Huda O Ali', 'Amir Ahmed', 'Sarah Nolasco', 'Nosheen Maqbool', 'Shadan Mirarmandehi', 'Faraj B Shaban', 'Iram Meharban', 'Mohamed F Bakaram', 'Yasir M Salih', 'Ahmed Abbas Ahmed', 'Hassana Begum', 'Ahmed Abbas Ahmed', 'Kiran K Chahal', 'Zainab Khattak', 'Shadan Alam']	.
# c307	Thursday	9	12	CS219	Kashif Munir
# ['Sarah L Barber-Jones', 'Sam Isherwood', 'Mohammed Z Albahar', 'Faheema Korumtollee', 'Kamila Houdkova', 'Sarina Patel', 'Sarwar Hussain', 'Soha Siahpoosh Kolyaei', 'Ann Wilson', 'Leila C Payne', 'Mohammed Zafran', 'Sarah R Young', 'Sarah J Bradford', 'Iram Meharban', 'Dean Brodesky', 'Amir Ahmed', 'Judi Glen', 'Maria Lytras', 'Ahmad F Yang Abd Talib', 'Nabila Altaf', 'Arsheen Rajpar', 'Arsheen Rajpar', 'Samar E Nassar', 'Ahmed Abbas Ahmed', 'Maria A Grenfell', 'Sam D Edwards', 'Sarah R Young', 'Manal Aldaihani', 'Leila C Payne']	.
# c308	Tuesday	14	17	SS152	Sumera Abbas
# ['Sarah H Przybylak', 'Faraj B Shaban', 'Zaki Choudhury', 'Sarah J Bradford', 'Ahmed Abbas Ahmed', 'Ayman Jaheen', 'Halima Sayed', 'Natasha J Seaward', 'Naseem Akram', 'Naseem Akram', 'Razan Z Haji Zulkifli', 'Zahir Hussain', 'Kamila Houdkova', 'Natasha Leeson', 'Nima Dirie', 'Nabila Altaf', 'Ayse Hatunoglu', 'Adam Mickiewicz', 'Amber Summerfield', 'Babak Cheraghchi Bashi Astaneh', 'Mika Tatsumoto', 'Ayda Niazi', 'Sarah Hadley', 'Jan Fiala', 'Naseem Akram', 'Rida Shaikh', 'Meryem Mehmetbasoglu', 'Adam Green', 'Shahina Parveen']	.
# c309	Friday	9	12	CS211	Shehreyar Rashid
# ['Muhammad Ijaz-Ul-Haq', 'Natasha Tait', 'Jina Zhao', 'Maysa Saeidi', 'Yasmin Ahmed', 'Anja Sarlah', 'Amber Summerfield', 'Yas Khaled', 'Sarah Montgomery', 'Ibrar Manawer', 'Selina V Penarski', 'Irfan Yousaf', 'Aida Hoxha', 'Sara De La Serna', 'Kamila Houdkova', 'Sarah French', 'Siraj Shariff', 'Salma Khanam', 'Mohamed A Baalousha', 'Ann White', 'Jina Zhao', 'Omar S Aslam', 'Samina Akbar', 'Mohammed Z Albahar', 'Shari K Rasmussen', 'Eileen Haycox', 'Natasha Edwards', 'Leanne M Taylor-Smith', 'Maria Antonia Morua Leyva']	.
# c308	Monday	10	13	EE229	Kifayat Ullah
# ['Sheila Hughton', 'Asim Ali', 'Farzad Farahmand', 'Kiran K Chahal', 'Sarah Dobson', 'Shahzada S Niwaz', 'Shahid Khan', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Leyla Doroudi', 'Hazimah H Hj Hamzah', 'Sajida Ayub', 'Zahra Faraji Rad', 'Syed M Abbas', 'Damian A Cummings', 'Nausheen Saleem', 'Sarah Fogg', 'Shari K Rasmussen', 'Hazimah H Hj Hamzah', 'Anita Hodler', 'Leanne M Taylor-Smith', 'Aleena Unadkat', 'Adam Green', 'Nausheen Saleem', 'Leyla Doroudi', 'Salma Khanam', 'Syed M Abbas', 'Salma Khanam', 'Adam Flowers', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub']	.
# c302	Wednesday	14	17	SS152	Shoaib Mehboob
# ['Kamal Anwar', 'Ibrar Manawer', 'Maria Antonia Morua Leyva', 'Sarah L Barber-Jones', 'Samar E Nassar', 'Marwa Elcheikh', 'Samar E Nassar', 'Sarah Fogg', 'Kamila Houdkova', 'Adam L Finch', 'Naveed Hussain', 'Ann White', 'Soha Siahpoosh Kolyaei', 'Shireen Dowlut-Beebeejaun', 'Natasha Lelijveld', 'Anja Brezovnik', 'Sara Zamberlan', 'Behzad Babakhani', 'Hassana Begum', 'Yas Khaled', 'Lilia Kyuchukova', 'Shahina Parveen', 'Syed M Ghufran', 'Sarah Hanley', 'Leila C Payne', 'Sarah Taylor', 'Sarah L Clark', 'Maria M Ponce Carpio', 'Behzad Babakhani']	.
# c307	Wednesday	10	13	SS118	Hassan Raza
# ['Arsheen Rajpar', 'Sarah J Hammon', 'Sarah Armstrong', 'Ann D Brix', 'Anita Hodler', 'Nausheen Saleem', 'Marwa Elcheikh', 'Tara Glickman', 'Salma Khanam', 'Omar Chaudhrey', 'Zahra Faraji Rad', 'Sarina Patel', 'Ahmed Ahmed', 'Yasir M Salih', 'Mohammed I Al Arfaj', 'Naseem Akram', 'Jasmine Winyard', 'Zainab Khattak', 'Adam Mickiewicz', 'Ahmed Abbas Ahmed', 'Eileen Haycox', 'Hanna I Siahaan', 'Ann D Brix', 'Ann White', 'Mohammed Z Albahar', 'Shahid Khan', 'Leila C Payne', 'Hazimah H Hj Hamzah', 'Reem N Hassan']	.
# c309	Wednesday	9	12	MG220	Ameen Chilwan
# ['Sarah Nolasco', 'Jina Zhao', 'Nadine Meyer', 'Bahjat Al-Ani', 'Sarah Dobson', 'Natasha J Seaward', 'Kiran K Chahal', 'Halima Sayed', 'Sadra Keyhani', 'Adam Green', 'Ayman Jaheen', 'Zainab Khattak', 'Hassana Begum', 'Ann D Brix', 'Syed M Ghufran', 'Ayman Jaheen', 'Samina Akbar', 'Maria Lytras', 'Adam Selby', 'Sarah Austin', 'Sarah S Shahid', 'Adam Selby', 'Arsheen Rajpar', 'Ahmad F Yang Abd Talib', 'Natasha Leeson', 'Faheema Korumtollee', 'Mohammed Z Albahar', 'Saleem Abubacker', 'Natasha Leeson']	.
# c310	Friday	12	15	EE227	Mehwish Hassan
# ['Soha Siahpoosh Kolyaei', 'Amber Summerfield', 'Hamza Bin Muhammad', 'Muhammad Ijaz-Ul-Haq', 'Adam Sanders', 'Aras Panahian Jand', 'Faheema Korumtollee', 'Adam Green', 'Ann Tai', 'Zaki Choudhury', 'Sam Dalgleish', 'Mona Vadher', 'Shahzada S Niwaz', 'Maria Antonia Morua Leyva', 'Judi Glen', 'Sam Isherwood', 'Sarah Hadley', 'Tina Nasersharif', 'Aida Hoxha', 'Negar Saleh', 'Sarah Hanley', 'Sarina Patel', 'Samina Akbar', 'Maryam Askari Louyeh', 'Selina V Penarski', 'Yas Khaled', 'Selina V Penarski', 'Salwa S Alobaid', 'Maria M Ponce Carpio']	.
# c304	Friday	14	17	SS113	Muhammad Usman
# ['Sonia V Diaz', 'Bahjat Al-Ani', 'Aleena Unadkat', 'Salma Khanam', 'Muhammad Ijaz-Ul-Haq', 'Ann D Brix', 'Nadine Meyer', 'Amir Ahmed', 'Ann Wilson', 'Sarah Fogg', 'Kamal Anwar', 'Adam Kirk', 'Jasmine Winyard', 'Sam Isherwood', 'Samina Akbar', 'Bibi A Khan', 'Ahmed Abbas Ahmed', 'Salman Hassan Zadeh', 'Sara De La Serna', 'Leyla Doroudi', 'Anita Hodler', 'Mohammed Z Albahar', 'Judi Glen', 'Judi Glen', 'Hanna I Siahaan', 'Ahmed Ahmed', 'Leanne M Taylor-Smith', 'Shari K Rasmussen', 'Reem N Hassan']	.
# c306	Tuesday	13	16	MG220	Amna Irum
# ['Syed M Abbas', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Rida Shaikh', 'Behzad Babakhani', 'Adam L Finch', 'Ann Tai', 'Adam Sanders', 'Mohammed Zafran', 'Amir Ahmed', 'Yas Khaled', 'Samar E Nassar', 'Naveed Hussain', 'Huda O Ali', 'Amir Ahmed', 'Ana Sbert Ortin', 'Behzad Babakhani', 'Shahid Khan', 'Natasha Lelijveld', 'Nina N Wronka', 'Sarah L Barber-Jones', 'Sarah N Md Sallehuddin Khan', 'Sarah R Young', 'Sadia Rehman', 'Sonia Zain', 'Ann Tai', 'Mohamed A Baalousha', 'Adam C Ryan', 'Meryem Mehmetbasoglu', 'Nima Dirie']	.
# c308	Friday	12	15	CS118	Noor ul Ain
# ['Leyla Doroudi', 'Yasir M Salih', 'Naseem Akram', 'Yaser A Aljammaz', 'Adam L Finch', 'Amber Summerfield', 'Sam Isherwood', 'Sadia Rehman', 'Mohammed Sukkari', 'Halima Sayed', 'Sarah R Young', 'Ann Tai', 'Yas Khaled', 'Samina Akbar', 'Mohammed A Suleman', 'Sarah Clements', 'Shari K Rasmussen', 'Sarah Nolasco', 'Samina Akbar', 'Saleem Abubacker', 'Shahzada S Niwaz', 'Nosheen Maqbool', 'Farzana Yamin', 'Yaser A Aljammaz', 'Sarah Hadley', 'Ann Wilson', 'Babak Cheraghchi Bashi Astaneh', 'Tina Nasersharif', 'Mohammed A Suleman']	.
# c306	Monday	14	17	CS220	Hassan Mustafa
# ['Zahir Hussain', 'Manal Aldaihani', 'Naseem Akram', 'Mohammed Sukkari', 'Maria A Grenfell', 'Sarah Wilson', 'Dean Brodesky', 'Hazimah H Hj Hamzah', 'Rafal Szczypinski', 'Omar Chaudhrey', 'Natasha J Seaward', 'Eileen Harris', 'Samar E Nassar', 'Mohammed Sukkari', 'Meltem Naylor', 'Rida Shaikh', 'Zainab Khattak', 'Sarah Austin', 'Salwa S Alobaid', 'Kiran K Chahal', 'Sara Zamberlan', 'Aras Panahian Jand', 'Meryem Mehmetbasoglu', 'Ahmed Abbas Ahmed', 'Eileen Harris', 'Sarah N Md Sallehuddin Khan', 'Tara Glickman', 'Manal Aldaihani', 'Salma Khanam']	.
# c310	Friday	13	16	CS328	Shehreyar Rashid
# ['Sarah French', 'Saleem Abubacker', 'Amber Summerfield', 'Syed M Abbas', 'Sagar R Jilka', 'Natasha Lelijveld', 'Samina Akbar', 'Mohammad Abir', 'Maria Antonia Morua Leyva', 'Judi Glen', 'Jan Fiala', 'Natasha J Seaward', 'Reem N Hassan', 'Sam Duncanson', 'Judi Glen', 'Yas Khaled', 'Shireen Dowlut-Beebeejaun', 'Tina Nasersharif', 'Adam Mickiewicz', 'Ana Sbert Ortin', 'Sonia Zain', 'Sarah J Roberts', 'Behzad Babakhani', 'Yaser A Aljammaz', 'Eileen Harris', 'Anja Sarlah', 'Sam Isherwood', 'Ibrar Manawer', 'Ayse Hatunoglu']	.
# c305	Thursday	10	13	CS220	Waseem Shahzad
# ['Aida Hoxha', 'Maryam Askari Louyeh', 'Shahid Khan', 'Sarah Dobson', 'Sarah French', 'Sarah Austin', 'Sam Duncanson', 'Zahir Hussain', 'Eileen Haycox', 'Bahjat Al-Ani', 'Sarah H Przybylak', 'Ana Sbert Ortin', 'Sarah L Clark', 'Ayse Hatunoglu', 'Tina Nasersharif', 'Sara De La Serna', 'Sam Dalgleish', 'Sarah N Md Sallehuddin Khan', 'Dalia Remeikyte', 'Ann Wilson', 'Hamza Bin Muhammad', 'Mohamed F Bakaram', 'Babak Cheraghchi Bashi Astaneh', 'Ramesh R Singh', 'Mohammed Zafran', 'Adam Green', 'Samar E Nassar', 'Sarah Hewitt', 'Adam Selby']	.
# c309	Friday	13	16	EE229	Muhammad Usman
# ['Ibrar Manawer', 'Natasha Leeson', 'Bahjat Al-Ani', 'Eileen Haycox', 'Meltem Naylor', 'Adam Mickiewicz', 'Lilia Kyuchukova', 'Sarah E Kirkham-Slack', 'Asim Ali', 'Kamila Houdkova', 'Zahra Faraji Rad', 'Adam C Ryan', 'Nina N Wronka', 'Sam D Edwards', 'Ana Sbert Ortin', 'Dean Brodesky', 'Natasha Edwards', 'Sara Zamberlan', 'Leyla Doroudi', 'Maria M Ponce Carpio', 'Sarah Austin', 'Nadia Parveen', 'Reem N Hassan', 'Sarah Hinett', 'Jenna Riley', 'Halima Sayed', 'Sarah Hinett', 'Hamza Bin Muhammad', 'Safiya Issa']	.
# c301	Monday	11	14	SE110	Kashif Munir
# ['Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sarina Patel', 'Sarah N Md Sallehuddin Khan', 'Mika Tatsumoto', 'Mohammed I Al Arfaj', 'Amir Ahmed', 'Sarah L Clark', 'Halima Sayed', 'Adam Mickiewicz', 'Sarah Austin', 'Razan Z Haji Zulkifli', 'Ana Sbert Ortin', 'Natasha Lelijveld', 'Sarah Montgomery', 'Maria Lytras', 'Sarah Taylor', 'Sadia Rehman', 'Eileen Haycox', 'Imtiaz Kermali', 'Ramesh R Singh', 'Adam Green', 'Shireen Dowlut-Beebeejaun', 'Shireen Dowlut-Beebeejaun', 'Ayda Niazi', 'Samar E Nassar', 'Adam Flowers', 'Syed M Ghufran', 'Yas Khaled', 'Tina Nasersharif']	.
# c309	Wednesday	14	17	CS220	Waseem Shahzad
# ['Sarah Montgomery', 'Shadan Alam', 'Kamila Houdkova', 'Salman Hassan Zadeh', 'Amir Ahmed', 'Ali M Sadeghioon', 'Ann D Brix', 'Abdul Gafur', 'Nadia Parveen', 'Sam D Edwards', 'Abdul Gafur', 'Hanna I Siahaan', 'Leila C Payne', 'Kiran K Chahal', 'Abdul Gafur', 'Sam Dalgleish', 'Maria M Ponce Carpio', 'Sarah N Md Sallehuddin Khan', 'Soha Siahpoosh Kolyaei', 'Muna Osman', 'Mohammed Sukkari', 'Tina Nasersharif', 'Sadra Keyhani', 'Zainab Khattak', 'Sarah Wilson', 'Sarah Dobson', 'Sarina Patel', 'Sarah Hanley', 'Jenna Riley']	.
# c301	Thursday	13	16	EE229	Muhammad Asim
# ['Shahzada S Niwaz', 'Yasir M Salih', 'Sarah French', 'Mohammed Zafran', 'Ahmed Abbas Ahmed', 'Iram Matloob', 'Soha Siahpoosh Kolyaei', 'Sarah Hinett', 'Rida Shaikh', 'Tara Glickman', 'Sarah S Shahid', 'Sam Duncanson', 'Marwa Elcheikh', 'Natasha Leeson', 'Safiya Issa', 'Amir Ahmed', 'Sarah S Shahid', 'Ana B Javier Cuetos', 'Sam Dalgleish', 'Yasir M Salih', 'Maria Lytras', 'Zahra Faraji Rad', 'Muna Osman', 'Marwa Elcheikh', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Adam L Finch', 'Muhammad Ijaz-Ul-Haq', 'Natasha Edwards', 'Marwa Elcheikh']	.
# c310	Tuesday	10	13	SS118	Khadija Farooq
# ['Maria A Grenfell', 'Tara Glickman', 'Seema Mandalia', 'Sarah J Hammon', 'Maryam Askari Louyeh', 'Ann Tai', 'Jasmine Winyard', 'Sam Dalgleish', 'Naveed Hussain', 'Damian A Cummings', 'Eileen Harris', 'Yasir M Salih', 'Parastoo Jamshidi', 'Hamza Bin Muhammad', 'Mohammed Z Albahar', 'Sarah Armstrong', 'Sarah J Roberts', 'Sam Dalgleish', 'Sajida Ayub', 'Sarah Dobson', 'Mika Tatsumoto', 'Zeenat K Guness-Goolbar', 'Sarah Clements', 'Bibi A Khan', 'Adam Sanders', 'Ayse Hatunoglu', 'Sam D Edwards', 'Damian A Cummings', 'Ana B Javier Cuetos']	.
# c303	Monday	13	16	CS211	Farwa Batool
# ['Yasmin Ahmed', 'Seema Mandalia', 'Ana Sbert Ortin', 'Maria M Ponce Carpio', 'Usman Rafiq', 'Ann D Brix', 'Zeenat K Guness-Goolbar', 'Sarah Hinett', 'Bushra Duri', 'Sonia Zain', 'Sarah S Shahid', 'Marwa Elcheikh', 'Jasmine Winyard', 'Sara De La Serna', 'Jasmine Winyard', 'Marwa Elcheikh', 'Kamal Anwar', 'Imtiaz Kermali', 'Adam Sanders', 'Sarah French', 'Nina N Wronka', 'Anja Brezovnik', 'Maria M Ponce Carpio', 'Nadia Parveen', 'Ann Tai', 'Sam J Pottier', 'Sarah N Md Sallehuddin Khan', 'Saleem Abubacker', 'Sarah J Roberts']	.
# c310	Wednesday	14	17	EE227	Asma Nisa
# ['Sarah Fogg', 'Arooba Zahoor', 'Sara De La Serna', 'Ahmed Abbas Ahmed', 'Selina V Penarski', 'Aleena Unadkat', 'Adam C Ryan', 'Sarah Montgomery', 'Manal Aldaihani', 'Yasmin Ahmed', 'Huda O Ali', 'Iram Meharban', 'Babak Cheraghchi Bashi Astaneh', 'Bahjat Al-Ani', 'Mohamed F Bakaram', 'Ahmad F Yang Abd Talib', 'Ana Sbert Ortin', 'Anita Hodler', 'Leyla Doroudi', 'Adam Flowers', 'Rida Shaikh', 'Ibrahim Adegboye', 'Jan Fiala', 'Salman Hassan Zadeh', 'Shahid Khan', 'Sheila Hughton', 'Sarah Dobson', 'Hassana Begum', 'Dalia Remeikyte']	.
# c301	Friday	11	14	CS220	Shoaib Mehboob
# ['Mohamed F Bakaram', 'Parastoo Jamshidi', 'Natasha Leeson', 'Bahjat Al-Ani', 'Bahjat Al-Ani', 'Irfan Yousaf', 'Naseem Akram', 'Mohamed F Bakaram', 'Shahid Khan', 'Adam Selby', 'Babak Cheraghchi Bashi Astaneh', 'Arman N Bahadori', 'Mohammed A Suleman', 'Sarah J Hammon', 'Ann Tai', 'Sarah L Barber-Jones', 'Omar F Khan', 'Sarina Patel', 'Faris Quaid', 'Jenna Riley', 'Natasha Edwards', 'Sarwar Hussain', 'Sam Dalgleish', 'Judi Glen', 'Ibrahim Adegboye', 'Sarah J Hammon', 'Sarah Taylor', 'Sarah Hanley', 'Mohammed Z Albahar']	.
# c304	Friday	10	13	SS118	Hassan Raza
# ['Shahzada S Niwaz', 'Naveed Hussain', 'Maria A Grenfell', 'Adam N Starling', 'Anja Brezovnik', 'Soha Siahpoosh Kolyaei', 'Kamila Houdkova', 'Sam J Pottier', 'Arsheen Rajpar', 'Ayan Lowe', 'Nima Dirie', 'Saleem Abubacker', 'Adam N Starling', 'Sarah Hanley', 'Sarah Austin', 'Adam Kirk', 'Adam Kirk', 'Imtiaz Kermali', 'Yasir M Salih', 'Rafal Szczypinski', 'Sadia Rehman', 'Sarah Armstrong', 'Yas Khaled', 'Usman Rafiq', 'Sarah R Young', 'Hamza Bin Muhammad', 'Sam Dalgleish', 'Ahmed Abbas Ahmed', 'Safiya Issa']	.
# c304	Monday	11	14	EE229	Mehboobullah
# ['Yaser A Aljammaz', 'Ayan Lowe', 'Mohammed A Suleman', 'Reem N Hassan', 'Sarah Hinett', 'Adam N Starling', 'Zaki Choudhury', 'Irfan Yousaf', 'Naveed Hussain', 'Aidan P Murphy', 'Sarah Hanley', 'Yasir M Salih', 'Maria A Grenfell', 'Amber Summerfield', 'Sam D Edwards', 'Shadan Alam', 'Soha Siahpoosh Kolyaei', 'Amber Summerfield', 'Kabir A Khan', 'Sarah J Hammon', 'Anita Hodler', 'Maryam Askari Louyeh', 'Naveed Hussain', 'Zaki Choudhury', 'Anja Brezovnik', 'Sarah Hanley', 'Amber Summerfield', 'Soha Siahpoosh Kolyaei', 'Nima Dirie']	.
# c309	Thursday	14	17	MT224	Farah Jabeen Awan
# ['Marwa Elcheikh', 'Ann Tai', 'Imtiaz Kermali', 'Sarah J Hammon', 'Muhammad Ijaz-Ul-Haq', 'Jan Fiala', 'Nadine Meyer', 'Jenna Riley', 'Mona Vadher', 'Rafal Szczypinski', 'Babak Cheraghchi Bashi Astaneh', 'Jasmine Winyard', 'Aidan P Murphy', 'Adam Mickiewicz', 'Hazimah H Hj Hamzah', 'Imtiaz Kermali', 'Yasir M Salih', 'Shahzada S Niwaz', 'Sonia V Diaz', 'Hassana Begum', 'Natasha Leeson', 'Ameerah Kasenally-Boodoo', 'Ana Vukojevic', 'Ayse Hatunoglu', 'Zahra Faraji Rad', 'Nadine Meyer', 'Ayda Niazi', 'Ameerah Kasenally-Boodoo', 'Anita Hodler']	.
# c301	Tuesday	11	14	EE229	Noreen Jamil
# ['Lilia Kyuchukova', 'Natasha Edwards', 'Sonia Zain', 'Faris Quaid', 'Natasha Edwards', 'Sarah R Young', 'Sarah Hewitt', 'Zeenat K Guness-Goolbar', 'Tara Glickman', 'Safiya Issa', 'Adam Selby', 'Naseem Akram', 'Adam N Starling', 'Omar Chaudhrey', 'Negar Saleh', 'Behzad Babakhani', 'Sam J Pottier', 'Anja Sarlah', 'Rafal Szczypinski', 'Sarah Montgomery', 'Shahina Parveen', 'Bibi A Khan', 'Ibrahim Adegboye', 'Maria Antonia Morua Leyva', 'Eileen Haycox', 'Nadia Parveen', 'Adam L Finch', 'Samar E Nassar', 'Ayda Niazi']	.
# c310	Tuesday	9	12	MG220	Behjat Zuhaira
# ['Tara Glickman', 'Arsheen Rajpar', 'Ibrahim Adegboye', 'Hanna I Siahaan', 'Adam C Ryan', 'Omar S Aslam', 'Sarah Armstrong', 'Samina Akbar', 'Sarah Dobson', 'Yasir M Salih', 'Ann Tai', 'Huda O Ali', 'Rafal Szczypinski', 'Maria M Ponce Carpio', 'Amber Summerfield', 'Aleena Unadkat', 'Shahzada S Niwaz', 'Sam Duncanson', 'Sonia Zain', 'Ayse Hatunoglu', 'Parastoo Jamshidi', 'Natasha Lelijveld', 'Samar E Nassar', 'Maria M Ponce Carpio', 'Sarah Montgomery', 'Ann D Brix', 'Ana Sbert Ortin', 'Eileen Harris', 'Sonia Zain']	.
# c308	Thursday	10	13	AI2011	Umair Arshad
# ['Kamila Houdkova', 'Mika Tatsumoto', 'Safiya Issa', 'Ann D Brix', 'Saleem Abubacker', 'Anja Sarlah', 'Ali M Sadeghioon', 'Sarah H Przybylak', 'Faraj B Shaban', 'Adam Kirk', 'Ana Vukojevic', 'Sarah Dobson', 'Sadia Rehman', 'Ana Vukojevic', 'Leanne M Taylor-Smith', 'Sarah R Young', 'Sarah E Kirkham-Slack', 'Sadra Keyhani', 'Meltem Naylor', 'Babak Cheraghchi Bashi Astaneh', 'Meryem Mehmetbasoglu', 'Zahir Hussain', 'Yaser A Aljammaz', 'Nabila Altaf', 'Natasha Leeson', 'Sam Duncanson', 'Meryem Mehmetbasoglu', 'Marwa Elcheikh', 'Hamza Bin Muhammad']	.
# c302	Tuesday	14	17	SS111	Shafaq Riaz
# ['Omar S Aslam', 'Adam L Finch', 'Sara Zamberlan', 'Sarah J Hammon', 'Amber Summerfield', 'Adam L Finch', 'Yasmin Ahmed', 'Usman Rafiq', 'Adam Green', 'Ana B Javier Cuetos', 'Meryem Mehmetbasoglu', 'Adam Sanders', 'Aida Hoxha', 'Tina Nasersharif', 'Sarah Dobson', 'Adam C Ryan', 'Natasha J Seaward', 'Sarah Hadley', 'Halima Sayed', 'Maysa Saeidi', 'Sara Zamberlan', 'Maria A Grenfell', 'Usman Rafiq', 'Leyla Doroudi', 'Sonia Zain', 'Adam Kirk', 'Shahid Khan', 'Mika Tatsumoto', 'Sara De La Serna']	.
# c309	Thursday	11	14	CS217	Subhan Ullah
# ['Ana B Javier Cuetos', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Sarah S Shahid', 'Mohammed I Al Arfaj', 'Tina Nasersharif', 'Soha Siahpoosh Kolyaei', 'Siraj Shariff', 'Sarah Armstrong', 'Seema Mandalia', 'Farzad Farahmand', 'Hanna I Siahaan', 'Adam Kirk', 'Behzad Babakhani', 'Ayan Lowe', 'Salma Khanam', 'Eileen Harris', 'Natasha Lelijveld', 'Adam Kirk', 'Naveed Hussain', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Jina Zhao', 'Bibi A Khan', 'Ana B Javier Cuetos', 'Jina Zhao', 'Sonia Zain', 'Salma Khanam', 'Samina Akbar', 'Salman Hassan Zadeh', 'Faraj B Shaban']	.
# c310	Wednesday	12	15	SS152	Maheen Arshad
# ['Sarah Montgomery', 'Sam Dalgleish', 'Jina Zhao', 'Mohamed A Baalousha', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Ali M Sadeghioon', 'Yaser A Aljammaz', 'Kamal Anwar', 'Maria Lytras', 'Rafal Szczypinski', 'Sam Duncanson', 'Faraj B Shaban', 'Natasha Lelijveld', 'Razan Z Haji Zulkifli', 'Mohammad Abir', 'Arman N Bahadori', 'Salwa S Alobaid', 'Zahir Hussain', 'Omar Chaudhrey', 'Aras Panahian Jand', 'Bibi A Khan', 'Sarah Hinett', 'Natasha Tait', 'Razan Z Haji Zulkifli', 'Adam Flowers', 'Kamila Houdkova', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Dalia Remeikyte', 'Omar S Aslam']	.
# c302	Friday	12	15	CS211	Zohaib Iqbal
# ['Salma Khanam', 'Leanne M Taylor-Smith', 'Shahid Khan', 'Maria Lytras', 'Maria Antonia Morua Leyva', 'Ana Vukojevic', 'Imtiaz Kermali', 'Eileen Harris', 'Zahir Hussain', 'Amber Summerfield', 'Sheila Hughton', 'Sarah Fogg', 'Natasha Leeson', 'Adam Flowers', 'Aleena Unadkat', 'Selina V Penarski', 'Sarah J Hammon', 'Aida Hoxha', 'Syed M Ghufran', 'Mohammed A Suleman', 'Sarah L Barber-Jones', 'Faraj B Shaban', 'Sarah J Bradford', 'Tara Glickman', 'Eileen Haycox', 'Jasmine Winyard', 'Faheema Korumtollee', 'Eileen Haycox', 'Sarah S Shahid']	.
# c309	Thursday	14	17	CS219	Sumera Abbas
# ['Ann D Brix', 'Negar Saleh', 'Zaki Choudhury', 'Adam N Starling', 'Eileen Harris', 'Zahra Faraji Rad', 'Natasha Leeson', 'Sajida Ayub', 'Hazimah H Hj Hamzah', 'Nina N Wronka', 'Nadine Meyer', 'Adam C Ryan', 'Shadan Alam', 'Tina Nasersharif', 'Sarah Armstrong', 'Ahmad F Yang Abd Talib', 'Mohammed Sukkari', 'Damian A Cummings', 'Sarah French', 'Ana Sbert Ortin', 'Ann Tai', 'Sarah J Roberts', 'Sarah L Clark', 'Zahra Faraji Rad', 'Sarah Hadley', 'Ramesh R Singh', 'Nadia Parveen', 'Meryem Mehmetbasoglu', 'Sarwar Hussain']	.
# c301	Monday	12	15	CY2012	Javaria Imtiaz
# ['Ana Vukojevic', 'Dalia Remeikyte', 'Natasha Lelijveld', 'Adam L Finch', 'Adam Green', 'Sam Dalgleish', 'Sadra Keyhani', 'Ramesh R Singh', 'Shadan Mirarmandehi', 'Faraj B Shaban', 'Natasha Leeson', 'Sarah R Young', 'Mohammed I Al Arfaj', 'Ali M Sadeghioon', 'Kiran K Chahal', 'Rida Shaikh', 'Natasha Lelijveld', 'Ayan Lowe', 'Sarah Wilson', 'Asim Ali', 'Damian A Cummings', 'Omar S Aslam', 'Kamila Keshubay', 'Maria A Grenfell', 'Sarah Montgomery', 'Eileen Harris', 'Farzana Yamin', 'Sam D Edwards', 'Hazimah H Hj Hamzah']	.
# c304	Wednesday	9	12	CS211	Tayyab Nadeem
# ['Faris Quaid', 'Leanne M Taylor-Smith', 'Sajida Ayub', 'Yas Khaled', 'Sarah Hewitt', 'Ana Sbert Ortin', 'Omar Chaudhrey', 'Bibi A Khan', 'Adam Kirk', 'Saleem Abubacker', 'Omar S Aslam', 'Sam Dalgleish', 'Natasha Edwards', 'Arman N Bahadori', 'Ana Sbert Ortin', 'Natasha Lelijveld', 'Mohamed F Bakaram', 'Sarah N Md Sallehuddin Khan', 'Ana Sbert Ortin', 'Mohammed Z Albahar', 'Sarah N Md Sallehuddin Khan', 'Safiya Issa', 'Adam N Starling', 'Mohammed Z Albahar', 'Nabila Altaf', 'Maria Lytras', 'Sarah Taylor', 'Sarah L Clark', 'Aidan P Murphy']	.
# c302	Wednesday	10	13	CS118	Ameen Chilwan
# ['Sarah J Bradford', 'Maria A Grenfell', 'Maria M Ponce Carpio', 'Amber Summerfield', 'Tina Nasersharif', 'Sarah Armstrong', 'Sarah Hewitt', 'Aleena Unadkat', 'Adam Selby', 'Syed M Ghufran', 'Selina V Penarski', 'Siraj Shariff', 'Safiya Issa', 'Usman Rafiq', 'Sarah Wilson', 'Sarah Taylor', 'Halima Sayed', 'Mohammed Z Albahar', 'Saleem Abubacker', 'Saleem Abubacker', 'Seema Mandalia', 'Adam Kirk', 'Adam Kirk', 'Nadine Meyer', 'Bushra Duri', 'Muhammad Ijaz-Ul-Haq', 'Negar Saleh', 'Ahmed Abbas Ahmed', 'Shahid Khan']	.
# c303	Wednesday	13	16	SS118	Mehboobullah
# ['Nina N Wronka', 'Naveed Hussain', 'Nadine Meyer', 'Eileen Harris', 'Sonia Zain', 'Iram Matloob', 'Sarah Taylor', 'Sonia Zain', 'Sarah Taylor', 'Ahmed Abbas Ahmed', 'Jasmine Winyard', 'Sarah Hadley', 'Amir Ahmed', 'Natasha J Seaward', 'Maryam Askari Louyeh', 'Sonia V Diaz', 'Yasmin Ahmed', 'Ayan Lowe', 'Arooba Zahoor', 'Sarah J Roberts', 'Selina V Penarski', 'Zainab Khattak', 'Arooba Zahoor', 'Natasha Lelijveld', 'Sara Zamberlan', 'Ayse Hatunoglu', 'Kamila Keshubay', 'Irfan Yousaf', 'Salma Khanam']	.
# c303	Monday	13	16	CS307	Noreen Jamil
# ['Mohammad Abir', 'Arman N Bahadori', 'Amber Summerfield', 'Arsheen Rajpar', 'Eileen Harris', 'Ann White', 'Syed M Ghufran', 'Parastoo Jamshidi', 'Ann White', 'Maria Lytras', 'Behzad Babakhani', 'Ameerah Kasenally-Boodoo', 'Dean Brodesky', 'Sarwar Hussain', 'Sam J Pottier', 'Adam Kirk', 'Bahjat Al-Ani', 'Ann Tai', 'Muhammad Ijaz-Ul-Haq', 'Nabila Altaf', 'Omar Chaudhrey', 'Sam D Edwards', 'Natasha Leeson', 'Zahir Hussain', 'Rafal Szczypinski', 'Natasha Edwards', 'Ahmad F Yang Abd Talib', 'Sarah Clements', 'Dalia Remeikyte']	.
# c302	Tuesday	12	15	CS218	Faisal Cheema
# ['Yas Khaled', 'Sam D Edwards', 'Ayman Jaheen', 'Sara Zamberlan', 'Sarah Clements', 'Lilia Kyuchukova', 'Seema Mandalia', 'Meryem Mehmetbasoglu', 'Dalia Remeikyte', 'Sam Isherwood', 'Huda O Ali', 'Shadan Alam', 'Sarah J Roberts', 'Iram Meharban', 'Kiran K Chahal', 'Aidan P Murphy', 'Sadra Keyhani', 'Sarah Nolasco', 'Jina Zhao', 'Samar E Nassar', 'Ramesh R Singh', 'Nima Dirie', 'Adam Selby', 'Nadia Parveen', 'Adam Kirk', 'Soha Siahpoosh Kolyaei', 'Sarah Hewitt', 'Sarah H Przybylak', 'Soha Siahpoosh Kolyaei']	.
#
#  D A D
# c309	Thursday	12	15	SS118	Faisal Cheema
# ['Kamila Houdkova', 'Amir Ahmed', 'Ramesh R Singh', 'Syed M Ghufran', 'Iram Meharban', 'Zaki Choudhury', 'Ann D Brix', 'Adam C Ryan', 'Sarah Fogg', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Shadan Mirarmandehi', 'Arman N Bahadori', 'Ahmad F Yang Abd Talib', 'Ayse Hatunoglu', 'Damian A Cummings', 'Aleena Unadkat', 'Iram Matloob', 'Sarah Fogg', 'Sarah Hinett', 'Ahmed Abbas Ahmed', 'Yas Khaled', 'Mohamed F Bakaram', 'Omar F Khan', 'Yasmin Ahmed', 'Eileen Haycox', 'Asim Ali', 'Rida Shaikh', 'Zainab Khattak', 'Razan Z Haji Zulkifli']	.
# c303	Friday	13	16	CS302	Mehboobullah
# ['Dalia Remeikyte', 'Adam Mickiewicz', 'Judi Glen', 'Sara Zamberlan', 'Samar E Nassar', 'Natasha J Seaward', 'Omar F Khan', 'Kiran K Chahal', 'Sarah Austin', 'Arsheen Rajpar', 'Imtiaz Kermali', 'Leila C Payne', 'Natasha Lelijveld', 'Sarah E Kirkham-Slack', 'Anita Hodler', 'Nina N Wronka', 'Shahina Parveen', 'Kiran K Chahal', 'Soha Siahpoosh Kolyaei', 'Farzana Yamin', 'Salman Hassan Zadeh', 'Mohamed A Baalousha', 'Ayman Jaheen', 'Jan Fiala', 'Aras Panahian Jand', 'Sheila Hughton', 'Nima Dirie', 'Ana B Javier Cuetos', 'Sarah E Kirkham-Slack']	.
# c307	Friday	11	14	MG223	Waseem Shahzad
# ['Maryam Askari Louyeh', 'Sarah Hanley', 'Siraj Shariff', 'Sarah Nolasco', 'Natasha Edwards', 'Ana Vukojevic', 'Iram Meharban', 'Sarah Hinett', 'Eileen Harris', 'Syed M Abbas', 'Soha Siahpoosh Kolyaei', 'Jina Zhao', 'Aida Hoxha', 'Imtiaz Kermali', 'Aras Panahian Jand', 'Bahjat Al-Ani', 'Ayan Lowe', 'Sarah Montgomery', 'Ibrar Manawer', 'Rida Shaikh', 'Ibrar Manawer', 'Manal Aldaihani', 'Ana Sbert Ortin', 'Dean Brodesky', 'Tara Glickman', 'Aleena Unadkat', 'Shahina Parveen', 'Mona Vadher', 'Shahid Khan']	.
# c310	Friday	10	13	SE110	Adnan Tariq
# ['Siraj Shariff', 'Sarah Dobson', 'Sarah Wilson', 'Nina N Wronka', 'Zaki Choudhury', 'Lilia Kyuchukova', 'Sadra Keyhani', 'Mona Vadher', 'Faraj B Shaban', 'Kiran K Chahal', 'Maryam Askari Louyeh', 'Sarah Taylor', 'Mohammed I Al Arfaj', 'Naveed Hussain', 'Sarah Hewitt', 'Ann Tai', 'Imtiaz Kermali', 'Mohammed Zafran', 'Natasha J Seaward', 'Kamal Anwar', 'Naseem Akram', 'Sarah L Clark', 'Sarah Clements', 'Mohammed Zafran', 'Mohammed I Al Arfaj', 'Faheema Korumtollee', 'Maria Lytras', 'Nadine Meyer', 'Ameerah Kasenally-Boodoo']	.
# c302	Wednesday	14	17	CS328	Kifayat Ullah
# ['Dean Brodesky', 'Nabila Altaf', 'Ramesh R Singh', 'Sarah N Md Sallehuddin Khan', 'Ana B Javier Cuetos', 'Kamila Houdkova', 'Kabir A Khan', 'Salwa S Alobaid', 'Ayse Hatunoglu', 'Nina N Wronka', 'Arooba Zahoor', 'Meryem Mehmetbasoglu', 'Kamal Anwar', 'Zeenat K Guness-Goolbar', 'Soha Siahpoosh Kolyaei', 'Eileen Harris', 'Damian A Cummings', 'Dean Brodesky', 'Sarah Clements', 'Sarah Austin', 'Sajida Ayub', 'Sara Zamberlan', 'Farzad Farahmand', 'Ibrahim Adegboye', 'Sarah E Kirkham-Slack', 'Sonia Zain', 'Mohammed Sukkari', 'Jan Fiala', 'Eileen Harris']	.
# c304	Thursday	10	13	EE229	Noor ul Ain
# ['Irfan Yousaf', 'Bibi A Khan', 'Sarah Wilson', 'Anja Brezovnik', 'Sagar R Jilka', 'Ana Sbert Ortin', 'Anja Sarlah', 'Salman Hassan Zadeh', 'Dalia Remeikyte', 'Aidan P Murphy', 'Sonia Zain', 'Abdul Gafur', 'Mohamed A Baalousha', 'Faraj B Shaban', 'Eileen Harris', 'Razan Z Haji Zulkifli', 'Sarah J Bradford', 'Jan Fiala', 'Kabir A Khan', 'Ana Sbert Ortin', 'Nima Dirie', 'Naseem Akram', 'Arman N Bahadori', 'Arman N Bahadori', 'Jasmine Winyard', 'Kamila Keshubay', 'Faheema Korumtollee', 'Natasha Tait', 'Nadine Meyer']	.
# c304	Friday	11	14	CS211	Gul e Aisha
# ['Huda O Ali', 'Sara Zamberlan', 'Shadan Alam', 'Nadia Parveen', 'Sarah Hadley', 'Sarah Hewitt', 'Zahir Hussain', 'Arooba Zahoor', 'Eileen Harris', 'Huda O Ali', 'Nina N Wronka', 'Sonia V Diaz', 'Sam D Edwards', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Zaki Choudhury', 'Sarah J Bradford', 'Yaser A Aljammaz', 'Sam J Pottier', 'Babak Cheraghchi Bashi Astaneh', 'Naseem Akram', 'Sarah Hewitt', 'Jenna Riley', 'Mona Vadher', 'Soha Siahpoosh Kolyaei', 'Bahjat Al-Ani', 'Meryem Mehmetbasoglu', 'Ibrahim Adegboye', 'Tina Nasersharif', 'Aleena Unadkat']	.
# c310	Friday	9	12	SS113	Tayyab Nadeem
# ['Sarah Dobson', 'Meryem Mehmetbasoglu', 'Zaki Choudhury', 'Sonia Zain', 'Sonia V Diaz', 'Amir Ahmed', 'Sadia Rehman', 'Natasha Tait', 'Mohammed I Al Arfaj', 'Maria M Ponce Carpio', 'Siraj Shariff', 'Sarah S Shahid', 'Irfan Yousaf', 'Shadan Mirarmandehi', 'Anja Sarlah', 'Siraj Shariff', 'Faraj B Shaban', 'Siraj Shariff', 'Sarah J Hammon', 'Adam Flowers', 'Bushra Duri', 'Shahzada S Niwaz', 'Sarah Austin', 'Ana Vukojevic', 'Faris Quaid', 'Ayda Niazi', 'Shadan Alam', 'Sarah Clements', 'Ayse Hatunoglu']	.
# c305	Wednesday	14	17	EE229	Hasan Mujtaba
# ['Mohammad Abir', 'Eileen Haycox', 'Adam Flowers', 'Behzad Babakhani', 'Rafal Szczypinski', 'Ahmed Abbas Ahmed', 'Parastoo Jamshidi', 'Ayman Jaheen', 'Arooba Zahoor', 'Ibrar Manawer', 'Adam Selby', 'Maria M Ponce Carpio', 'Sarah Montgomery', 'Faris Quaid', 'Dalia Remeikyte', 'Bibi A Khan', 'Nadine Meyer', 'Jenna Riley', 'Nausheen Saleem', 'Shahina Parveen', 'Sarah Austin', 'Jina Zhao', 'Sadra Keyhani', 'Ana B Javier Cuetos', 'Mohamed F Bakaram', 'Shahid Khan', 'Zainab Khattak', 'Razan Z Haji Zulkifli', 'Natasha Tait']	.
# c305	Monday	11	14	CS118	Usman Ashraf
# ['Sam D Edwards', 'Jan Fiala', 'Nina N Wronka', 'Hamza Bin Muhammad', 'Ameerah Kasenally-Boodoo', 'Tara Glickman', 'Nadia Parveen', 'Sarah Armstrong', 'Omar Chaudhrey', 'Sajida Ayub', 'Ameerah Kasenally-Boodoo', 'Sarah Dobson', 'Ahmed Abbas Ahmed', 'Sonia V Diaz', 'Zeenat K Guness-Goolbar', 'Bahjat Al-Ani', 'Hazimah H Hj Hamzah', 'Nina N Wronka', 'Bahjat Al-Ani', 'Negar Saleh', 'Sarina Patel', 'Irfan Yousaf', 'Kamal Anwar', 'Ibrar Manawer', 'Ayda Niazi', 'Safiya Issa', 'Amber Summerfield', 'Ana B Javier Cuetos', 'Ann Wilson']	.
# c302	Thursday	11	14	CS219	Mehboobullah
# ['Sam D Edwards', 'Safiya Issa', 'Maria M Ponce Carpio', 'Sarah L Barber-Jones', 'Jan Fiala', 'Eileen Harris', 'Natasha Leeson', 'Adam L Finch', 'Meryem Mehmetbasoglu', 'Adam Selby', 'Sarah Fogg', 'Sarah J Bradford', 'Nina N Wronka', 'Maria M Ponce Carpio', 'Marwa Elcheikh', 'Leila C Payne', 'Samar E Nassar', 'Sajida Ayub', 'Aidan P Murphy', 'Samar E Nassar', 'Sarah J Roberts', 'Ahmed Ahmed', 'Adam Selby', 'Ayan Lowe', 'Yaser A Aljammaz', 'Sam J Pottier', 'Nabila Altaf', 'Hanna I Siahaan', 'Hamza Bin Muhammad']	.
# c307	Tuesday	10	13	MT224	Zainab Abaid
# ['Syed M Ghufran', 'Sagar R Jilka', 'Adam Mickiewicz', 'Shadan Mirarmandehi', 'Reem N Hassan', 'Syed M Abbas', 'Yasir M Salih', 'Sarah Clements', 'Kamila Houdkova', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Faheema Korumtollee', 'Ann White', 'Syed M Abbas', 'Saleem Abubacker', 'Adam Flowers', 'Ana Sbert Ortin', 'Anja Brezovnik', 'Bibi A Khan', 'Sarah N Md Sallehuddin Khan', 'Arman N Bahadori', 'Rafal Szczypinski', 'Ana Sbert Ortin', 'Ahmed Ahmed', 'Sarah Hanley', 'Mika Tatsumoto', 'Sonia Zain', 'Leyla Doroudi', 'Manal Aldaihani', 'Maysa Saeidi']	.
# c303	Tuesday	12	15	EE229	Maimoona Rassol
# ['Eileen Haycox', 'Kabir A Khan', 'Salwa S Alobaid', 'Safiya Issa', 'Muhammad Ijaz-Ul-Haq', 'Mohamed A Baalousha', 'Ayda Niazi', 'Sarah French', 'Jina Zhao', 'Maria M Ponce Carpio', 'Leila C Payne', 'Sarah J Hammon', 'Dean Brodesky', 'Ana Sbert Ortin', 'Salma Khanam', 'Syed M Ghufran', 'Mohammed Sukkari', 'Nosheen Maqbool', 'Meryem Mehmetbasoglu', 'Mohamed F Bakaram', 'Sadra Keyhani', 'Razan Z Haji Zulkifli', 'Tara Glickman', 'Salwa S Alobaid', 'Leanne M Taylor-Smith', 'Hassana Begum', 'Ahmed Ahmed', 'Sara Zamberlan', 'Mohammed A Suleman']	.
# c310	Tuesday	13	16	MG220	Mehboobullah
# ['Syed M Abbas', 'Samina Akbar', 'Sarah Hewitt', 'Samar E Nassar', 'Ana Vukojevic', 'Iram Meharban', 'Ahmed Ahmed', 'Kabir A Khan', 'Farzana Yamin', 'Mohammed Z Albahar', 'Adam N Starling', 'Sarah Hinett', 'Sarah J Bradford', 'Soha Siahpoosh Kolyaei', 'Negar Saleh', 'Salma Khanam', 'Anja Brezovnik', 'Sam Dalgleish', 'Ameerah Kasenally-Boodoo', 'Naveed Hussain', 'Sarah J Roberts', 'Damian A Cummings', 'Adam Sanders', 'Dalia Remeikyte', 'Behzad Babakhani', 'Jenna Riley', 'Sam Isherwood', 'Shari K Rasmussen', 'Nadine Meyer']	.
# c302	Monday	14	17	CS118	Waqas Munir
# ['Kamal Anwar', 'Meltem Naylor', 'Naseem Akram', 'Usman Rafiq', 'Shadan Mirarmandehi', 'Omar S Aslam', 'Ahmed Abbas Ahmed', 'Ann D Brix', 'Sarah Armstrong', 'Sagar R Jilka', 'Ahmad F Yang Abd Talib', 'Sarah J Bradford', 'Sarah S Shahid', 'Mohammed Sukkari', 'Kabir A Khan', 'Yasmin Ahmed', 'Shadan Mirarmandehi', 'Shahina Parveen', 'Nausheen Saleem', 'Tara Glickman', 'Zaki Choudhury', 'Halima Sayed', 'Anita Hodler', 'Anita Hodler', 'Rida Shaikh', 'Nausheen Saleem', 'Ahmed Abbas Ahmed', 'Sara De La Serna', 'Yasmin Ahmed']	.
# c301	Wednesday	12	15	SS118	Behjat Zuhaira
# ['Mika Tatsumoto', 'Kamila Houdkova', 'Shahina Parveen', 'Faheema Korumtollee', 'Damian A Cummings', 'Mohamed F Bakaram', 'Hazimah H Hj Hamzah', 'Kamal Anwar', 'Nadia Parveen', 'Sarah Montgomery', 'Rafal Szczypinski', 'Sara Zamberlan', 'Leyla Doroudi', 'Bahjat Al-Ani', 'Selina V Penarski', 'Leila C Payne', 'Ameerah Kasenally-Boodoo', 'Sarah Clements', 'Anita Hodler', 'Kiran K Chahal', 'Farzad Farahmand', 'Naveed Hussain', 'Mohamed F Bakaram', 'Eileen Harris', 'Samar E Nassar', 'Zahir Hussain', 'Eileen Haycox', 'Sadra Keyhani', 'Sarwar Hussain']	.
# c304	Tuesday	13	16	CS218	Hassan Raza
# ['Mohamed A Baalousha', 'Arooba Zahoor', 'Faris Quaid', 'Nadine Meyer', 'Sam Isherwood', 'Sam Isherwood', 'Mohammed Z Albahar', 'Shadan Mirarmandehi', 'Adam Kirk', 'Tina Nasersharif', 'Adam Flowers', 'Maryam Askari Louyeh', 'Abdul Gafur', 'Babak Cheraghchi Bashi Astaneh', 'Sara De La Serna', 'Naveed Hussain', 'Ayan Lowe', 'Dean Brodesky', 'Arooba Zahoor', 'Abdul Gafur', 'Mohammed I Al Arfaj', 'Sadra Keyhani', 'Sarah Hewitt', 'Siraj Shariff', 'Hazimah H Hj Hamzah', 'Nina N Wronka', 'Reem N Hassan', 'Sarah Hinett', 'Sara De La Serna']	.
# c301	Thursday	14	17	CS220	Behjat Zuhaira
# ['Meryem Mehmetbasoglu', 'Adam L Finch', 'Sarah Hadley', 'Sam Dalgleish', 'Ayda Niazi', 'Leyla Doroudi', 'Judi Glen', 'Sarah Armstrong', 'Mohammed Sukkari', 'Faheema Korumtollee', 'Sarah Hewitt', 'Selina V Penarski', 'Salman Hassan Zadeh', 'Adam Sanders', 'Sarah Fogg', 'Sarah S Shahid', 'Yas Khaled', 'Bushra Duri', 'Ann Tai', 'Omar S Aslam', 'Sara Zamberlan', 'Zahir Hussain', 'Sarah Austin', 'Syed M Abbas', 'Yas Khaled', 'Faraj B Shaban', 'Sarah Hewitt', 'Dean Brodesky', 'Sarah N Md Sallehuddin Khan']	.
# c306	Friday	14	17	CS220	Waseem Shahzad
# ['Salwa S Alobaid', 'Arman N Bahadori', 'Mohammed Z Albahar', 'Damian A Cummings', 'Shadan Mirarmandehi', 'Adam L Finch', 'Adam Flowers', 'Ann Wilson', 'Siraj Shariff', 'Sarah J Roberts', 'Sarah French', 'Ahmed Ahmed', 'Sarah L Barber-Jones', 'Mohamed A Baalousha', 'Sajida Ayub', 'Aidan P Murphy', 'Mohamed A Baalousha', 'Tara Glickman', 'Eileen Harris', 'Salman Hassan Zadeh', 'Samar E Nassar', 'Syed M Abbas', 'Bibi A Khan', 'Maria Lytras', 'Maria A Grenfell', 'Sarah Fogg', 'Arman N Bahadori', 'Selina V Penarski', 'Meryem Mehmetbasoglu']	.
# c306	Thursday	14	17	CS118	Ameen Chilwan
# ['Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Amir Ahmed', 'Eileen Haycox', 'Mona Vadher', 'Adam Selby', 'Damian A Cummings', 'Safiya Issa', 'Manal Aldaihani', 'Zeenat K Guness-Goolbar', 'Sarah L Clark', 'Kamila Houdkova', 'Adam Selby', 'Natasha Tait', 'Ana B Javier Cuetos', 'Sonia V Diaz', 'Maria A Grenfell', 'Arsheen Rajpar', 'Nima Dirie', 'Iram Meharban', 'Shireen Dowlut-Beebeejaun', 'Leila C Payne', 'Kamila Keshubay', 'Sarah Hanley', 'Maria Lytras', 'Natasha Tait', 'Ayse Hatunoglu', 'Arooba Zahoor', 'Jasmine Winyard', 'Hassana Begum']	.
# c304	Monday	9	12	SS111	Sanaa Ilyas
# ['Hazimah H Hj Hamzah', 'Muna Osman', 'Tina Nasersharif', 'Leanne M Taylor-Smith', 'Tina Nasersharif', 'Sajida Ayub', 'Sara Zamberlan', 'Zahir Hussain', 'Safiya Issa', 'Nadia Parveen', 'Hamza Bin Muhammad', 'Bushra Duri', 'Mohamed F Bakaram', 'Judi Glen', 'Meltem Naylor', 'Sarah H Przybylak', 'Parastoo Jamshidi', 'Mohammad Abir', 'Marwa Elcheikh', 'Arman N Bahadori', 'Sarah Fogg', 'Yasmin Ahmed', 'Mohammed I Al Arfaj', 'Bibi A Khan', 'Jasmine Winyard', 'Muna Osman', 'Anita Hodler', 'Nima Dirie', 'Razan Z Haji Zulkifli']	.
# c302	Wednesday	10	13	EE227	Behjat Zuhaira
# ['Samar E Nassar', 'Sarina Patel', 'Soha Siahpoosh Kolyaei', 'Nadia Parveen', 'Parastoo Jamshidi', 'Leyla Doroudi', 'Shahina Parveen', 'Asim Ali', 'Sarah Hewitt', 'Zahir Hussain', 'Ana Vukojevic', 'Maria A Grenfell', 'Arman N Bahadori', 'Sonia V Diaz', 'Sonia V Diaz', 'Adam C Ryan', 'Maria A Grenfell', 'Kiran K Chahal', 'Arman N Bahadori', 'Sarah H Przybylak', 'Sara Zamberlan', 'Kamila Houdkova', 'Muhammad Ijaz-Ul-Haq', 'Ibrar Manawer', 'Sam J Pottier', 'Halima Sayed', 'Ibrahim Adegboye', 'Sarah Hanley', 'Sarah Hanley']	.
# c301	Wednesday	10	13	DS3011	Shams Farooq
# ['Ayman Jaheen', 'Naseem Akram', 'Selina V Penarski', 'Zahir Hussain', 'Natasha J Seaward', 'Aida Hoxha', 'Damian A Cummings', 'Mona Vadher', 'Seema Mandalia', 'Reem N Hassan', 'Ann White', 'Parastoo Jamshidi', 'Mika Tatsumoto', 'Ahmad F Yang Abd Talib', 'Sarah Taylor', 'Marwa Elcheikh', 'Sam Duncanson', 'Sagar R Jilka', 'Shahina Parveen', 'Sarah L Clark', 'Maryam Askari Louyeh', 'Nima Dirie', 'Meryem Mehmetbasoglu', 'Usman Rafiq', 'Anita Hodler', 'Hazimah H Hj Hamzah', 'Ibrar Manawer', 'Shari K Rasmussen', 'Omar Chaudhrey']	.
# c308	Monday	10	13	EE229	Aqeel Shahzad
# ['Omar S Aslam', 'Sarah J Hammon', 'Sarah Montgomery', 'Sheila Hughton', 'Kamal Anwar', 'Imtiaz Kermali', 'Sarah Clements', 'Mona Vadher', 'Ahmed Abbas Ahmed', 'Ayan Lowe', 'Irfan Yousaf', 'Omar Chaudhrey', 'Muhammad Ijaz-Ul-Haq', 'Iram Meharban', 'Marwa Elcheikh', 'Sam D Edwards', 'Sarah Hanley', 'Ramesh R Singh', 'Adam Sanders', 'Mona Vadher', 'Mohammad Abir', 'Salma Khanam', 'Babak Cheraghchi Bashi Astaneh', 'Faheema Korumtollee', 'Omar S Aslam', 'Salma Khanam', 'Sarah Dobson', 'Leila C Payne', 'Ann Wilson']	.
# c301	Monday	9	12	EE229	Mehboobullah
# ['Sarah S Shahid', 'Ann White', 'Farzana Yamin', 'Iram Matloob', 'Sarah Hinett', 'Eileen Harris', 'Rafal Szczypinski', 'Sarah Hewitt', 'Adam C Ryan', 'Ann Tai', 'Anja Sarlah', 'Samina Akbar', 'Natasha Leeson', 'Ramesh R Singh', 'Ahmed Ahmed', 'Mohammed Z Albahar', 'Hazimah H Hj Hamzah', 'Marwa Elcheikh', 'Jina Zhao', 'Jasmine Winyard', 'Shireen Dowlut-Beebeejaun', 'Salma Khanam', 'Anja Sarlah', 'Sajida Ayub', 'Sarah Wilson', 'Arooba Zahoor', 'Jasmine Winyard', 'Eileen Haycox', 'Sarah Hanley']	.
# c302	Wednesday	9	12	CS328	Faisal Cheema
# ['Kamila Houdkova', 'Sarah Austin', 'Nausheen Saleem', 'Leyla Doroudi', 'Hamza Bin Muhammad', 'Zainab Khattak', 'Hazimah H Hj Hamzah', 'Leyla Doroudi', 'Sam Dalgleish', 'Mohammed A Suleman', 'Zahir Hussain', 'Faris Quaid', 'Sarwar Hussain', 'Kiran K Chahal', 'Kamal Anwar', 'Mona Vadher', 'Sarah Hadley', 'Sarah N Md Sallehuddin Khan', 'Kamal Anwar', 'Amber Summerfield', 'Maria Lytras', 'Ameerah Kasenally-Boodoo', 'Kamal Anwar', 'Mika Tatsumoto', 'Sarah Hinett', 'Amber Summerfield', 'Aidan P Murphy', 'Ana B Javier Cuetos', 'Safiya Issa']	.
# c301	Friday	13	16	SS118	Sumera Abbas
# ['Syed M Ghufran', 'Kabir A Khan', 'Meryem Mehmetbasoglu', 'Mohammed Z Albahar', 'Razan Z Haji Zulkifli', 'Sarah J Hammon', 'Omar Chaudhrey', 'Sarah Taylor', 'Zeenat K Guness-Goolbar', 'Sajida Ayub', 'Zahra Faraji Rad', 'Asim Ali', 'Sarah Wilson', 'Mohammed Z Albahar', 'Shadan Mirarmandehi', 'Yaser A Aljammaz', 'Sarah Nolasco', 'Dalia Remeikyte', 'Ayda Niazi', 'Maria Antonia Morua Leyva', 'Ameerah Kasenally-Boodoo', 'Nabila Altaf', 'Naveed Hussain', 'Ayman Jaheen', 'Seema Mandalia', 'Salma Khanam', 'Sarah Wilson', 'Shahid Khan', 'Rafal Szczypinski']	.
# c307	Friday	12	15	AI2011	Zohaib Iqbal
# ['Maria M Ponce Carpio', 'Sara De La Serna', 'Meltem Naylor', 'Sarah Hewitt', 'Kiran K Chahal', 'Siraj Shariff', 'Nadine Meyer', 'Maria Antonia Morua Leyva', 'Adam Selby', 'Sonia V Diaz', 'Natasha J Seaward', 'Nabila Altaf', 'Nadine Meyer', 'Sarina Patel', 'Ayda Niazi', 'Adam Sanders', 'Sarah H Przybylak', 'Usman Rafiq', 'Jan Fiala', 'Sarah Hanley', 'Sagar R Jilka', 'Sam Dalgleish', 'Asim Ali', 'Mohamed F Bakaram', 'Sonia V Diaz', 'Samar E Nassar', 'Aras Panahian Jand', 'Hanna I Siahaan', 'Ameerah Kasenally-Boodoo']	.
# c307	Tuesday	13	16	DS3011	Umair Arshad
# ['Adam Kirk', 'Sarah French', 'Ann Tai', 'Shadan Alam', 'Ann Wilson', 'Hazimah H Hj Hamzah', 'Sarah Hanley', 'Hazimah H Hj Hamzah', 'Ayse Hatunoglu', 'Muna Osman', 'Maryam Askari Louyeh', 'Zeenat K Guness-Goolbar', 'Maria A Grenfell', 'Ana Vukojevic', 'Aras Panahian Jand', 'Sarah Hewitt', 'Adam Mickiewicz', 'Salwa S Alobaid', 'Sam Isherwood', 'Manal Aldaihani', 'Leanne M Taylor-Smith', 'Parastoo Jamshidi', 'Meryem Mehmetbasoglu', 'Dean Brodesky', 'Ahmed Abbas Ahmed', 'Amber Summerfield', 'Hamza Bin Muhammad', 'Sarah R Young', 'Amber Summerfield']	.
# c304	Monday	9	12	CS218	Subhan Ullah
# ['Sarah E Kirkham-Slack', 'Maryam Askari Louyeh', 'Adam Flowers', 'Anita Hodler', 'Sarina Patel', 'Mona Vadher', 'Sara De La Serna', 'Irfan Yousaf', 'Sarah Armstrong', 'Huda O Ali', 'Maria A Grenfell', 'Sarah Armstrong', 'Sarwar Hussain', 'Ann D Brix', 'Salma Khanam', 'Siraj Shariff', 'Manal Aldaihani', 'Iram Matloob', 'Sarah E Kirkham-Slack', 'Jasmine Winyard', 'Imtiaz Kermali', 'Faraj B Shaban', 'Maysa Saeidi', 'Ali M Sadeghioon', 'Siraj Shariff', 'Ayan Lowe', 'Ali M Sadeghioon', 'Mohammed Z Albahar', 'Natasha Tait']	.
# c310	Wednesday	9	12	CY2012	Hammad Majeed
# ['Adam N Starling', 'Sarah Hadley', 'Hassana Begum', 'Usman Rafiq', 'Ahmed Abbas Ahmed', 'Ana B Javier Cuetos', 'Adam N Starling', 'Soha Siahpoosh Kolyaei', 'Mohammed A Suleman', 'Kamila Houdkova', 'Sarah Fogg', 'Ana B Javier Cuetos', 'Sarah J Roberts', 'Arsheen Rajpar', 'Sarah Hanley', 'Sarah Armstrong', 'Maria M Ponce Carpio', 'Omar Chaudhrey', 'Adam Green', 'Adam Kirk', 'Kabir A Khan', 'Sadra Keyhani', 'Naveed Hussain', 'Sara Zamberlan', 'Nabila Altaf', 'Adam Selby', 'Zahra Faraji Rad', 'Sagar R Jilka', 'Sadia Rehman']	.
# c306	Wednesday	12	15	SS152	Amna Irum
# ['Ahmed Ahmed', 'Sarah L Clark', 'Meltem Naylor', 'Farzana Yamin', 'Muhammad Ijaz-Ul-Haq', 'Sarah J Bradford', 'Reem N Hassan', 'Anja Brezovnik', 'Dean Brodesky', 'Anja Brezovnik', 'Meltem Naylor', 'Zainab Khattak', 'Aras Panahian Jand', 'Arman N Bahadori', 'Sarah Hinett', 'Adam Flowers', 'Maria Lytras', 'Judi Glen', 'Asim Ali', 'Adam Selby', 'Yasir M Salih', 'Kiran K Chahal', 'Natasha Tait', 'Usman Rafiq', 'Kamal Anwar', 'Sarah Fogg', 'Omar Chaudhrey', 'Naseem Akram', 'Bibi A Khan']	.
# c305	Wednesday	11	14	SS118	Sara Aziz
# ['Mohammed Z Albahar', 'Kamila Houdkova', 'Adam Flowers', 'Sarina Patel', 'Hassana Begum', 'Sajida Ayub', 'Leila C Payne', 'Amber Summerfield', 'Ibrahim Adegboye', 'Usman Rafiq', 'Sarah Clements', 'Anja Brezovnik', 'Ramesh R Singh', 'Omar S Aslam', 'Reem N Hassan', 'Nadia Parveen', 'Leanne M Taylor-Smith', 'Sonia V Diaz', 'Selina V Penarski', 'Kiran K Chahal', 'Sarah Hinett', 'Anja Brezovnik', 'Babak Cheraghchi Bashi Astaneh', 'Marwa Elcheikh', 'Sam J Pottier', 'Usman Rafiq', 'Zahir Hussain', 'Arman N Bahadori', 'Sarah Clements']	.
# c305	Tuesday	14	17	SS118	Nagina Safdar
# ['Sadia Rehman', 'Mohammed I Al Arfaj', 'Anita Hodler', 'Faris Quaid', 'Eileen Haycox', 'Kamila Houdkova', 'Yasir M Salih', 'Ibrar Manawer', 'Sarah Hadley', 'Sadra Keyhani', 'Sarah Armstrong', 'Arooba Zahoor', 'Sam D Edwards', 'Iram Matloob', 'Mohammed Z Albahar', 'Imtiaz Kermali', 'Shahzada S Niwaz', 'Zeenat K Guness-Goolbar', 'Sara Zamberlan', 'Adam Selby', 'Kamal Anwar', 'Arman N Bahadori', 'Kabir A Khan', 'Arman N Bahadori', 'Ibrar Manawer', 'Mohammed Sukkari', 'Adam Sanders', 'Ameerah Kasenally-Boodoo', 'Eileen Haycox']	.
# c305	Tuesday	13	16	EE229	Zainab Abaid
# ['Shahzada S Niwaz', 'Maria M Ponce Carpio', 'Rafal Szczypinski', 'Negar Saleh', 'Judi Glen', 'Muna Osman', 'Leyla Doroudi', 'Behzad Babakhani', 'Adam Kirk', 'Sarah Hewitt', 'Sajida Ayub', 'Razan Z Haji Zulkifli', 'Bushra Duri', 'Sarah L Clark', 'Razan Z Haji Zulkifli', 'Ana B Javier Cuetos', 'Sarah H Przybylak', 'Sarah Fogg', 'Sarah Austin', 'Kiran K Chahal', 'Samina Akbar', 'Salma Khanam', 'Anja Brezovnik', 'Adam Mickiewicz', 'Eileen Haycox', 'Manal Aldaihani', 'Sarah Fogg', 'Sarah J Bradford', 'Babak Cheraghchi Bashi Astaneh']	.
# c305	Friday	9	12	CS220	Farwa Batool
# ['Mohamed F Bakaram', 'Mohammed I Al Arfaj', 'Nosheen Maqbool', 'Yasir M Salih', 'Naseem Akram', 'Adam Selby', 'Sagar R Jilka', 'Shahzada S Niwaz', 'Natasha Leeson', 'Adam Kirk', 'Zaki Choudhury', 'Omar S Aslam', 'Mohammed Z Albahar', 'Maria Lytras', 'Mohamed F Bakaram', 'Sarah Hanley', 'Sarah Hadley', 'Natasha Lelijveld', 'Sadia Rehman', 'Muhammad Ijaz-Ul-Haq', 'Ramesh R Singh', 'Sarah H Przybylak', 'Sarah French', 'Amber Summerfield', 'Ahmad F Yang Abd Talib', 'Aleena Unadkat', 'Tina Nasersharif', 'Syed M Abbas', 'Amir Ahmed']	.
# c308	Thursday	14	17	CS211	Adnan Tariq
# ['Sarah L Barber-Jones', 'Shari K Rasmussen', 'Parastoo Jamshidi', 'Safiya Issa', 'Mohamed A Baalousha', 'Faraj B Shaban', 'Sarina Patel', 'Halima Sayed', 'Ramesh R Singh', 'Sarah Wilson', 'Yaser A Aljammaz', 'Sarah Dobson', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Ana Vukojevic', 'Nosheen Maqbool', 'Bahjat Al-Ani', 'Sarwar Hussain', 'Sarah E Kirkham-Slack', 'Mohammed A Suleman', 'Adam Kirk', 'Sarah Clements', 'Kabir A Khan', 'Huda O Ali', 'Sadra Keyhani', 'Sarah R Young', 'Tina Nasersharif', 'Nadine Meyer', 'Mohammed Z Albahar', 'Sarah L Clark']	.
# c310	Tuesday	13	16	CS328	Nagina Safdar
# ['Anja Sarlah', 'Aidan P Murphy', 'Shari K Rasmussen', 'Natasha Leeson', 'Maysa Saeidi', 'Hassana Begum', 'Ali M Sadeghioon', 'Sarah Hanley', 'Mohammed Z Albahar', 'Mohamed F Bakaram', 'Babak Cheraghchi Bashi Astaneh', 'Faris Quaid', 'Nosheen Maqbool', 'Mohamed A Baalousha', 'Yasir M Salih', 'Aidan P Murphy', 'Mohammed Sukkari', 'Meryem Mehmetbasoglu', 'Muna Osman', 'Zaki Choudhury', 'Maryam Askari Louyeh', 'Sarwar Hussain', 'Jasmine Winyard', 'Sarah N Md Sallehuddin Khan', 'Parastoo Jamshidi', 'Irfan Yousaf', 'Meltem Naylor', 'Mohammad Abir', 'Dalia Remeikyte']	.
# c308	Wednesday	14	17	CS118	Amna Irum
# ['Selina V Penarski', 'Ana Sbert Ortin', 'Ann White', 'Mohamed A Baalousha', 'Sarah L Barber-Jones', 'Kabir A Khan', 'Salwa S Alobaid', 'Ali M Sadeghioon', 'Anja Sarlah', 'Sarah Fogg', 'Sarah Nolasco', 'Arman N Bahadori', 'Aras Panahian Jand', 'Halima Sayed', 'Naseem Akram', 'Adam L Finch', 'Sarah L Barber-Jones', 'Sarah J Hammon', 'Meltem Naylor', 'Ibrahim Adegboye', 'Ahmed Ahmed', 'Ayan Lowe', 'Adam L Finch', 'Salwa S Alobaid', 'Ramesh R Singh', 'Shadan Alam', 'Sam Dalgleish', 'Ann Wilson', 'Faraj B Shaban']	.
# c304	Monday	9	12	SS111	Kashif Munir
# ['Ramesh R Singh', 'Shahina Parveen', 'Dalia Remeikyte', 'Amir Ahmed', 'Sarah Austin', 'Muna Osman', 'Bahjat Al-Ani', 'Aida Hoxha', 'Eileen Haycox', 'Shahina Parveen', 'Syed M Ghufran', 'Aras Panahian Jand', 'Meltem Naylor', 'Shari K Rasmussen', 'Jina Zhao', 'Irfan Yousaf', 'Meryem Mehmetbasoglu', 'Ana B Javier Cuetos', 'Sarah H Przybylak', 'Nabila Altaf', 'Natasha Leeson', 'Sarah L Barber-Jones', 'Farzana Yamin', 'Siraj Shariff', 'Faheema Korumtollee', 'Sam Duncanson', 'Zainab Khattak', 'Adam Mickiewicz', 'Anja Sarlah']	.
# c301	Wednesday	9	12	CS307	Sara Aziz
# ['Yaser A Aljammaz', 'Hazimah H Hj Hamzah', 'Ali M Sadeghioon', 'Amber Summerfield', 'Sarah Armstrong', 'Sarah Montgomery', 'Sarah S Shahid', 'Adam Flowers', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Irfan Yousaf', 'Lilia Kyuchukova', 'Ayman Jaheen', 'Saleem Abubacker', 'Huda O Ali', 'Shadan Alam', 'Kamila Keshubay', 'Amber Summerfield', 'Farzad Farahmand', 'Natasha Lelijveld', 'Nima Dirie', 'Omar F Khan', 'Zahra Faraji Rad', 'Sarah Clements', 'Sarah J Roberts', 'Sarah S Shahid', 'Adam Flowers', 'Sarah E Kirkham-Slack', 'Sarah J Bradford', 'Adam Kirk']	.
# c308	Tuesday	9	12	MG220	Adnan Tariq
# ['Ibrahim Adegboye', 'Meryem Mehmetbasoglu', 'Ahmed Abbas Ahmed', 'Shireen Dowlut-Beebeejaun', 'Faraj B Shaban', 'Sarah L Barber-Jones', 'Nosheen Maqbool', 'Iram Matloob', 'Sara Zamberlan', 'Jasmine Winyard', 'Sarwar Hussain', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub', 'Damian A Cummings', 'Natasha J Seaward', 'Zahra Faraji Rad', 'Huda O Ali', 'Bibi A Khan', 'Nadine Meyer', 'Amir Ahmed', 'Leyla Doroudi', 'Mohamed F Bakaram', 'Sarah J Bradford', 'Omar Chaudhrey', 'Farzana Yamin', 'Naseem Akram', 'Sarah Wilson', 'Zahra Faraji Rad', 'Judi Glen', 'Abdul Gafur']	.
# c308	Thursday	11	14	SS111	Waseem Shahzad
# ['Yas Khaled', 'Tina Nasersharif', 'Natasha Leeson', 'Nadine Meyer', 'Aras Panahian Jand', 'Ana B Javier Cuetos', 'Naveed Hussain', 'Faris Quaid', 'Ana Vukojevic', 'Sarah R Young', 'Selina V Penarski', 'Meltem Naylor', 'Sarah Dobson', 'Sarina Patel', 'Faraj B Shaban', 'Ann Wilson', 'Sara De La Serna', 'Asim Ali', 'Selina V Penarski', 'Shari K Rasmussen', 'Adam C Ryan', 'Adam Mickiewicz', 'Muna Osman', 'Sam Dalgleish', 'Ayda Niazi', 'Adam Mickiewicz', 'Dean Brodesky', 'Mohammed Sukkari', 'Mohammed I Al Arfaj']	.
# c301	Wednesday	12	15	EE229	Amna Irum
# ['Sarah Taylor', 'Jina Zhao', 'Ayda Niazi', 'Sarah H Przybylak', 'Sadra Keyhani', 'Ahmad F Yang Abd Talib', 'Samina Akbar', 'Sarah Hinett', 'Naseem Akram', 'Anja Sarlah', 'Anja Brezovnik', 'Sarah Hinett', 'Sam J Pottier', 'Razan Z Haji Zulkifli', 'Jasmine Winyard', 'Sarah S Shahid', 'Aleena Unadkat', 'Babak Cheraghchi Bashi Astaneh', 'Nima Dirie', 'Farzad Farahmand', 'Hassana Begum', 'Ahmad F Yang Abd Talib', 'Sarah Clements', 'Sadra Keyhani', 'Tara Glickman', 'Kiran K Chahal', 'Hamza Bin Muhammad', 'Reem N Hassan', 'Ayse Hatunoglu']	.
# c307	Tuesday	11	14	AI2011	Muhammad Usman
# ['Aida Hoxha', 'Abdul Gafur', 'Saleem Abubacker', 'Amber Summerfield', 'Omar Chaudhrey', 'Sarah J Roberts', 'Maria Antonia Morua Leyva', 'Manal Aldaihani', 'Anja Sarlah', 'Faraj B Shaban', 'Shahina Parveen', 'Maria M Ponce Carpio', 'Seema Mandalia', 'Ayman Jaheen', 'Hazimah H Hj Hamzah', 'Yaser A Aljammaz', 'Syed M Ghufran', 'Ahmed Abbas Ahmed', 'Nina N Wronka', 'Anita Hodler', 'Maria A Grenfell', 'Adam Mickiewicz', 'Sarah R Young', 'Amber Summerfield', 'Yas Khaled', 'Arooba Zahoor', 'Soha Siahpoosh Kolyaei', 'Ann Wilson', 'Ann White']	.
# c302	Friday	11	14	EE229	Sara Aziz
# ['Negar Saleh', 'Ibrahim Adegboye', 'Adam C Ryan', 'Maria A Grenfell', 'Shahzada S Niwaz', 'Arsheen Rajpar', 'Safiya Issa', 'Marwa Elcheikh', 'Tara Glickman', 'Syed M Abbas', 'Adam Sanders', 'Shahzada S Niwaz', 'Marwa Elcheikh', 'Manal Aldaihani', 'Bibi A Khan', 'Mika Tatsumoto', 'Ibrar Manawer', 'Sam Dalgleish', 'Jasmine Winyard', 'Ibrahim Adegboye', 'Lilia Kyuchukova', 'Meryem Mehmetbasoglu', 'Ann D Brix', 'Tara Glickman', 'Dean Brodesky', 'Adam Kirk', 'Mohamed A Baalousha', 'Natasha Edwards', 'Adam Flowers']	.
# c310	Wednesday	13	16	CS302	Mehboobullah
# ['Yas Khaled', 'Sonia Zain', 'Maysa Saeidi', 'Zainab Khattak', 'Hassana Begum', 'Sarah Fogg', 'Faheema Korumtollee', 'Sarah L Barber-Jones', 'Faraj B Shaban', 'Hassana Begum', 'Ramesh R Singh', 'Judi Glen', 'Sarah Taylor', 'Huda O Ali', 'Sarah Montgomery', 'Lilia Kyuchukova', 'Ahmed Abbas Ahmed', 'Sajida Ayub', 'Adam Mickiewicz', 'Anita Hodler', 'Anita Hodler', 'Sarah Hewitt', 'Jenna Riley', 'Ann Wilson', 'Sarah Hewitt', 'Tina Nasersharif', 'Damian A Cummings', 'Rida Shaikh', 'Mohammed Riyaz Shahul Hameed Mohammed Yakub']	.
# c301	Wednesday	11	14	CS328	Khadija Farooq
# ['Mohammed Sukkari', 'Ibrahim Adegboye', 'Negar Saleh', 'Shari K Rasmussen', 'Faheema Korumtollee', 'Sajida Ayub', 'Sarah Hanley', 'Behzad Babakhani', 'Faraj B Shaban', 'Faheema Korumtollee', 'Sarah Montgomery', 'Sarah Hadley', 'Mohammed I Al Arfaj', 'Ana Vukojevic', 'Sara Zamberlan', 'Sarah Armstrong', 'Bushra Duri', 'Ibrahim Adegboye', 'Farzad Farahmand', 'Kiran K Chahal', 'Anja Sarlah', 'Sadia Rehman', 'Ayda Niazi', 'Yas Khaled', 'Sarah Armstrong', 'Natasha Leeson', 'Zainab Khattak', 'Natasha Lelijveld', 'Aidan P Murphy']	.

# %% [markdown]
# # Crossover

# %%
def binary_crossover(husband, wife):
    length = len(husband.genes) // 2
    children = []
    son = husband.genes[:length] + wife.genes[length:]
    daughter = wife.genes[:length] + husband.genes[length:]

    children.append(son)
    children.append(daughter)

    return children


def randomized_fixed_point_crossover(mom, dad):
    # Random point must be between the length of the best member
    #     print("Length of member 1 are:", len(chromosome_1.genes))
    pass_loop = True

    new_pop = []

    while pass_loop:
        try:
            random_fixed_point = random.randint(1, len(mom.genes) - 1)
            son = np.concatenate((mom.genes[:random_fixed_point], dad.genes[random_fixed_point:]))
            daughter = np.concatenate((dad.genes[:random_fixed_point], mom.genes[random_fixed_point:]))

            new_pop.append(son)
            new_pop.append(daughter)

            #             for gene_a, gene_b in zip(chromosome_a, chromosome_b):
            #                 if (gene_a == gene_b):
            #                     print ("Gene is same!")

            #             if chromosome_a == chromosome_b:
            #                 print ("Chromosome is same!")

            pass_loop = False
        except Exception as e:
            print("Error! ", str(e))
            pass_loop = True

    return new_pop


def crossover(mom, dad, population):
    #     return binary_crossover(mom, dad)
    new_chromosomes = []
    for i in range(0, random.randint(2, 8)):
        children = randomized_fixed_point_crossover(mom, dad)
        for child in children:
            #             if (child not in new_chromosomes):
            new_chromosomes.append(Chromosome(genes=child))

    return Population(chromosomes=new_chromosomes)

# %% [markdown]
# # Constraints

# %%
def hard_test_invigilator(chromosome):
    wrong_value = 0
    wrong_genes = []
    
    points = 0
    for gene_1 in chromosome:
        for gene_2 in chromosome:
            if gene_2 == gene_1:
                continue
            if gene_2.day == gene_1.day:
                if gene_2.start_time == gene_1.start_time:
                    if gene_2.classroom_name == gene_1.classroom_name:
                        if gene_2.instructor == gene_1.instructor:
                            continue
                        else:
                            points += 10

    return points
    # for gene1 in chromosome.genes:
    #     for gene2 in chromosome.genes:
    #         if gene1.day == gene2.day:
    #             if gene1.start_time == gene2.start_time:
    #                 wrong_genes.append(gene1)
    #                 wrong_genes.append(gene2)
    #                 wrong_value += 1

    # i = 0
    # while i < len(chromosome.genes) - 1:
    #     j = i
    #     while j < len(chromosome.genes) - 1:
    #         j += 1
    #         if chromosome[i].day == chromosome[j].day:
    #             if chromosome[i].instructor == chromosome[j].instructor:
    #                 if abs(chromosome[i].start_time - chromosome[j].start_time) < 3:
    #                     if (chromosome[i], chromosome[j]) not in wrong_genes and (
    #                             chromosome[j], chromosome[i]) not in wrong_genes:
    #                         # wrong_genes.append((chromosome[i], chromosome[j]))
    #                         # wrong_value += 1
    #                         return False
    #     i += 1
    #
    # for genes in wrong_genes:
    #     print(genes[0])
    #     print(genes[1])

    # return wrong_value
#     return True


def hard_test_valid_paper_duration(chromosome):
    #     for chromosome in chromosomes:
    points = 0
    for gene_p in chromosome:
        if (gene_p.end_time - gene_p.start_time) != 3:
            continue
        else:
            points += 10

    #     print("I am true at: ",gene_p.start_time,gene_p.end_time)
    return points


def hard_test_no_exam_on_weekends(chromosome):
    #     for chromosome in chromosomes:
    points = 0
    for gene_p in chromosome:
        if (gene_p.day in ["Saturday", "Sunday"]):
            continue
        else:
            points += 10
    return points


# def hard_test_one_invigilator_per_exam(chromosome):
#     """At a given time, one instructor can only invigilate one exam"""
#     pass


## Possible generic constraints
def hard_test_student_one_exam_at_a_time(chromosome):
    """At a given time, student can only give one exam"""
    # Note: Also test the current gene from which the student is selected, because the same student might be repeated in a single class
    points = 0
    i = j = 0

    while i < len(chromosome.genes):
        for student in chromosome.genes[i].students:
            for genes in chromosome:
                if genes == chromosome.genes[i]:
                    continue
                if genes.start_time == chromosome.genes[i].start_time and genes.day == chromosome.genes[i].day:
                    if student in genes.students:
                        # print('Student in multiple exam')
                        continue
                    else:
                        points += 10
        i += 1

    return points


def hard_test_one_exam_per_course(chromosome):
    """First hard constraint: Every course must have an exam"""
    pass


def hard_test_one_exam_per_classroom(chromosome):
    """At a given time, a classroom can only have one exam ongoing"""
    for genes_1 in chromosome:
        for genes_2 in chromosome:
            if genes_1 == genes_2:
                continue
            if genes_2.classroom_name == genes_1.classroom_name:
                if genes_1.start_time < genes_2.start_time or genes_2.start_time < genes_1.start_time:
                    return False

    return True


def hard_test_classroom_capacity(chromosome):
    """Number of students in an exam must not exceed the classroom capacity"""
    pass


def hard_test_students_taking_correct_exam(chromosome):
    """Students must be taking the exam of the course they're registered for"""
    #     print(student_course_file)

    points = 0
    for genes in chromosome:
        for student in genes.students:
            #             print(student_course_file["StudentName"])
            mask = student_course_file["StudentName"] == student
            student_courses = student_course_file[mask]["CourseCode"]
                # print(student_courses)
            if genes.course not in student_courses:
                # print('Student not taking correct exam')
                continue
            else:
                points += 10

    return points


def soft_test_consecutive_exams(data):
    print("Hello soft constraint test")
    return True


HARD_CONSTRAINTS = [
    {
        "name": "Paper must be of 3 hours",
        "func": hard_test_valid_paper_duration,
        "fields": [
            'start_time',
            'end_time',
        ]
    },
#     {
#         "name": "Instructor cannot invigilate two consecutive exams",
#         "func": hard_test_invigilator,
#         "fields": [
#             'instructor',
#         ]
#     },
    {
        "name": "No exams on weekend",
        "func": hard_test_no_exam_on_weekends,
        "fields": [
            'day',
        ]
    },
    {
        "name": "One exam at a time",
        "func": hard_test_student_one_exam_at_a_time,
        "fields": [
            'students',
        ]
    },
    {
        "name": "Student taking correct exam ",
        "func": hard_test_students_taking_correct_exam,
        "fields": [
            'students',
        ]
    },
]

soft_constraints = [
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },
    {
        "name": "Student should not have consecutive exams",
        "func": soft_test_consecutive_exams
    },

]

# %% [markdown]
# # Fitness of chromosome

# %%
def set_fitness(chromosome_p):
    constraints_passed = 0
    fields_to_mutate = []

    # Right now, checking only hard constraints
    for constraint in HARD_CONSTRAINTS:
        constraints_passed += constraint["func"](chromosome_p)
        if constraints_passed < 1000:
            if constraint["fields"] not in fields_to_mutate: fields_to_mutate += constraint["fields"]

    # Set fitness value of individual chromosome
    chromosome_p.fitness_value = constraints_passed

    return constraints_passed, fields_to_mutate

# %%
new_pop = initialize_population()

for chromosome in new_pop:
    chromosome.fitness_value = random.randint(0,20)

mom, dad = select_best_mom_and_dad(new_pop)

fields_to_mutate = []


fitness_value, temp_fields = set_fitness(mom)
if temp_fields not in fields_to_mutate: fields_to_mutate.append(temp_fields)
else: fields_to_mutate.append([])
    
        
print(fields_to_mutate)

# %% [markdown]
# # Mutation

# %%
def modify_gene(gene, fields):
    # Two different approaches:
    # 1. Only mutate those values which were found to violate the constraints e.g time was not right so mutate time only
    #    -> will require a list of all constraints not met by the chromosome
    # 2. Mutate the entire gene completely

    # For now, let's try a combination of both.
    # Our model is partially self-aware.
    # So what we can do is that flip a coin.
    # If heads, then return a completely new gene.
    # If tails, apply some self-awareness.

    coin = random.randint(0, 1)

    # First make a completely random new Gene
    new_gene = Gene()

    # If heads...
    if coin:
        return new_gene

    # Else if tails...

    # Modify the existing fields of the selected gene
    for field in fields:
        setattr(gene, field, getattr(new_gene, field))

    return gene


def modify_chromosome(chromosome, random_index):
    # if heads, delete a gene
    # if tails, regenerate the entire chromosome
    coin = random.randint(0, 1)

    if coin:
        np.delete(chromosome.genes, random_index)
    else:
        chromosome = Chromosome()

    return chromosome


def mutate(chromosome, fields_to_mutate):
    #     print("Chromosome length:", len(chromosome.genes))
    random_index = random.randint(0, len(chromosome.genes) - 1)

    coin = random.randint(0, 1)

    # if heads, modify a gene
    if coin:
        chromosome.genes[random_index] = modify_gene(chromosome.genes[random_index], fields_to_mutate)
    # if tails, modify the chromosome itself
    else:
        chromosome = modify_chromosome(chromosome, random_index)

    #     print ("Chromosome is:", chromosome)

    return chromosome

    new_pop = initialize_population()

    for chromosome in new_pop:
        chromosome.fitness_value = random.randint(0, 20)

    mom, dad = select_best_mom_and_dad(new_pop)

    fields_to_mutate = []

    fitness_value, temp_fields = set_fitness(mom)
    if temp_fields not in fields_to_mutate:
        fields_to_mutate.append(temp_fields)
    else:
        fields_to_mutate.append([])

    #     for gene in mom:
    #         print(gene)

    print(fields_to_mutate)

    #     print('Mom genes before mutation')
    #     for chromosome in mom:
    #         for gene in chromosome:
    #             print(gene)
    random_index = random.randint(0, len(mom.genes) - 1)
    previous_constraint, fields_to_mutate = set_fitness(mom)
    print('Constraints met before mutation: ', previous_constraint)

    for i in range(0, 200):
        mom = mutate(mom, fields_to_mutate)

        new_constraint, fields_to_mutate = set_fitness(mom)

    for gene in mom:
        print(gene)

    print('Constraints met after mutation: ', new_constraint)

# %%
    new_pop = initialize_population()

    for chromosome in new_pop:
        chromosome.fitness_value = random.randint(0,20)
    
    mom, dad = select_best_mom_and_dad(new_pop)

    fields_to_mutate = []

    fitness_value, temp_fields = set_fitness(mom)
    if temp_fields not in fields_to_mutate:
        fields_to_mutate.append(temp_fields)
    else:
        fields_to_mutate.append([])

#     for gene in mom:
#         print(gene)
        
    print(fields_to_mutate)

#     print('Mom genes before mutation')
#     for chromosome in mom:
#         for gene in chromosome:
#             print(gene)
    random_index = random.randint(0, len(mom.genes) - 1)
    previous_constraint, fields_to_mutate = set_fitness(mom)
    print('Constraints met before mutation: ', previous_constraint)

    for i in range(0, 10):
        mom = mutate(mom, fields_to_mutate)

        new_constraint, fields_to_mutate = set_fitness(mom)

    for gene in mom:
        print(gene)
        
    print('Constraints met after mutation: ', new_constraint)

# %% [markdown]
# # Evaluation

# %%
min_soft_constraints = 3


def evaluate(candidate, tatti):
    #     for constraint in hard_constraints:
    #         if (constraint["func"](solution) == False):
    #             return False

    #     print (tatti)

    if tatti is None:
        tatti = copy.deepcopy(candidate)
    elif candidate.fitness_value > tatti.fitness_value:
        tatti = copy.deepcopy(candidate)
    #     soft_constraint_pass_counter = 0
    #     for constraint in soft_constraints:
    #         if (constraint["func"](solution) == True):
    #             soft_constraint_pass_counter += 1
    #         if soft_constraint_pass_counter > min_soft_constraints:
    #             return True

    return tatti


def print_mom_and_dad(mom, dad):
    print("Mom genes:")

    for gene in mom:
        print(gene)

    print("Mom Fitness Value: ", mom.fitness_value)
    print("\n")
    print("Dad genes:")

    for gene in dad:
        print(gene)

    print("Dad Fitness Value: ", dad.fitness_value)

# %%
# evaluate(mom)

# %% [markdown]
# # Our Genetic Algorithm
#
# ## Basic
# Steps are:
# - ~Generate New Population~
# - ~Initial Selection of Parents~
# - ~Crossover~
# - ~Fitness~
# - ~Mutate~
# - ~Select best mom and dad~
# - ~Evaluate~
#
# ## Advanced
# - ~Use pandas, numpy!~
# - ~Set accurate constraints (we have issues in some constraints where we are only checking Intra-chromosome, whereas we should be checking  INTER-chromosome e.g. Teacher constraint, sometimes teacher might appear in different classrooms)~ (Fixed by putting classroom_name in Gene class)
# - ~Completely clean out "Member" implementations~
# - ~Generate more children~
# - ~Roulette wheel selection~
# - ~Population regeneration if evaluation failure, if certain number of failures happen then stop~
#     ~- If mom and dad better than last time, then continue. Maybe you'll find better~
# - Days should have IDs, so that we can also go to the next week incase the current week is full
# - Make all test cases:
#     - Hard constraints
#     - Soft constraints
# - Generate a completely correct value
#
#
#
# ## Cherry-on-top
# - Use data from the CSVs

# %%
def GeneticAlgorithm():
    max_generations = random.randint(20, 300)
    mutation_probability = random.randint(0, 50)
    qoum_check = random.randint(10, max_generations // 4)
    hidayah = random.randint(0, 5)
    qiyamah = random.randint(hidayah, qoum_check // 2)

    print("==========================    HYPERPARAMETERS    ==========================")
    print("Max generations\t\t:", max_generations)
    print("Mutation Probability\t:", mutation_probability)
    print("Qoum Check\t\t:", qoum_check)
    print("Hidayah\t\t\t:", hidayah)
    print("Qiyamah\t\t\t:", qiyamah)
    print("\n\n")

    new_generation = initialize_population()

    solution_counter = 0
    prev_best_solution = None
    best_solution = None

    ## Two options:
    ## Randomize initial mom and dad

    ## Or select the best
    for chromosome in new_generation:
        set_fitness(chromosome)
    mom, dad = select_best_mom_and_dad(new_generation)

    #     print("========================= Before:")
    #     print_mom_and_dad(mom, dad)

    print("\n\n")

    # -------------------------------- START GA LOOP

    for i in range(0, max_generations):

        #         print("Mom is = ", mom)
        #         print("Dad is = ", dad)
        #         print("Crossing over...")
        children = crossover(mom, dad, new_generation)
        new_chromosomes = []
        fields_to_mutate = []
        for idx, chromosome in enumerate(children):

            #             print("Setting fitness...")
            fitness_value, temp_fields = set_fitness(chromosome)
            fields_to_mutate.append(temp_fields)

            #             if fitness_value == -1:
            #                 continue

            if random.randint(0, 100) < mutation_probability:
                #                 print("Mutating...")
                #                 prev_fitness_value = copy.deepcopy(fitness_value)
                #                 while fitness_value <= prev_fitness_value:
                mutate(chromosome, fields_to_mutate[idx])
                fitness_value_changed, fields_to_mutate[idx] = set_fitness(chromosome)
                fitness_value = fitness_value_changed

            new_chromosomes.append(chromosome)

        #         sorted_generation = sorted(new_generation, key=lambda chromosome: chromosome.fitness_value )

        #         new_generation.chromosomes = sorted_generation[len(sorted_generation)//2:]

        #         for chromosome in new_chromosomes:
        #             new_generation.chromosomes.append(chromosome)

        next_gen = Population(chromosomes=new_chromosomes)

        #         for chromosome in next_gen:
        #             print("Fitness value", chromosome.fitness_value)

        mom, dad = select_best_mom_and_dad(next_gen)

        best_solution = evaluate(mom, best_solution)

        ### print Every 100th generation results
        if i % qoum_check == 0:

            print('\nCurrent generation..: {}'.format(i))
            print('Current Mom fitness value:', mom.fitness_value)
            print('Current Dad fitness value:', dad.fitness_value)
            print('Best solution so far: {}'.format(best_solution.fitness_value))
            if prev_best_solution is None:
                prev_best_solution = best_solution
            if best_solution.fitness_value > prev_best_solution.fitness_value:
                solution_counter = 0
            elif best_solution.fitness_value == prev_best_solution.fitness_value:
                solution_counter += 1

            print("Muhlat counter:", solution_counter)

            if solution_counter > qiyamah:
                # Too much stagnation
                print(
                    '"And if you turn away, He will replace you with another people; then they will not be the likes of you." - (Qur’an, 47: 38)')
                change_fundamentals()
                
                new_generation = initialize_population()
                np.append(new_generation.chromosomes, mom)
                np.append(new_generation.chromosomes, prev_best_solution)

                solution_counter = 0

            elif solution_counter > hidayah:
                # Reintroduce  D A D into chromosome pool
                print(
                    '"And We made them leaders, guiding people by Our Command, and We sent them inspiration to do good deeds, to establish regular prayers, and to practice regular charity; and they constantly worshipped Us." (Qur’an, 21: 73)')
                dad = best_solution

            else:
                prev_best_solution = best_solution

    # -------------------------------- END GA LOOP

    print("\n\n")

    #     print("========================= After 1000 iterations:")
    #     print_mom_and_dad(mom, dad)

    print("\n\n=================================------------======================================")

    best_solution = sorted(best_solution, key=lambda gene: (gene.day, gene.start_time))

    print("Our best solution is:")
    for gene in best_solution:
        print(gene)

    print("\nFitness value is: ", best_solution.fitness_value)

# %%
GeneticAlgorithm()
# Out:
# ==========================    HYPERPARAMETERS    ==========================
# Max generations		: 99
# Mutation Probability	: 7
# Qoum Check		: 13
# Hidayah			: 4
# Qiyamah			: 6
